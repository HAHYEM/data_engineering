# %%
#실시간 차트

#웹 크롤링을 쉽게 해주는 BeautifulSoup
#크롤링: 웹 사이트의 HTML문서에서 필요한 정보를 수집하는 것
#스크래이핑: 실제 HTML만을 이용해 수집하는 것(크롤링의 일종)

#Anaconda 설치 시 BeautifulSoup 라이브러리가 자동으로 포함됨
from bs4 import BeautifulSoup
from urllib.request import urlopen

pg = urlopen('http://www.mnet.com/chart/TOP100/2018031514') #url의 페이지(html) 불러오기 / 엠넷
pg2 = urlopen('http://www.mnet.com/chart/TOP100/2018031514?pNum=2')

soup = BeautifulSoup(pg, 'html.parser')
soup2 = BeautifulSoup(pg2, 'html.parser')

song_list = soup.find(class_='MMLTable jQMMLTable').table.tbody.find_all('tr')
song_list

song_list2 = soup2.find(class_='MMLTable jQMMLTable').table.tbody.find_all('tr')
song_list2
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [<tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Faded - 선택" type="checkbox" value="5148577"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_51">51위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">4</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/523296 " target="_self"><img alt="Faded - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '523296', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/523/523296.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/5148577" target="_self">Faded - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('5148577');" title="Faded 새창">Faded</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/477488 " target="_self" title="Alan Walker - 아티스트">Alan Walker</a> /
#  							<a class="MMLIInfo_Album" href=" /album/523296 " target="_self" title="Faded - 앨범">Faded</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('5148577','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('5148577');" title="Faded - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_5148577" title="마이앨범 담기">5148577</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('5148577');" title="Faded - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('5148577');" title="Faded - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="LIKEY - 선택" type="checkbox" value="19724193"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_52">52위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">14</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2232812 " target="_self"><img alt="twicetagram - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2232812', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/232/2232812.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/19724193" target="_self">LIKEY - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('19724193');" title="LIKEY 새창">LIKEY</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/463178 " target="_self" title="TWICE(트와이스) - 아티스트">TWICE(트와이스)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2232812 " target="_self" title="twicetagram - 앨범">twicetagram</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('19724193','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('19724193');" title="LIKEY - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_19724193" title="마이앨범 담기">19724193</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('19724193');" title="LIKEY - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('19724193');" title="LIKEY - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('19724193','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('19724193','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  <div class="mqs_info" style="display:block;">
#  <div class="mqs_infoTxt">
#  <a href="javascript:;" onclick="$('#mqsInfo').show();">원음 이용안내</a>
#  <button onclick="$(this).parent('.mqs_infoTxt').parent('.mqs_info').hide();mnetCookie.setCookie('mqsLayer','Y',7);" type="button">닫기</button>
#  </div>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="GO - 선택" type="checkbox" value="30701750"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_53">53위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">9</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2858698 " target="_self"><img alt="NCT 2018 EMPATHY - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2858698', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/858/2858698.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30701750" target="_self">GO - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30701750');" title="GO 새창">GO</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/505958 " target="_self" title="NCT DREAM - 아티스트">NCT DREAM</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2858698 " target="_self" title="NCT 2018 EMPATHY - 앨범">NCT 2018 EMPATHY</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30701750','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30701750');" title="GO - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30701750" title="마이앨범 담기">30701750</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30701750');" title="GO - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30701750');" title="GO - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30701750','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Love Letter (언약) - 선택" type="checkbox" value="298204"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_54">54위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">3</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/20811 " target="_self"><img alt="Love Letter - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '20811', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/020/20811.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/298204" target="_self">Love Letter (언약) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('298204');" title="Love Letter (언약) 새창">Love Letter (언약)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/80854 " target="_self" title="2Shai - 아티스트">2Shai</a> /
#  							<a class="MMLIInfo_Album" href=" /album/20811 " target="_self" title="Love Letter - 앨범">Love Letter</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('298204','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('298204');" title="Love Letter (언약) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_298204" title="마이앨범 담기">298204</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('298204');" title="Love Letter (언약) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('298204');" title="Love Letter (언약) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="그날처럼 - 선택" type="checkbox" value="22972170"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_55">55위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">809</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2515484 " target="_self"><img alt="그날처럼 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2515484', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/515/2515484.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/22972170" target="_self">그날처럼 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('22972170');" title="그날처럼 새창">그날처럼</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/372831 " target="_self" title="장덕철 - 아티스트">장덕철</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2515484 " target="_self" title="그날처럼 - 앨범">그날처럼</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('22972170','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('22972170');" title="그날처럼 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_22972170" title="마이앨범 담기">22972170</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('22972170');" title="그날처럼 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('22972170');" title="그날처럼 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('22972170','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('22972170','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="비밀정원 - 선택" type="checkbox" value="27687757"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_56">56위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">4</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2760481 " target="_self"><img alt="비밀정원 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2760481', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/760/2760481.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/27687757" target="_self">비밀정원 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('27687757');" title="비밀정원 새창">비밀정원</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/404673 " target="_self" title="오마이걸(OH MY GIRL) - 아티스트">오마이걸(OH MY GIRL)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2760481 " target="_self" title="비밀정원 - 앨범">비밀정원</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('27687757','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('27687757');" title="비밀정원 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_27687757" title="마이앨범 담기">27687757</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('27687757');" title="비밀정원 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('27687757');" title="비밀정원 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('27687757','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('27687757','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="다른사람을 사랑하고 있어 - 선택" type="checkbox" value="29438397"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_57">57위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">22</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2779423 " target="_self"><img alt="Faces of Love - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2779423', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/779/2779423.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/29438397" target="_self">다른사람을 사랑하고 있어 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('29438397');" title="다른사람을 사랑하고 있어 새창">다른사람을 사랑하고 있어</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/177360 " target="_self" title="수지(SUZY) - 아티스트">수지(SUZY)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2779423 " target="_self" title="Faces of Love - 앨범">Faces of Love</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('29438397','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('29438397');" title="다른사람을 사랑하고 있어 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_29438397" title="마이앨범 담기">29438397</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('29438397');" title="다른사람을 사랑하고 있어 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('29438397');" title="다른사람을 사랑하고 있어 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('29438397','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('29438397','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="봄타 - 선택" type="checkbox" value="30617313"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_58">58위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">6</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828085 " target="_self"><img alt="Yellow Flower - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828085', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828085.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617313" target="_self">봄타 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617313');" title="봄타 새창">봄타</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317059 " target="_self" title="마마무(Mamamoo) - 아티스트">마마무(Mamamoo)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828085 " target="_self" title="Yellow Flower - 앨범">Yellow Flower</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617313','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617313');" title="봄타 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617313" title="마이앨범 담기">30617313</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617313');" title="봄타 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617313','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617313','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="사랑은 아프다 - 선택" type="checkbox" value="30390864"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_59">59위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">17</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2788095 " target="_self"><img alt="미스티 (JTBC 금토드라마) OST - Part 1 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2788095', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/788/2788095.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30390864" target="_self">사랑은 아프다 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30390864');" title="사랑은 아프다 새창">사랑은 아프다</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/7916 " target="_self" title="이승철 - 아티스트">이승철</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2788095 " target="_self" title="미스티 (JTBC 금토드라마) OST - Part 1 - 앨범">미스티 (JTBC 금토드라마) OST - Part 1</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30390864','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30390864');" title="사랑은 아프다 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30390864" title="마이앨범 담기">30390864</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30390864');" title="사랑은 아프다 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30390864');" title="사랑은 아프다 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30390864','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Baby Don’t Stop - 선택" type="checkbox" value="30701749"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_60">60위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">10</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2858698 " target="_self"><img alt="NCT 2018 EMPATHY - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2858698', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/858/2858698.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30701749" target="_self">Baby Don’t Stop - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30701749');" title="Baby Don’t Stop 새창">Baby Don’t Stop</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/487174 " target="_self" title="NCT U - 아티스트">NCT U</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2858698 " target="_self" title="NCT 2018 EMPATHY - 앨범">NCT 2018 EMPATHY</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30701749','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30701749');" title="Baby Don’t Stop - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30701749" title="마이앨범 담기">30701749</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30701749');" title="Baby Don’t Stop - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30701749');" title="Baby Don’t Stop - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30701749','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="TOUCH - 선택" type="checkbox" value="30701751"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_61">61위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">15</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2858698 " target="_self"><img alt="NCT 2018 EMPATHY - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2858698', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/858/2858698.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30701751" target="_self">TOUCH - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30701751');" title="TOUCH 새창">TOUCH</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/499482 " target="_self" title="NCT 127 - 아티스트">NCT 127</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2858698 " target="_self" title="NCT 2018 EMPATHY - 앨범">NCT 2018 EMPATHY</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30701751','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30701751');" title="TOUCH - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30701751" title="마이앨범 담기">30701751</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30701751');" title="TOUCH - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30701751');" title="TOUCH - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30701751','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Heart Shaker - 선택" type="checkbox" value="25021489"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_62">62위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">9</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2637695 " target="_self"><img alt="Merry &amp; Happy - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2637695', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/637/2637695.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/25021489" target="_self">Heart Shaker - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('25021489');" title="Heart Shaker 새창">Heart Shaker</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/463178 " target="_self" title="TWICE(트와이스) - 아티스트">TWICE(트와이스)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2637695 " target="_self" title="Merry &amp; Happy - 앨범">Merry &amp; Happy</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('25021489','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('25021489');" title="Heart Shaker - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_25021489" title="마이앨범 담기">25021489</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('25021489');" title="Heart Shaker - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('25021489');" title="Heart Shaker - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('25021489','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('25021489','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="The Reason - 선택" type="checkbox" value="30628076"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_63">63위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">27</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628076" target="_self">The Reason - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628076');" title="The Reason 새창">The Reason</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628076','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628076');" title="The Reason - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628076" title="마이앨범 담기">30628076</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628076');" title="The Reason - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30628076','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30628076','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="답장 - 선택" type="checkbox" value="27813954"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_64">64위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">19</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2761476 " target="_self"><img alt="답장 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2761476', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/761/2761476.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/27813954" target="_self">답장 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('27813954');" title="답장 새창">답장</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/1331 " target="_self" title="김동률 - 아티스트">김동률</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2761476 " target="_self" title="답장 - 앨범">답장</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('27813954','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('27813954');" title="답장 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_27813954" title="마이앨범 담기">27813954</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('27813954');" title="답장 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('27813954');" title="답장 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('27813954','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('27813954','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="HOLIDAY (Feat. DPR LIVE) - 선택" type="checkbox" value="29438398"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_65">65위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">28</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2779423 " target="_self"><img alt="Faces of Love - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2779423', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/779/2779423.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/29438398" target="_self">HOLIDAY (Feat. DPR LIVE) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('29438398');" title="HOLIDAY (Feat. DPR LIVE) 새창">HOLIDAY (Feat. DPR LIVE)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/177360 " target="_self" title="수지(SUZY) - 아티스트">수지(SUZY)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2779423 " target="_self" title="Faces of Love - 앨범">Faces of Love</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('29438398','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('29438398');" title="HOLIDAY (Feat. DPR LIVE) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_29438398" title="마이앨범 담기">29438398</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('29438398');" title="HOLIDAY (Feat. DPR LIVE) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('29438398');" title="HOLIDAY (Feat. DPR LIVE) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('29438398','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('29438398','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="우산 (Feat. 윤하) - 선택" type="checkbox" value="1669825"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_66">66위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">9</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/159821 " target="_self"><img alt="Pieces, Part One - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '159821', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/159/159821.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/1669825" target="_self">우산 (Feat. 윤하) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('1669825');" title="우산 (Feat. 윤하) 새창">우산 (Feat. 윤하)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/81181 " target="_self" title="에픽하이 (EPIK HIGH) - 아티스트">에픽하이 (EPIK HIGH)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/159821 " target="_self" title="Pieces, Part One - 앨범">Pieces, Part One</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('1669825','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('1669825');" title="우산 (Feat. 윤하) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_1669825" title="마이앨범 담기">1669825</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('1669825');" title="우산 (Feat. 윤하) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('1669825');" title="우산 (Feat. 윤하) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="망설이다 - 선택" type="checkbox" value="30628077"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_67">67위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">29</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628077" target="_self">망설이다 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628077');" title="망설이다 새창">망설이다</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628077','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628077');" title="망설이다 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628077" title="마이앨범 담기">30628077</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628077');" title="망설이다 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30628077','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
# ...
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('16263456');" title="Beautiful - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('16263456');" title="Beautiful - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('16263456','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('16263456','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="한숨 - 선택" type="checkbox" value="5234732"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_96">96위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/534414 " target="_self"><img alt="SEOULITE - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '534414', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/534/534414.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/5234732" target="_self">한숨 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('5234732');" title="한숨 새창">한숨</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/228515 " target="_self" title="이하이 - 아티스트">이하이</a> /
#  							<a class="MMLIInfo_Album" href=" /album/534414 " target="_self" title="SEOULITE - 앨범">SEOULITE</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('5234732','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('5234732');" title="한숨 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_5234732" title="마이앨범 담기">5234732</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('5234732');" title="한숨 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('5234732');" title="한숨 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('5234732','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="파랑새 - 선택" type="checkbox" value="30627896"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_97">97위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">34</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2829651 " target="_self"><img alt="에이프릴(APRIL) 5th Mini Album `The Blue` - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2829651', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/829/2829651.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30627896" target="_self">파랑새 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30627896');" title="파랑새 새창">파랑새</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/456349 " target="_self" title="에이프릴(APRIL) - 아티스트">에이프릴(APRIL)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2829651 " target="_self" title="에이프릴(APRIL) 5th Mini Album `The Blue` - 앨범">에이프릴(APRIL) 5th Mini Album `The Blue`</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30627896','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30627896');" title="파랑새 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30627896" title="마이앨범 담기">30627896</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30627896');" title="파랑새 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30627896');" title="파랑새 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30627896','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="IF YOU - 선택" type="checkbox" value="4675137"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_98">98위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">6</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/467970 " target="_self"><img alt="D - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '467970', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/467/467970.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/4675137" target="_self">IF YOU - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('4675137');" title="IF YOU 새창">IF YOU</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/132028 " target="_self" title="BIGBANG - 아티스트">BIGBANG</a> /
#  							<a class="MMLIInfo_Album" href=" /album/467970 " target="_self" title="D - 앨범">D</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('4675137','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('4675137');" title="IF YOU - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_4675137" title="마이앨범 담기">4675137</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('4675137');" title="IF YOU - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('4675137','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Undercover (Feat. 윤미래) - 선택" type="checkbox" value="30628588"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_99">99위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">9</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2829750 " target="_self"><img alt="Only Human - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2829750', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/829/2829750.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628588" target="_self">Undercover (Feat. 윤미래) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628588');" title="Undercover (Feat. 윤미래) 새창">Undercover (Feat. 윤미래)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/249016 " target="_self" title="Junoflo(주노플로) - 아티스트">Junoflo(주노플로)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2829750 " target="_self" title="Only Human - 앨범">Only Human</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628588','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628588');" title="Undercover (Feat. 윤미래) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628588" title="마이앨범 담기">30628588</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628588');" title="Undercover (Feat. 윤미래) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30628588','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="물감 - 선택" type="checkbox" value="18038921"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_100">100위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">848</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/1980313 " target="_self"><img alt="물감 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '1980313', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/001/980/1980313.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/18038921" target="_self">물감 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('18038921');" title="물감 새창">물감</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/367350 " target="_self" title="문문(MoonMoon) - 아티스트">문문(MoonMoon)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/1980313 " target="_self" title="물감 - 앨범">물감</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('18038921','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('18038921');" title="물감 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_18038921" title="마이앨범 담기">18038921</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('18038921');" title="물감 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('18038921','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>]

# %%
mnet=[]

for song in song_list: # 실시간 차트에서 노래 정보 가져오기
    
    rank= song.find('span', class_='MMLI_RankNum').get_text().strip('위')
    num= song.find('td', class_='MMLItemUpdown').get_text()
    song_name= song.find('a', class_='MMLI_Song').get_text()
    singer= song.find('a', class_='MMLIInfo_Artist').get_text()
    album= song.find('a', class_='MMLIInfo_Album').get_text()
    
    page3 = song.find('a')['href']
    page3 = urlopen('http://www.mnet.com' + page3)
    soup3 = BeautifulSoup(page3, 'html.parser')
    s_date= soup3.find('dd').find_all('p')[1].find(class_='right').get_text()
    s_date
    
    
    num=num.replace('보합0','0')
    num=num.replace('상승','')
    num=num.replace('하락','')
    if num == '신규진입':
        num=0    
    if int(num) > 100 :
        num = 100
    mnet.append([int(rank), int(num), song_name, singer, album, s_date])
    
    print('순위: ', rank)
    print('등락: ', num)
    print('곡: ', song_name)
    print('가수: ', singer)
    print('앨범: ', album)
    print('발매일: ', s_date)
    print()
    
for song in song_list2: # mnet은 1-50위, 51-100위 페이지가 다르므로 for문을 두 번 돌림.
    
    rank= song.find('span', class_='MMLI_RankNum').get_text().strip('위')
    num= song.find('td', class_='MMLItemUpdown').get_text()
    song_name= song.find('a', class_='MMLI_Song').get_text()
    singer= song.find('a', class_='MMLIInfo_Artist').get_text()
    album= song.find('a', class_='MMLIInfo_Album').get_text()
    
    pg3 = song.find('a')['href']
    pg3 = urlopen('http://www.mnet.com' + pg3)
    soup3 = BeautifulSoup(pg3, 'html.parser')
    s_date= soup3.find('dd').find_all('p')[1].find(class_='right').get_text()
    s_date
    
    num=num.replace('보합0','0')
    num=num.replace('상승','')
    num=num.replace('하락','')
    if num == '신규진입':
        num=0
    if int(num) > 100 :
        num = 100
    mnet.append([int(rank), int(num), song_name, singer, album, s_date])
    
    print('순위: ', rank)
    print('등락: ', num)
    print('곡: ', song_name)
    print('가수: ', singer)
    print('앨범: ', album)
    print('발매일: ', s_date)
    print()
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  1
# 등락:  0
# 곡:  꽃 길
# 가수:  BIGBANG
# 앨범:  꽃 길
# 발매일:  2018.03.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  2
# 등락:  0
# 곡:  별이 빛나는 밤
# 가수:  마마무(Mamamoo)
# 앨범:  Yellow Flower
# 발매일:  2018.03.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  3
# 등락:  1
# 곡:  Look
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  4
# 등락:  1
# 곡:  Jenga (Feat. Gaeko)
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  5
# 등락:  0
# 곡:  내가 더 나빠
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  6
# 등락:  5
# 곡:  사랑을 했다 (LOVE SCENARIO)
# 가수:  iKON
# 앨범:  Return
# 발매일:  2018.01.25
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  7
# 등락:  0
# 곡:  나타나줘 (Feat. 박재범)
# 가수:  로꼬
# 앨범:  나타나줘
# 발매일:  2018.03.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  8
# 등락:  2
# 곡:  You
# 가수:  멜로망스(Melomance)
# 앨범:  투유 프로젝트 - 슈가맨2 Part 2
# 발매일:  2018.01.22
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  9
# 등락:  1
# 곡:  My Blossom
# 가수:  소유(SOYOU)
# 앨범:  My Blossom
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  10
# 등락:  1
# 곡:  괜찮냐고
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  11
# 등락:  1
# 곡:  뿜뿜
# 가수:  모모랜드(MOMOLAND)
# 앨범:  GREAT!
# 발매일:  2018.01.03
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  12
# 등락:  1
# 곡:  약속해요 (I.P.U.)
# 가수:  Wanna One(워너원)
# 앨범:  약속해요 (I.P.U.) - Special Theme Track
# 발매일:  2018.03.05
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  13
# 등락:  4
# 곡:  너 하나만 (Feat. 효린)
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  14
# 등락:  0
# 곡:  애쓰지 마요
# 가수:  박보람
# 앨범:  애쓰지 마요
# 발매일:  2018.02.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  15
# 등락:  5
# 곡:  My Way
# 가수:  이수(엠씨더맥스)
# 앨범:  돈꽃 OST Part 1
# 발매일:  2017.11.11
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  16
# 등락:  0
# 곡:  그때 헤어지면 돼
# 가수:  로이킴
# 앨범:  그때 헤어지면 돼
# 발매일:  2018.02.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  17
# 등락:  10
# 곡:  Roller Coaster
# 가수:  청하
# 앨범:  Offset
# 발매일:  2018.01.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  18
# 등락:  10
# 곡:  HandClap
# 가수:  Fitz & The Tantrums
# 앨범:  Fitz and The Tantrums (Deluxe)
# 발매일:  2017.07.28
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  19
# 등락:  0
# 곡:  잘 살길 바래 (With DAVII)
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  20
# 등락:  31
# 곡:  밤이 되니까
# 가수:  펀치(Punch)
# 앨범:  밤이 되니까
# 발매일:  2017.09.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  21
# 등락:  18
# 곡:  네가 없는 곳
# 가수:  양요섭
# 앨범:  YANG YOSEOP 2ND MINI ALBUM `白`
# 발매일:  2018.02.19
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  22
# 등락:  30
# 곡:  Bad Boy
# 가수:  Red Velvet (레드벨벳)
# 앨범:  The Perfect Red Velvet - The 2nd Album Repackage
# 발매일:  2018.01.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  23
# 등락:  5
# 곡:  후유증
# 가수:  민경훈
# 앨범:  후유증
# 발매일:  2018.02.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  24
# 등락:  25
# 곡:  선물
# 가수:  멜로망스(Melomance)
# 앨범:  Moonlight
# 발매일:  2017.07.10
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  25
# 등락:  4
# 곡:  instagram
# 가수:  DEAN
# 앨범:  instagram
# 발매일:  2017.12.26
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  26
# 등락:  5
# 곡:  MIANHAE
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  27
# 등락:  28
# 곡:  눈사람
# 가수:  정승환
# 앨범:  그리고 봄
# 발매일:  2018.02.19
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  28
# 등락:  5
# 곡:  너 없는 시간들
# 가수:  다비치
# 앨범:  &10
# 발매일:  2018.01.25
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  29
# 등락:  3
# 곡:  비행운
# 가수:  문문(MoonMoon)
# 앨범:  LIFE IS BEAUTY FULL
# 발매일:  2016.11.10
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  30
# 등락:  5
# 곡:  오늘밤도
# 가수:  펀치(Punch)
# 앨범:  오늘밤도
# 발매일:  2018.02.06
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  31
# 등락:  28
# 곡:  all of my life
# 가수:  박원
# 앨범:  0M
# 발매일:  2017.07.27
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  32
# 등락:  16
# 곡:  Thunder
# 가수:  Imagine Dragons
# 앨범:  Evolve
# 발매일:  2018.02.22
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  33
# 등락:  3
# 곡:  봉제선 (Feat. 수란)
# 가수:  다이나믹 듀오(Dynamic Duo)
# 앨범:  봉제선
# 발매일:  2018.02.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  34
# 등락:  1
# 곡:  #첫사랑
# 가수:  볼빨간사춘기
# 앨범:  #첫사랑
# 발매일:  2018.01.10
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  35
# 등락:  36
# 곡:  바람
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  36
# 등락:  21
# 곡:  Havana (Feat. Young Thug)
# 가수:  Camila Cabello
# 앨범:  Camila
# 발매일:  2018.01.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  37
# 등락:  8
# 곡:  별 바람 꽃 태양
# 가수:  마마무(Mamamoo)
# 앨범:  Yellow Flower
# 발매일:  2018.03.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  38
# 등락:  12
# 곡:  There`s Nothing Holdin` Me Back
# 가수:  Shawn Mendes
# 앨범:  Illuminate (New Deluxe Ver.)
# 발매일:  2017.04.21
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  39
# 등락:  11
# 곡:  All Falls Down (Feat. Noah Cyrus, Digit ..
# 가수:  Alan Walker
# 앨범:  All Falls Down
# 발매일:  2017.10.27
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  40
# 등락:  100
# 곡:  비도 오고 그래서 (Feat. 신용재)
# 가수:  헤이즈(Heize)
# 앨범:  /// (너 먹구름 비)
# 발매일:  2017.06.26
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  41
# 등락:  7
# 곡:  Action! (Feat. GRAY)
# 가수:  DPR LIVE
# 앨범:  Action!
# 발매일:  2018.03.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  42
# 등락:  100
# 곡:  이 별
# 가수:  길구봉구
# 앨범:  Star
# 발매일:  2017.09.18
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  43
# 등락:  21
# 곡:  주인공
# 가수:  선미
# 앨범:  주인공
# 발매일:  2018.01.18
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  44
# 등락:  20
# 곡:  BOSS
# 가수:  NCT U
# 앨범:  NCT 2018 EMPATHY
# 발매일:  2018.03.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  45
# 등락:  9
# 곡:  가을 안부
# 가수:  먼데이키즈(Monday Kiz)
# 앨범:  가을 안부
# 발매일:  2017.10.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  46
# 등락:  15
# 곡:  눈 떠보니 이별이더라
# 가수:  포맨
# 앨범:  REMEMBER ME
# 발매일:  2017.10.24
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  47
# 등락:  10
# 곡:  True Love
# 가수:  김성규
# 앨범:  1st Album `10 Stories`
# 발매일:  2018.02.26
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  48
# 등락:  5
# 곡:  Grapevine (포도주) (Feat. 박재범)
# 가수:  Junoflo(주노플로)
# 앨범:  Only Human
# 발매일:  2018.03.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  49
# 등락:  30
# 곡:  이슬을 머금은 나무
# 가수:  XIA
# 앨범:  Tarantallegra
# 발매일:  2012.05.15
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  50
# 등락:  9
# 곡:  봄날
# 가수:  방탄소년단
# 앨범:  YOU NEVER WALK ALONE
# 발매일:  2017.02.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  51
# 등락:  4
# 곡:  Faded
# 가수:  Alan Walker
# 앨범:  Faded
# 발매일:  2016.01.15
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  52
# 등락:  14
# 곡:  LIKEY
# 가수:  TWICE(트와이스)
# 앨범:  twicetagram
# 발매일:  2017.10.30
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  53
# 등락:  9
# 곡:  GO
# 가수:  NCT DREAM
# 앨범:  NCT 2018 EMPATHY
# 발매일:  2018.03.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  54
# 등락:  3
# 곡:  Love Letter (언약)
# 가수:  2Shai
# 앨범:  Love Letter
# 발매일:  2003.09.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  55
# 등락:  100
# 곡:  그날처럼
# 가수:  장덕철
# 앨범:  그날처럼
# 발매일:  2017.11.28
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  56
# 등락:  4
# 곡:  비밀정원
# 가수:  오마이걸(OH MY GIRL)
# 앨범:  비밀정원
# 발매일:  2018.01.09
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  57
# 등락:  22
# 곡:  다른사람을 사랑하고 있어
# 가수:  수지(SUZY)
# 앨범:  Faces of Love
# 발매일:  2018.01.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  58
# 등락:  6
# 곡:  봄타
# 가수:  마마무(Mamamoo)
# 앨범:  Yellow Flower
# 발매일:  2018.03.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  59
# 등락:  17
# 곡:  사랑은 아프다
# 가수:  이승철
# 앨범:  미스티 (JTBC 금토드라마) OST - Part 1
# 발매일:  2018.02.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  60
# 등락:  10
# 곡:  Baby Don’t Stop
# 가수:  NCT U
# 앨범:  NCT 2018 EMPATHY
# 발매일:  2018.03.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  61
# 등락:  15
# 곡:  TOUCH
# 가수:  NCT 127
# 앨범:  NCT 2018 EMPATHY
# 발매일:  2018.03.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  62
# 등락:  9
# 곡:  Heart Shaker
# 가수:  TWICE(트와이스)
# 앨범:  Merry & Happy
# 발매일:  2017.12.11
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  63
# 등락:  27
# 곡:  The Reason
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  64
# 등락:  19
# 곡:  답장
# 가수:  김동률
# 앨범:  답장
# 발매일:  2018.01.11
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  65
# 등락:  28
# 곡:  HOLIDAY (Feat. DPR LIVE)
# 가수:  수지(SUZY)
# 앨범:  Faces of Love
# 발매일:  2018.01.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  66
# 등락:  9
# 곡:  우산 (Feat. 윤하)
# 가수:  에픽하이 (EPIK HIGH)
# 앨범:  Pieces, Part One
# 발매일:  2008.04.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  67
# 등락:  29
# 곡:  망설이다
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  68
# 등락:  32
# 곡:  Rude Boy
# 가수:  마마무(Mamamoo)
# 앨범:  Yellow Flower
# 발매일:  2018.03.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  69
# 등락:  13
# 곡:  기억의 빈자리
# 가수:  나얼
# 앨범:  기억의 빈자리
# 발매일:  2017.11.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  70
# 등락:  26
# 곡:  우리
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  71
# 등락:  31
# 곡:  고마워
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  72
# 등락:  100
# 곡:  덜덜덜
# 가수:  EXID
# 앨범:  Full Moon
# 발매일:  2017.11.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  73
# 등락:  16
# 곡:  벚꽃 엔딩
# 가수:  버스커 버스커
# 앨범:  버스커 버스커
# 발매일:  2012.03.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  74
# 등락:  14
# 곡:  끌림
# 가수:  김성규
# 앨범:  1st Album `10 Stories`
# 발매일:  2018.02.26
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  75
# 등락:  100
# 곡:  너였다면
# 가수:  정승환
# 앨범:  또 오해영 OST Part 5
# 발매일:  2016.05.31
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  76
# 등락:  18
# 곡:  얼굴 찌푸리지 말아요
# 가수:  하이라이트(Highlight)
# 앨범:  CAN YOU FEEL IT?
# 발매일:  2017.03.20
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  77
# 등락:  5
# 곡:  비가와 (Rain)
# 가수:  소유
# 앨범:  비가와
# 발매일:  2017.02.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  78
# 등락:  100
# 곡:  불장난
# 가수:  BLACKPINK
# 앨범:  SQUARE TWO
# 발매일:  2016.11.01
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  79
# 등락:  100
# 곡:  그때의 나, 그때의 우리
# 가수:  어반 자카파(Urban Zakapa)
# 앨범:  그때의 나, 그때의 우리
# 발매일:  2017.11.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  80
# 등락:  100
# 곡:  Something Just Like This
# 가수:  The Chainsmokers
# 앨범:  Memories...Do Not Open
# 발매일:  2017.04.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  81
# 등락:  21
# 곡:  잘가라
# 가수:  홍진영
# 앨범:  잘가라
# 발매일:  2018.02.07
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  82
# 등락:  16
# 곡:  Lost Stars
# 가수:  Adam Levine
# 앨범:  영화 Begin Again OST
# 발매일:  2014.07.14
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  83
# 등락:  5
# 곡:  우리도 그들처럼
# 가수:  XIA(준수)
# 앨범:  우리도 그들처럼
# 발매일:  2017.12.15
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  84
# 등락:  10
# 곡:  어떤 사랑
# 가수:  승관(SEVENTEEN)
# 앨범:  마더 OST Part 5
# 발매일:  2018.03.15
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  85
# 등락:  0
# 곡:  사랑하지 않은 것처럼
# 가수:  버즈
# 앨범:  `Be One` - Buzz The 1st Mini Album
# 발매일:  2017.07.28
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  86
# 등락:  100
# 곡:  REALLY REALLY
# 가수:  WINNER
# 앨범:  FATE NUMBER FOR
# 발매일:  2017.04.04
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  87
# 등락:  100
# 곡:  노력
# 가수:  박원
# 앨범:  1/24
# 발매일:  2016.11.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  88
# 등락:  6
# 곡:  미안해
# 가수:  양다일
# 앨범:  inside
# 발매일:  2017.12.29
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  89
# 등락:  100
# 곡:  널 너무 모르고
# 가수:  헤이즈(Heize)
# 앨범:  /// (너 먹구름 비)
# 발매일:  2017.06.26
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  90
# 등락:  6
# 곡:  안되나용  (Feat. 휘성(Realslow))
# 가수:  김영철
# 앨범:  안되나용...(부재: 화양사거리)
# 발매일:  2018.02.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  91
# 등락:  100
# 곡:  나의 사춘기에게
# 가수:  볼빨간사춘기
# 앨범:  Red Diary Page.1
# 발매일:  2017.09.28
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  92
# 등락:  100
# 곡:  팔레트 (Feat. G-DRAGON)
# 가수:  아이유(IU)
# 앨범:  Palette
# 발매일:  2017.04.21
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  93
# 등락:  100
# 곡:  무제(無題) (Untitled, 2014)
# 가수:  G-DRAGON
# 앨범:  권지용
# 발매일:  2017.06.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  94
# 등락:  8
# 곡:  별
# 가수:  양요섭
# 앨범:  YANG YOSEOP 2ND MINI ALBUM `白`
# 발매일:  2018.02.19
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  95
# 등락:  8
# 곡:  Beautiful
# 가수:  크러쉬(CRUSH)
# 앨범:  도깨비 OST Part 4
# 발매일:  2016.12.17
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  96
# 등락:  1
# 곡:  한숨
# 가수:  이하이
# 앨범:  SEOULITE
# 발매일:  2016.03.09
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  97
# 등락:  34
# 곡:  파랑새
# 가수:  에이프릴(APRIL)
# 앨범:  에이프릴(APRIL) 5th Mini Album `The Blue`
# 발매일:  2018.03.12
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  98
# 등락:  6
# 곡:  IF YOU
# 가수:  BIGBANG
# 앨범:  D
# 발매일:  2015.07.01
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  99
# 등락:  9
# 곡:  Undercover (Feat. 윤미래)
# 가수:  Junoflo(주노플로)
# 앨범:  Only Human
# 발매일:  2018.03.13
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  100
# 등락:  100
# 곡:  물감
# 가수:  문문(MoonMoon)
# 앨범:  물감
# 발매일:  2017.04.24

# %%
import pandas as pd

mnet_df=pd.DataFrame(mnet, columns=['mnet순위','mnet등락','곡','가수','앨범','발매일']) #노래 정보 data_frame 만들기
mnet_df.head()
# Out:
#    mnet순위  mnet등락                    곡            가수             앨범  \
# 0       1       0                  꽃 길       BIGBANG            꽃 길
# 1       2       0             별이 빛나는 밤  마마무(Mamamoo)  Yellow Flower
# 2       3       1                 Look    GOT7 (갓세븐)    Eyes On You
# 3       4       1  Jenga (Feat. Gaeko)    헤이즈(Heize)             바람
# 4       5       0              내가 더 나빠    헤이즈(Heize)             바람
#
#           발매일
# 0  2018.03.13
# 1  2018.03.07
# 2  2018.03.12
# 3  2018.03.08
# 4  2018.03.08

# %%
pg3 = song.find('a')['href'] # 발매일 정보를 가져오기 위해 곡 개별 url 추출
pg3 = urlopen('http://www.mnet.com' + pg3)

soup3 = BeautifulSoup(pg3, 'html.parser')
s_date= soup3.find('dd').find_all('p')[1].find(class_='right').get_text() # 발매일 추출
s_date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_hostport(self, host, port)
#     884                 try:
# --> 885                     port = int(host[i+1:])
#     886                 except ValueError:
#
# ValueError: invalid literal for int() with base 10: "melon.link.goAlbumDetail('10145963');"
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-222-34906a1bf40e> in <module>()
#       1 pg3 = song.find('a')['href'] # 발매일 정보를 가져오기 위해 곡 개별 url 추출
# ----> 2 pg3 = urlopen('http://www.mnet.com' + pg3)
#       3
#       4 soup3 = BeautifulSoup(pg3, 'html.parser')
#       5 s_date= soup3.find('dd').find_all('p')[1].find(class_='right').get_text() # 발매일 추출
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1284
#    1285         # will parse host:port
# -> 1286         h = http_class(host, timeout=req.timeout, **http_conn_args)
#    1287         h.set_debuglevel(self._debuglevel)
#    1288
#
# C:\ProgramData\Anaconda3\lib\http\client.py in __init__(self, host, port, timeout, source_address)
#     847         self._tunnel_headers = {}
#     848
# --> 849         (self.host, self.port) = self._get_hostport(host, port)
#     850
#     851         # This is stored as an instance variable to allow unit
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_hostport(self, host, port)
#     888                         port = self.default_port
#     889                     else:
# --> 890                         raise InvalidURL("nonnumeric port: '%s'" % host[i+1:])
#     891                 host = host[:i]
#     892             else:
#
# InvalidURL: nonnumeric port: 'melon.link.goAlbumDetail('10145963');'

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import seaborn as sns

# %%
import platform #os 정보를 가져 올 수 있는 모듈
from matplotlib import font_manager, rc
# font_manager : 폰트 관리 모듈, rc : 폰트 변경 모듈
from matplotlib import pyplot as plt # 시각화 도구
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False # 유니코드 표현 설정하기

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # OS가 APPLE(Darwin)이면 AppleGothic으로 폰트 설정
elif platform.system() == 'Windows':
    path="c:/Windows/Fonts/malgun.ttf" #OS가 윈도우즈면 맑은 고딕으로 설정
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown System.')

# %%
np.corrcoef(mnet_df['mnet순위'], mnet_df['mnet등락']) # 순위와 등락폭은 관계가 있다.
# Out:
# array([[1.        , 0.44532933],
#        [0.44532933, 1.        ]])

# %%
plt.figure(figsize=(13,8))
plt.plot(mnet_df['mnet순위'], mnet_df['mnet등락'],color='blue',markersize=12)
plt.grid()
plt.legend()
plt.xlabel('rank')
plt.ylabel('num')
plt.show()

# %%
colormap = mnet_df['mnet등락']

plt.figure(figsize=(10,6))
plt.scatter(mnet_df['mnet순위'], mnet_df['mnet등락'], s=50, c=colormap, marker='>')
plt.colorbar()
plt.show()

# %%
page = urlopen('https://www.melon.com/chart/index.htm') # 멜론 실시간 차트 추출
soup = BeautifulSoup(page, 'html.parser')
song_list = soup.find(id='tb_list').tbody.find_all('tr')

# %%
melon = []

for song in song_list: # 실시간 차트 노래 정보 추출
    
    rank = song.find(class_ = 'rank').text
    updown = song.find(class_ = 'rank_wrap').text.split('\n')[2]    
    title = song.find('div', class_='rank01').a.text
    singer = song.find('div', class_='rank02').a.text
    album_name = song.find(class_='rank03').a.text

    song_num = song['data-song-no']
    url = 'https://www.melon.com/song/detail.htm?songId=' + song_num
    song_page = urlopen(url)
    soup = BeautifulSoup(song_page, 'html.parser')
    release_date = soup.find(class_ = 'list').find_all('dd')[1].text

    if updown == "" :
        updown = 0
        
    melon.append([int(rank), abs(int(updown)), title, singer, album_name, release_date])
    
    print('순위 : ', rank)
    print('변동폭 : ', updown)
    print('제목 : ', title)
    print('가수 : ', singer)
    print('앨범명 : ', album_name)
    print('발매일 : ', release_date)
    print()
# Out:
# 순위 :  1
# 변동폭 :  0
# 제목 :  꽃 길
# 가수 :  BIGBANG
# 앨범명 :  꽃 길
# 발매일 :  2018.03.13
#
# 순위 :  2
# 변동폭 :  0
# 제목 :  별이 빛나는 밤
# 가수 :  마마무
# 앨범명 :  Yellow Flower
# 발매일 :  2018.03.07
#
# 순위 :  3
# 변동폭 :  0
# 제목 :  Jenga (Feat. Gaeko)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
# 발매일 :  2018.03.08
#
# 순위 :  4
# 변동폭 :  0
# 제목 :  사랑을 했다 (LOVE SCENARIO)
# 가수 :  iKON
# 앨범명 :  Return
# 발매일 :  2018.01.25
#
# 순위 :  5
# 변동폭 :  0
# 제목 :  뿜뿜
# 가수 :  모모랜드 (MOMOLAND)
# 앨범명 :  GREAT!
# 발매일 :  2018.01.03
#
# 순위 :  6
# 변동폭 :  0
# 제목 :  그날처럼
# 가수 :  장덕철
# 앨범명 :  그날처럼
# 발매일 :  2017.11.28
#
# 순위 :  7
# 변동폭 :  0
# 제목 :  내가 더 나빠
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
# 발매일 :  2018.03.08
#
# 순위 :  8
# 변동폭 :  0
# 제목 :  그때 헤어지면 돼
# 가수 :  로이킴
# 앨범명 :  그때 헤어지면 돼
# 발매일 :  2018.02.12
#
# 순위 :  9
# 변동폭 :  0
# 제목 :  HandClap
# 가수 :  Fitz & The Tantrums
# 앨범명 :  Fitz and The Tantrums (Deluxe)
# 발매일 :  2016.07.28
#
# 순위 :  10
# 변동폭 :  0
# 제목 :  Bad Boy
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  The Perfect Red Velvet - The 2nd Album Repackage
# 발매일 :  2018.01.29
#
# 순위 :  11
# 변동폭 :  0
# 제목 :  Roller Coaster
# 가수 :  청하
# 앨범명 :  Offset
# 발매일 :  2018.01.17
#
# 순위 :  12
# 변동폭 :  1
# 제목 :  선물
# 가수 :  멜로망스
# 앨범명 :  Moonlight
# 발매일 :  2017.07.10
#
# 순위 :  13
# 변동폭 :  1
# 제목 :  Havana (Feat. Young Thug)
# 가수 :  Camila Cabello
# 앨범명 :  Camila
# 발매일 :  2018.01.12
#
# 순위 :  14
# 변동폭 :  2
# 제목 :  나타나줘 (Feat. 박재범)
# 가수 :  로꼬
# 앨범명 :  나타나줘
# 발매일 :  2018.03.14
#
# 순위 :  15
# 변동폭 :  0
# 제목 :  약속해요 (I.P.U.)
# 가수 :  Wanna One (워너원)
# 앨범명 :  약속해요 (I.P.U.) - Special Theme Track
# 발매일 :  2018.03.05
#
# 순위 :  16
# 변동폭 :  0
# 제목 :  괜찮냐고
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
# 발매일 :  2018.03.08
#
# 순위 :  17
# 변동폭 :  0
# 제목 :  비행운
# 가수 :  문문 (MoonMoon)
# 앨범명 :  LIFE IS BEAUTY FULL
# 발매일 :  2016.11.10
#
# 순위 :  18
# 변동폭 :  0
# 제목 :  My Way
# 가수 :  이수 (엠씨 더 맥스)
# 앨범명 :  돈꽃 OST Part.1
# 발매일 :  2017.11.11
#
# 순위 :  19
# 변동폭 :  0
# 제목 :  눈사람
# 가수 :  정승환
# 앨범명 :  그리고 봄
# 발매일 :  2018.02.19
#
# 순위 :  20
# 변동폭 :  2
# 제목 :  instagram
# 가수 :  DEAN
# 앨범명 :  instagram
# 발매일 :  2017.12.26
#
# 순위 :  21
# 변동폭 :  2
# 제목 :  밤이 되니까
# 가수 :  펀치 (Punch)
# 앨범명 :  밤이 되니까
# 발매일 :  2017.09.29
#
# 순위 :  22
# 변동폭 :  1
# 제목 :  Beautiful
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
# 발매일 :  2017.11.13
#
# 순위 :  23
# 변동폭 :  3
# 제목 :  비도 오고 그래서 (Feat. 신용재)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  /// (너 먹구름 비)
# 발매일 :  2017.06.26
#
# 순위 :  24
# 변동폭 :  1
# 제목 :  주인공
# 가수 :  선미
# 앨범명 :  주인공
# 발매일 :  2018.01.18
#
# 순위 :  25
# 변동폭 :  1
# 제목 :  #첫사랑
# 가수 :  볼빨간사춘기
# 앨범명 :  #첫사랑
# 발매일 :  2018.01.10
#
# 순위 :  26
# 변동폭 :  0
# 제목 :  You
# 가수 :  멜로망스
# 앨범명 :  투유 프로젝트 - 슈가맨2 Part.2
# 발매일 :  2018.01.22
#
# 순위 :  27
# 변동폭 :  0
# 제목 :  이 별
# 가수 :  길구봉구
# 앨범명 :  Star
# 발매일 :  2017.09.18
#
# 순위 :  28
# 변동폭 :  0
# 제목 :  가을 안부
# 가수 :  먼데이 키즈
# 앨범명 :  가을 안부
# 발매일 :  2017.10.14
#
# 순위 :  29
# 변동폭 :  0
# 제목 :  에너제틱 (Energetic)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1X1=1(TO BE ONE)
# 발매일 :  2017.08.07
#
# 순위 :  30
# 변동폭 :  2
# 제목 :  그리워하다
# 가수 :  비투비
# 앨범명 :  Brother Act.
# 발매일 :  2017.10.16
#
# 순위 :  31
# 변동폭 :  0
# 제목 :  Heart Shaker
# 가수 :  TWICE (트와이스)
# 앨범명 :  Merry & Happy
# 발매일 :  2017.12.11
#
# 순위 :  32
# 변동폭 :  2
# 제목 :  좋니
# 가수 :  윤종신
# 앨범명 :  LISTEN 010 좋니
# 발매일 :  2017.06.22
#
# 순위 :  33
# 변동폭 :  1
# 제목 :  DNA
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
# 발매일 :  2017.09.18
#
# 순위 :  34
# 변동폭 :  2
# 제목 :  all of my life
# 가수 :  박원
# 앨범명 :  0M
# 발매일 :  2017.07.27
#
# 순위 :  35
# 변동폭 :  2
# 제목 :  눈 떠보니 이별이더라
# 가수 :  포맨
# 앨범명 :  REMEMBER ME
# 발매일 :  2017.10.24
#
# 순위 :  36
# 변동폭 :  1
# 제목 :  Shape of You
# 가수 :  Ed Sheeran
# 앨범명 :  ÷ (Deluxe)
# 발매일 :  2017.03.03
#
# 순위 :  37
# 변동폭 :  0
# 제목 :  밤편지
# 가수 :  아이유
# 앨범명 :  밤편지
# 발매일 :  2017.03.24
#
# 순위 :  38
# 변동폭 :  1
# 제목 :  봄날
# 가수 :  방탄소년단
# 앨범명 :  YOU NEVER WALK ALONE
# 발매일 :  2017.02.13
#
# 순위 :  39
# 변동폭 :  4
# 제목 :  LIKEY
# 가수 :  TWICE (트와이스)
# 앨범명 :  twicetagram
# 발매일 :  2017.10.30
#
# 순위 :  40
# 변동폭 :  2
# 제목 :  시차 (We Are) (Feat. 로꼬 & GRAY)
# 가수 :  우원재
# 앨범명 :  시차 (We Are)
# 발매일 :  2017.09.04
#
# 순위 :  41
# 변동폭 :  1
# 제목 :  기억의 빈자리
# 가수 :  나얼
# 앨범명 :  기억의 빈자리
# 발매일 :  2017.11.29
#
# 순위 :  42
# 변동폭 :  12
# 제목 :  Look
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  43
# 변동폭 :  2
# 제목 :  다른사람을 사랑하고 있어
# 가수 :  수지 (SUZY)
# 앨범명 :  Faces of Love
# 발매일 :  2018.01.29
#
# 순위 :  44
# 변동폭 :  15
# 제목 :  빨간 맛 (Red Flavor)
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  The Red Summer - Summer Mini Album
# 발매일 :  2017.07.09
#
# 순위 :  45
# 변동폭 :  1
# 제목 :  썸 탈꺼야
# 가수 :  볼빨간사춘기
# 앨범명 :  Red Diary Page.1
# 발매일 :  2017.09.28
#
# 순위 :  46
# 변동폭 :  1
# 제목 :  좋아
# 가수 :  민서
# 앨범명 :  2017 월간 윤종신 11월호
# 발매일 :  2017.11.15
#
# 순위 :  47
# 변동폭 :  9
# 제목 :  첫눈처럼 너에게 가겠다
# 가수 :  에일리
# 앨범명 :  도깨비 OST Part.9
# 발매일 :  2017.01.07
#
# 순위 :  48
# 변동폭 :  2
# 제목 :  There`s Nothing Holdin` Me Back
# 가수 :  Shawn Mendes
# 앨범명 :  Illuminate (New Deluxe Ver.)
# 발매일 :  2017.04.21
#
# 순위 :  49
# 변동폭 :  3
# 제목 :  피카부 (Peek-A-Boo)
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  Perfect Velvet - The 2nd Album
# 발매일 :  2017.11.17
#
# 순위 :  50
# 변동폭 :  0
# 제목 :  그때의 나, 그때의 우리
# 가수 :  어반자카파
# 앨범명 :  그때의 나, 그때의 우리
# 발매일 :  2017.11.08
#
# 순위 :  51
# 변동폭 :  9
# 제목 :  바람이 불었으면 좋겠어
# 가수 :  길구봉구
# 앨범명 :  바람이 불었으면 좋겠어
# 발매일 :  2014.01.03
#
# 순위 :  52
# 변동폭 :  1
# 제목 :  짙어져
# 가수 :  멜로망스
# 앨범명 :  Yellow OST Part.2
# 발매일 :  2017.10.15
#
# 순위 :  53
# 변동폭 :  5
# 제목 :  노력
# 가수 :  박원
# 앨범명 :  1/24
# 발매일 :  2016.11.17
#
# 순위 :  54
# 변동폭 :  5
# 제목 :  답장
# 가수 :  김동률
# 앨범명 :  답장
# 발매일 :  2018.01.11
#
# 순위 :  55
# 변동폭 :  7
# 제목 :  갖고 싶어
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
# 발매일 :  2017.11.13
#
# 순위 :  56
# 변동폭 :  7
# 제목 :  가시나
# 가수 :  선미
# 앨범명 :  SUNMI SPECIAL EDITION `가시나`
# 발매일 :  2017.08.22
#
# 순위 :  57
# 변동폭 :  1
# 제목 :  마지막처럼
# 가수 :  BLACKPINK
# 앨범명 :  마지막처럼
# 발매일 :  2017.06.22
#
# 순위 :  58
# 변동폭 :  8
# 제목 :  연애소설 (Feat. 아이유)
# 가수 :  에픽하이 (EPIK HIGH)
# 앨범명 :  WE`VE DONE SOMETHING WONDERFUL
# 발매일 :  2017.10.23
#
# 순위 :  59
# 변동폭 :  6
# 제목 :  바보야
# 가수 :  허각
# 앨범명 :  바보야
# 발매일 :  2017.11.27
#
# 순위 :  60
# 변동폭 :  19
# 제목 :  Lonely (Feat. 태연)
# 가수 :  종현 (JONGHYUN)
# 앨범명 :  종현 소품집 `이야기 Op.2`
# 발매일 :  2017.04.24
#
# 순위 :  61
# 변동폭 :  6
# 제목 :  미안해
# 가수 :  양다일
# 앨범명 :  inside
# 발매일 :  2017.12.29
#
# 순위 :  62
# 변동폭 :  5
# 제목 :  Thunder
# 가수 :  Imagine Dragons
# 앨범명 :  Evolve
# 발매일 :  2018.02.22
#
# 순위 :  63
# 변동폭 :  5
# 제목 :  Universe
# 가수 :  EXO
# 앨범명 :  Universe - 겨울 스페셜 앨범, 2017
# 발매일 :  2017.12.26
#
# 순위 :  64
# 변동폭 :  3
# 제목 :  너 없는 시간들
# 가수 :  다비치
# 앨범명 :  &10
# 발매일 :  2018.01.25
#
# 순위 :  65
# 변동폭 :  10
# 제목 :  REALLY REALLY
# 가수 :  WINNER
# 앨범명 :  FATE NUMBER FOR
# 발매일 :  2017.04.04
#
# 순위 :  66
# 변동폭 :  4
# 제목 :  고맙다
# 가수 :  세븐틴
# 앨범명 :  SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
# 발매일 :  2018.02.05
#
# 순위 :  67
# 변동폭 :  7
# 제목 :  Power
# 가수 :  EXO
# 앨범명 :  The Power of Music - The 4th Album Repackage
# 발매일 :  2017.09.05
#
# 순위 :  68
# 변동폭 :  13
# 제목 :  Ko Ko Bop
# 가수 :  EXO
# 앨범명 :  THE WAR - The 4th Album
# 발매일 :  2017.07.18
#
# 순위 :  69
# 변동폭 :  5
# 제목 :  고민보다 Go
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
# 발매일 :  2017.09.18
#
# 순위 :  70
# 변동폭 :  20
# 제목 :  WHERE YOU AT
# 가수 :  뉴이스트 W
# 앨범명 :  W, HERE
# 발매일 :  2017.10.10
#
# 순위 :  71
# 변동폭 :  6
# 제목 :  별 바람 꽃 태양
# 가수 :  마마무
# 앨범명 :  Yellow Flower
# 발매일 :  2018.03.07
#
# 순위 :  72
# 변동폭 :  8
# 제목 :  애쓰지 마요
# 가수 :  박보람
# 앨범명 :  애쓰지 마요
# 발매일 :  2018.02.13
#
# 순위 :  73
# 변동폭 :  3
# 제목 :  나의 사춘기에게
# 가수 :  볼빨간사춘기
# 앨범명 :  Red Diary Page.1
# 발매일 :  2017.09.28
#
# 순위 :  74
# 변동폭 :  18
# 제목 :  여보세요
# 가수 :  NU`EST
# 앨범명 :  THE SECOND MINI ALBUM `여보세요`
# 발매일 :  2013.02.13
#
# 순위 :  75
# 변동폭 :  11
# 제목 :  Closer (Feat. Halsey)
# 가수 :  The Chainsmokers
# 앨범명 :  Collage EP
# 발매일 :  2016.11.05
#
# 순위 :  76
# 변동폭 :  7
# 제목 :  MIC Drop
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
# 발매일 :  2017.09.18
#
# 순위 :  77
# 변동폭 :  8
# 제목 :  너 하나만 (Feat. 효린)
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  78
# 변동폭 :  0
# 제목 :  오늘밤도
# 가수 :  펀치 (Punch)
# 앨범명 :  오늘밤도
# 발매일 :  2018.02.06
#
# 순위 :  79
# 변동폭 :  11
# 제목 :  Twilight
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
# 발매일 :  2017.11.13
#
# 순위 :  80
# 변동폭 :  9
# 제목 :  잘 살길 바래 (With. DAVII)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
# 발매일 :  2018.03.08
#
# 순위 :  81
# 변동폭 :  2
# 제목 :  네가 없는 곳
# 가수 :  양요섭
# 앨범명 :  YANG YOSEOP 2ND MINI ALBUM `白`
# 발매일 :  2018.02.19
#
# 순위 :  82
# 변동폭 :  9
# 제목 :  활활 (Burn It Up)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1X1=1(TO BE ONE)
# 발매일 :  2017.08.07
#
# 순위 :  83
# 변동폭 :  4
# 제목 :  The Reason
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  84
# 변동폭 :  5
# 제목 :  She`s gone
# 가수 :  정일훈
# 앨범명 :  Big wave
# 발매일 :  2018.03.08
#
# 순위 :  85
# 변동폭 :  8
# 제목 :  MIANHAE
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
# 발매일 :  2018.03.08
#
# 순위 :  86
# 변동폭 :  7
# 제목 :  망설이다
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  87
# 변동폭 :  15
# 제목 :  Nothing Without You (Intro.)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
# 발매일 :  2017.11.13
#
# 순위 :  88
# 변동폭 :  6
# 제목 :  고무줄다리기 (Rubber Band)
# 가수 :  iKON
# 앨범명 :  고무줄다리기 (Rubber Band)
# 발매일 :  2018.03.05
#
# 순위 :  89
# 변동폭 :  9
# 제목 :  To Be One (Outro.)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
# 발매일 :  2017.11.13
#
# 순위 :  90
# 변동폭 :  6
# 제목 :  BOSS
# 가수 :  NCT U
# 앨범명 :  NCT 2018 EMPATHY
# 발매일 :  2018.03.14
#
# 순위 :  91
# 변동폭 :  0
# 제목 :  그 사람을 아나요
# 가수 :  임창정
# 앨범명 :  그 사람을 아나요
# 발매일 :  2017.10.23
# 순위 :  92
# 변동폭 :  11
# 제목 :  실례해도 될까요
# 가수 :  장재인
# 앨범명 :  LISTEN 020 실례해도 될까요
# 발매일 :  2018.03.09
#
# 순위 :  93
# 변동폭 :  3
# 제목 :  비밀정원
# 가수 :  오마이걸
# 앨범명 :  비밀정원
# 발매일 :  2018.01.09
#
# 순위 :  94
# 변동폭 :  6
# 제목 :  Action! (Feat. GRAY)
# 가수 :  DPR LIVE
# 앨범명 :  Action!
# 발매일 :  2018.03.13
#
# 순위 :  95
# 변동폭 :  0
# 제목 :  빛 (Hope)
# 가수 :  H.O.T.
# 앨범명 :  H.O.T 3
# 발매일 :  1998.09.01
#
# 순위 :  96
# 변동폭 :  3
# 제목 :  피 땀 눈물
# 가수 :  방탄소년단
# 앨범명 :  WINGS
# 발매일 :  2016.10.10
#
# 순위 :  97
# 변동폭 :  3
# 제목 :  고마워
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  98
# 변동폭 :  0
# 제목 :  우리
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
# 발매일 :  2018.03.12
#
# 순위 :  99
# 변동폭 :  2
# 제목 :  비
# 가수 :  폴킴
# 앨범명 :  비
# 발매일 :  2016.06.21
#
# 순위 :  100
# 변동폭 :  5
# 제목 :  비가 온다
# 가수 :  정승환
# 앨범명 :  그리고 봄
# 발매일 :  2018.02.19

# %%
melon_df = pd.DataFrame(melon, columns=['melon순위', 'melon변동폭', '곡', 'melon가수', 'melon앨범명', 'melon발매일'])
#멜론 노래 목록 데이터프레임 만들기

# %%
song = song_list[2]
song_num =song['data-song-no']
url = 'https://www.melon.com/song/detail.htm?songId=' + song_num # 발매일 정보를 얻기 위한 개별 곡 url 추출
song_page = urlopen(url)
soup = BeautifulSoup(song_page, 'html.parser')

# %%
np.corrcoef(melon_df['melon순위'],melon_df['melon변동폭'])  # 순위와 등락폭은 관계가 있다.
# Out:
# array([[1.        , 0.50555935],
#        [0.50555935, 1.        ]])

# %%
plt.figure(figsize=(13, 8))
plt.plot(melon_df['melon순위'],melon_df['melon변동폭'],color='red', markersize=12) #마커 꾸며주기 추가
plt.grid()
plt.legend()
plt.xlabel('rank') #x축 라벨 붙이기
plt.ylabel('updown') #y축 라벨 붙이기
plt.show()

# %%
colormap = melon_df['melon변동폭']

plt.figure(figsize=(10,6))
plt.scatter(melon_df['melon순위'], melon_df['melon변동폭'], s=50, c=colormap, marker='>')
plt.colorbar()
plt.show()

# %%
page = urlopen('https://music.bugs.co.kr/chart') # 벅스 실시간 차트 추출
soup = BeautifulSoup(page, 'html.parser')
all_song = soup.find(class_ = 'list trackList byChart').tbody.find_all('tr')

# %%
import re

bugs=[]

for song in all_song: # 실시간 차트에서 노래 정보 가져오기
    rank = int(song.find('strong').get_text())
    updown = song.find('p', class_='change').get_text()
    title = song.find('th', scope='row').get_text().strip()
    singer = ' '.join(list(set(re.split('\r\n|\n',song.find('p', class_='artist').get_text().strip())))).strip()
    album = song.find('a', class_='album').get_text()
    
    if '없음' in updown:
        updown = updown.replace("변동없음","")
    elif '상승'in updown:
        updown = updown.replace("계단 상승", "")
    elif '하락' in updown:
        updown = updown.replace("계단 하락", "")
    else:
        updown = 0
       
    
    #앨범 발매일
    album_page = song.find('a')['href']
    page_open= urlopen(album_page)
    album_pg = BeautifulSoup(page_open, 'html.parser')
    r_date = album_pg.find('tbody').find('time').text
    
    bugs.append([rank, int(updown), title, singer, album, r_date])
        
    print('순위 :', rank)
    print('등락 :', updown)
    print('곡 :', title)
    print('가수 :', singer)
    print('앨범 :', album)
    print('발매일 :', r_date)
    print()
# Out:
# 순위 : 1
# 등락 : 0
# 곡 : 꽃 길
# 가수 : BIGBANG
# 앨범 : 꽃 길
# 발매일 : 2018.03.13
#
# 순위 : 2
# 등락 : 0
# 곡 : 나타나줘 (Feat. 박재범)
# 가수 : 로꼬
# 앨범 : 나타나줘
# 발매일 : 2018.03.14
#
# 순위 : 3
# 등락 : 0
# 곡 : 별이 빛나는 밤
# 가수 : 마마무(Mamamoo)
# 앨범 : Yellow Flower
# 발매일 : 2018.03.07
#
# 순위 : 4
# 등락 : 0
# 곡 : Jenga (Feat. Gaeko)
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 5
# 등락 : 0
# 곡 : My Blossom
# 가수 : 소유 (SOYOU)
# 앨범 : My Blossom
# 발매일 : 2018.03.12
#
# 순위 : 6
# 등락 : 0
# 곡 : You
# 가수 : 멜로망스(MeloMance)
# 앨범 : 투유 프로젝트 - 슈가맨2 Part.2
# 발매일 : 2018.01.22
#
# 순위 : 7
# 등락 : 0
# 곡 : 내가 더 나빠
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 8
# 등락 :  1
# 곡 : 그때 헤어지면 돼
# 가수 : 로이킴
# 앨범 : 그때 헤어지면 돼
# 발매일 : 2018.02.12
#
# 순위 : 9
# 등락 :  1
# 곡 : 사랑을 했다 (LOVE SCENARIO)
# 가수 : iKON
# 앨범 : Return
# 발매일 : 2018.01.25
#
# 순위 : 10
# 등락 : 0
# 곡 : 그날처럼
# 가수 : 장덕철
# 앨범 : 그날처럼
# 발매일 : 2017.11.28
#
# 순위 : 11
# 등락 :  1
# 곡 : 뿜뿜
# 가수 : 모모랜드(MOMOLAND)
# 앨범 : GREAT!
# 발매일 : 2018.01.03
#
# 순위 : 12
# 등락 :  1
# 곡 : 괜찮냐고
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 13
# 등락 : 0
# 곡 : BOSS
# 가수 : NCT U
# 앨범 : NCT 2018 EMPATHY
# 발매일 : 2018.03.14
#
# 순위 : 14
# 등락 : 0
# 곡 : 눈사람
# 가수 : 정승환
# 앨범 : 그리고 봄
# 발매일 : 2018.02.19
#
# 순위 : 15
# 등락 : 0
# 곡 : Bad Boy
# 가수 : Red Velvet (레드벨벳)
# 앨범 : The Perfect Red Velvet - The 2nd Album Repackage
# 발매일 : 2018.01.29
#
# 순위 : 16
# 등락 : 0
# 곡 : Roller Coaster
# 가수 : 청하
# 앨범 : Offset
# 발매일 : 2018.01.17
#
# 순위 : 17
# 등락 :  3
# 곡 : Handclap
# 가수 : Fitz & The Tantrums
# 앨범 : Fitz and The Tantrums [Deluxe]
# 발매일 : 2017.07.28
#
# 순위 : 18
# 등락 : 0
# 곡 : instagram
# 가수 : DEAN(딘)
# 앨범 : instagram
# 발매일 : 2017.12.26
#
# 순위 : 19
# 등락 :  2
# 곡 : 선물
# 가수 : 멜로망스(MeloMance)
# 앨범 : Moonlight
# 발매일 : 2017.07.10
#
# 순위 : 20
# 등락 :  3
# 곡 : 별 바람 꽃 태양
# 가수 : 마마무(Mamamoo)
# 앨범 : Yellow Flower
# 발매일 : 2018.03.07
#
# 순위 : 21
# 등락 :  1
# 곡 : 잘 살길 바래 (With. DAVII)
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 22
# 등락 :  1
# 곡 : Havana (feat. Young Thug)
# 가수 : Camila Cabello(카밀라 카베요)
# 앨범 : Camila
# 발매일 : 2018.01.12
#
# 순위 : 23
# 등락 :  4
# 곡 : My Way
# 가수 : 이수
# 앨범 : 돈꽃 (MBC 토요드라마) OST - Part.1
# 발매일 : 2017.11.11
#
# 순위 : 24
# 등락 :  4
# 곡 : 밤편지
# 가수 : 아이유(IU)
# 앨범 : 밤편지
# 발매일 : 2017.03.24
#
# 순위 : 25
# 등락 :  6
# 곡 : 비
# 가수 : 폴킴(Paul Kim)
# 앨범 : 비
# 발매일 : 2016.06.21
#
# 순위 : 26
# 등락 :  1
# 곡 : 비가 온다
# 가수 : 정승환
# 앨범 : 그리고 봄
# 발매일 : 2018.02.19
#
# 순위 : 27
# 등락 :  2
# 곡 : TOUCH
# 가수 : NCT 127
# 앨범 : NCT 2018 EMPATHY
# 발매일 : 2018.03.14
#
# 순위 : 28
# 등락 :  4
# 곡 : MIANHAE
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 29
# 등락 :  3
# 곡 : 비도 오고 그래서 (Feat. 신용재)
# 가수 : 헤이즈(HEIZE)
# 앨범 : /// (너 먹구름 비)
# 발매일 : 2017.06.26
#
# 순위 : 30
# 등락 :  11
# 곡 : 좋니
# 가수 : 윤종신
# 앨범 : LISTEN 010 좋니
# 발매일 : 2017.06.22
#
# 순위 : 31
# 등락 :  7
# 곡 : 약속해요 (I.P.U.)
# 가수 : Wanna One(워너원)
# 앨범 : 약속해요 (I.P.U.) - Special Theme Track
# 발매일 : 2018.03.05
#
# 순위 : 32
# 등락 :  2
# 곡 : #첫사랑
# 가수 : 볼빨간사춘기
# 앨범 : #첫사랑
# 발매일 : 2018.01.10
#
# 순위 : 33
# 등락 :  13
# 곡 : all of my life
# 가수 : 박원
# 앨범 : 0M
# 발매일 : 2017.07.27
#
# 순위 : 34
# 등락 :  48
# 곡 : 너였다면
# 가수 : 정승환
# 앨범 : 또 오해영 (tvN 월화드라마) OST - Part.5
# 발매일 : 2016.05.31
#
# 순위 : 35
# 등락 : 0
# 곡 : 이 별
# 가수 : 길구봉구
# 앨범 : Star
# 발매일 : 2017.09.18
#
# 순위 : 36
# 등락 :  21
# 곡 : 눈 떠보니 이별이더라
# 가수 : 포맨
# 앨범 : REMEMBER ME
# 발매일 : 2017.10.24
#
# 순위 : 37
# 등락 :  1
# 곡 : 너 없는 시간들
# 가수 : 다비치
# 앨범 : &10
# 발매일 : 2018.01.25
#
# 순위 : 38
# 등락 :  5
# 곡 : 미안해
# 가수 : 양다일
# 앨범 : inside
# 발매일 : 2017.12.29
#
# 순위 : 39
# 등락 :  8
# 곡 : 밤이 되니까
# 가수 : 펀치 (Punch)
# 앨범 : 밤이 되니까
# 발매일 : 2017.09.29
#
# 순위 : 40
# 등락 :  5
# 곡 : 가을 안부
# 가수 : 먼데이 키즈(Monday Kiz)
# 앨범 : 가을 안부
# 발매일 : 2017.10.14
#
# 순위 : 41
# 등락 :  2
# 곡 : 비행운
# 가수 : 문문(MoonMoon)
# 앨범 : LIFE IS BEAUTY FULL
# 발매일 : 2016.11.10
#
# 순위 : 42
# 등락 :  7
# 곡 : 기억의 빈자리
# 가수 : 나얼(Na-Ul)
# 앨범 : 기억의 빈자리
# 발매일 : 2017.11.29
#
# 순위 : 43
# 등락 :  25
# 곡 : 비밀정원
# 가수 : 오마이걸(OH MY GIRL)
# 앨범 : 비밀정원
# 발매일 : 2018.01.09
#
# 순위 : 44
# 등락 :  4
# 곡 : 노력
# 가수 : 박원
# 앨범 : 1/24
# 발매일 : 2016.11.17
#
# 순위 : 45
# 등락 :  19
# 곡 : Shape Of You
# 가수 : Ed Sheeran(에드 시런)
# 앨범 : ÷ [Deluxe]
# 발매일 : 2017.03.03
#
# 순위 : 46
# 등락 :  15
# 곡 : 첫눈처럼 너에게 가겠다
# 가수 : 에일리(Ailee)
# 앨범 : 도깨비 (tvN 금토드라마) OST - Part.9
# 발매일 : 2017.01.07
#
# 순위 : 47
# 등락 :  9
# 곡 : 봉제선 (Feat. 수란)
# 가수 : 다이나믹 듀오(Dynamic Duo)
# 앨범 : 봉제선
# 발매일 : 2018.02.07
#
# 순위 : 48
# 등락 :  12
# 곡 : 짙어져
# 가수 : 멜로망스(MeloMance)
# 앨범 : 옐로우 (Yellow - 웹드라마) OST - Part.2
# 발매일 : 2017.10.15
#
# 순위 : 49
# 등락 :  6
# 곡 : 답장
# 가수 : 김동률
# 앨범 : 답장
# 발매일 : 2018.01.11
#
# 순위 : 50
# 등락 :  9
# 곡 : 좋아
# 가수 : 민서
# 앨범 : 2017 월간 윤종신 11월호
# 발매일 : 2017.11.15
#
# 순위 : 51
# 등락 :  20
# 곡 : 빛 (Hope)
# 가수 : H.O.T.
# 앨범 : Resurrection
# 발매일 : 1998.09
#
# 순위 : 52
# 등락 :  1
# 곡 : GO
# 가수 : NCT DREAM
# 앨범 : NCT 2018 EMPATHY
# 발매일 : 2018.03.14
#
# 순위 : 53
# 등락 :  17
# 곡 : 그리워하다
# 가수 : 비투비(BTOB)
# 앨범 : Brother Act.
# 발매일 : 2017.10.16
#
# 순위 : 54
# 등락 :  30
# 곡 : 후유증
# 가수 : 민경훈
# 앨범 : 후유증
# 발매일 : 2018.02.17
#
# 순위 : 55
# 등락 :  11
# 곡 : DNA
# 가수 : 방탄소년단
# 앨범 : LOVE YOURSELF 承 'Her'
# 발매일 : 2017.09.18
#
# 순위 : 56
# 등락 :  27
# 곡 : 주인공
# 가수 : 선미
# 앨범 : 주인공
# 발매일 : 2018.01.18
#
# 순위 : 57
# 등락 :  16
# 곡 : Thunder
# 가수 : Imagine Dragons(이매진 드래곤스)
# 앨범 : Evolve
# 발매일 : 2018.02.22
#
# 순위 : 58
# 등락 :  20
# 곡 : What Lovers Do (feat. SZA)
# 가수 : Maroon 5(마룬 파이브)
# 앨범 : Red Pill Blues [Deluxe Edition]
# 발매일 : 2017.11.03
#
# 순위 : 59
# 등락 :  26
# 곡 : 좋았을걸
# 가수 : 헤이즈(HEIZE)
# 앨범 : 슬기로운 감빵생활 (tvN 수목드라마) OST - Part.5
# 발매일 : 2017.12.14
#
# 순위 : 60
# 등락 :  6
# 곡 : REALLY REALLY
# 가수 : WINNER
# 앨범 : FATE NUMBER FOR
# 발매일 : 2017.04.04
#
# 순위 : 61
# 등락 :  10
# 곡 : 다른사람을 사랑하고 있어
# 가수 : 수지(SUZY)
# 앨범 : Faces of Love
# 발매일 : 2018.01.29
#
# 순위 : 62
# 등락 :  13
# 곡 : Closer (feat. Halsey)
# 가수 : The Chainsmokers(체인스모커스)
# 앨범 : Collage
# 발매일 : 2016.11.05
#
# 순위 : 63
# 등락 :  9
# 곡 : 바보야
# 가수 : 허각
# 앨범 : 바보야
# 발매일 : 2017.11.27
#
# 순위 : 64
# 등락 :  6
# 곡 : All The Stars (영화 '블랙 팬서' OST)
# 가수 : Kendrick Lamar(켄드릭 라마)
# 앨범 : 블랙 팬서 더 앨범 (Black Panther The Album Music From And Inspired By)
# 발매일 : 2018.02.09
#
# 순위 : 65
# 등락 :  14
# 곡 : 폰서트
# 가수 : 10cm(십센치)
# 앨범 : 4.0
# 발매일 : 2017.09.01
#
# 순위 : 66
# 등락 :  14
# 곡 : 마지막처럼
# 가수 : BLACKPINK
# 앨범 : 마지막처럼
# 발매일 : 2017.06.22
#
# 순위 : 67
# 등락 :  12
# 곡 : Look
# 가수 : GOT7 (갓세븐)
# 앨범 : Eyes On You
# 발매일 : 2018.03.12
#
# 순위 : 68
# 등락 :  28
# 곡 : 봄날
# 가수 : 방탄소년단
# 앨범 : YOU NEVER WALK ALONE
# 발매일 : 2017.02.13
#
# 순위 : 69
# 등락 :  17
# 곡 : 썸 탈꺼야
# 가수 : 볼빨간사춘기
# 앨범 : Red Diary Page.1
# 발매일 : 2017.09.28
#
# 순위 : 70
# 등락 :  8
# 곡 : 팔레트 (Feat. G-DRAGON)
# 가수 : 아이유(IU)
# 앨범 : Palette
# 발매일 : 2017.04.21
#
# 순위 : 71
# 등락 :  6
# 곡 : 다시 쓰고 싶어
# 가수 : 에일리(Ailee)
# 앨범 : 이런 꽃 같은 엔딩 (웹드라마) OST - Part.3
# 발매일 : 2018.02.09
#
# 순위 : 72
# 등락 :  17
# 곡 : 나의 사춘기에게
# 가수 : 볼빨간사춘기
# 앨범 : Red Diary Page.1
# 발매일 : 2017.09.28
#
# 순위 : 73
# 등락 :  23
# 곡 : Baby Don't Stop
# 가수 : NCT U
# 앨범 : NCT 2018 EMPATHY
# 발매일 : 2018.03.14
#
# 순위 : 74
# 등락 :  25
# 곡 : Lonely (Feat. 태연)
# 가수 : 종현 (JONGHYUN)
# 앨범 : 종현 소품집 '이야기 Op.2'
# 발매일 : 2017.04.24
#
# 순위 : 75
# 등락 :  20
# 곡 : 결혼
# 가수 : 문문(MoonMoon)
# 앨범 : 이번 생은 처음이라 (tvN 월화드라마) OST - Part.4
# 발매일 : 2017.10.24
#
# 순위 : 76
# 등락 :  20
# 곡 : 애쓰지 마요
# 가수 : 박보람
# 앨범 : 애쓰지 마요
# 발매일 : 2018.02.13
#
# 순위 : 77
# 등락 :  10
# 곡 : 시차 (We Are) (Feat. 로꼬 & GRAY)
# 가수 : 우원재
# 앨범 : 시차 (We Are)
# 발매일 : 2017.09.04
#
# 순위 : 78
# 등락 :  4
# 곡 : 벚꽃 엔딩
# 가수 : 버스커 버스커(Busker Busker)
# 앨범 : 버스커 버스커 1집
# 발매일 : 2012.03.29
#
# 순위 : 79
# 등락 :  16
# 곡 : 피카부 (Peek-A-Boo)
# 가수 : Red Velvet (레드벨벳)
# 앨범 : Perfect Velvet - The 2nd Album
# 발매일 : 2017.11.17
#
# 순위 : 80
# 등락 :  38
# 곡 : LIKEY
# 가수 : TWICE (트와이스)
# 앨범 : twicetagram
# 발매일 : 2017.10.30
#
# 순위 : 81
# 등락 :  47
# 곡 : Heart Shaker
# 가수 : TWICE (트와이스)
# 앨범 : Merry & Happy
# 발매일 : 2017.12.11
#
# 순위 : 82
# 등락 :  9
# 곡 : 한숨
# 가수 : 이하이
# 앨범 : SEOULITE
# 발매일 : 2016.03.09
#
# 순위 : 83
# 등락 :  10
# 곡 : 고민보다 Go
# 가수 : 방탄소년단
# 앨범 : LOVE YOURSELF 承 'Her'
# 발매일 : 2017.09.18
#
# 순위 : 84
# 등락 :  8
# 곡 : 그때의 나, 그때의 우리
# 가수 : 어반 자카파(Urban Zakapa)
# 앨범 : 그때의 나, 그때의 우리
# 발매일 : 2017.11.08
#
# 순위 : 85
# 등락 :  9
# 곡 : 연애소설 (Feat. 아이유)
# 가수 : 에픽하이 (EPIK HIGH)
# 앨범 : WE'VE DONE SOMETHING WONDERFUL
# 발매일 : 2017.10.23
#
# 순위 : 86
# 등락 :  5
# 곡 : 고무줄다리기 (Rubber Band)
# 가수 : iKON
# 앨범 : 고무줄다리기 (Rubber Band)
# 발매일 : 2018.03.05
#
# 순위 : 87
# 등락 :  22
# 곡 : 오늘밤도
# 가수 : 펀치 (Punch)
# 앨범 : 오늘밤도
# 발매일 : 2018.02.06
#
# 순위 : 88
# 등락 :  1
# 곡 : Action! (feat. GRAY)
# 가수 : DPR LIVE
# 앨범 : Action!
# 발매일 : 2018.03.13
#
# 순위 : 89
# 등락 :  35
# 곡 : There's Nothing Holdin' Me Back
# 가수 : Shawn Mendes(션 멘데스)
# 앨범 : Illuminate [New Deluxe Ver.]
# 발매일 : 2017.04.21
#
# 순위 : 90
# 등락 :  7
# 곡 : Perhaps Love (사랑인가요) (Prod.By 박근태)
# 가수 : 에릭남(Eric Nam)
# 앨범 : Your BGM Vol.1
# 발매일 : 2017.09.29
#
# 순위 : 91
# 등락 :  54
# 곡 : 빨간 맛 (Red Flavor)
# 가수 : Red Velvet (레드벨벳)
# 앨범 : The Red Summer - Summer Mini Album
# 발매일 : 2017.07.09
#
# 순위 : 92
# 등락 :  9
# 곡 : FRIENDS
# 가수 : Marshmello(마시멜로)
# 앨범 : FRIENDS
# 발매일 : 2018.02.09
#
# 순위 : 93
# 등락 :  5
# 곡 : Beautiful
# 가수 : Wanna One(워너원)
# 앨범 : 1-1=0 (NOTHING WITHOUT YOU)
# 발매일 : 2017.11.13
#
# 순위 : 94
# 등락 :  4
# 곡 : 이별 뒷면
# 가수 : 권진아
# 앨범 : 이런 꽃 같은 엔딩 (웹드라마) OST - Part.2
# 발매일 : 2018.02.02
#
# 순위 : 95
# 등락 :  26
# 곡 : YESTODAY
# 가수 : NCT U
# 앨범 : NCT 2018 EMPATHY
# 발매일 : 2018.03.14
#
# 순위 : 96
# 등락 :  2
# 곡 : True Love
# 가수 : 김성규
# 앨범 : 1st Album '10 Stories'
# 발매일 : 2018.02.26
#
# 순위 : 97
# 등락 :  17
# 곡 : 꿈꾸는 마음으로
# 가수 : 우주소녀
# 앨범 : Dream Your Dream
# 발매일 : 2018.02.27
#
# 순위 : 98
# 등락 :  10
# 곡 : Candy (캔디)
# 가수 : H.O.T.
# 앨범 : We Hate All Kinds Of Violence
# 발매일 : 1996.09
# 순위 : 99
# 등락 :  5
# 곡 : Blue
# 가수 : 볼빨간사춘기
# 앨범 : Red Diary Page.1
# 발매일 : 2017.09.28
#
# 순위 : 100
# 등락 :  1
# 곡 : HOLIDAY (Feat. DPR LIVE)
# 가수 : 수지(SUZY)
# 앨범 : Faces of Love
# 발매일 : 2018.01.29

# %%
bugs_df = pd.DataFrame(bugs, columns=['bugs순위','bugs등락','곡','bugs가수','bugs앨범','bugs발매일'])
# 벅스 실시간 차트 정보를 담는 데이터 프레임 만들기

# %%
np.corrcoef(bugs_df['bugs순위'], bugs_df['bugs등락']) # 순위와 등락폭은 관계가 있다.
# Out:
# array([[1.        , 0.46036567],
#        [0.46036567, 1.        ]])

# %%
plt.figure(figsize=(13,8))
plt.plot(bugs_df['bugs순위'], bugs_df['bugs등락'], color='purple', markersize=12)
plt.grid()
plt.legend(loc='best')
plt.xlabel('순위')
plt.ylabel('등락')
plt.show()

# %%
colormap = bugs_df['bugs등락']

plt.figure(figsize=(10,6))
plt.scatter(bugs_df['bugs순위'], bugs_df['bugs등락'], s=50, c=colormap, marker='>')
plt.colorbar()
plt.show()

# %%
result_df = pd.merge(mnet_df, melon_df, on='곡') # 엠넷-멜론의 차트 정보를 곡명을 기준으로 합친다.
result_df
# Out:
#     mnet순위  mnet등락                                곡                    가수  \
# 0        1       0                              꽃 길               BIGBANG
# 1        2       0                         별이 빛나는 밤          마마무(Mamamoo)
# 2        3       1                             Look            GOT7 (갓세븐)
# 3        4       1              Jenga (Feat. Gaeko)            헤이즈(Heize)
# 4        5       0                          내가 더 나빠            헤이즈(Heize)
# 5        6       5           사랑을 했다 (LOVE SCENARIO)                  iKON
# 6        7       0                 나타나줘 (Feat. 박재범)                    로꼬
# 7        8       2                              You       멜로망스(Melomance)
# 8       11       1                               뿜뿜        모모랜드(MOMOLAND)
# 9       12       1                    약속해요 (I.P.U.)        Wanna One(워너원)
# 10      13       4                 너 하나만 (Feat. 효린)            GOT7 (갓세븐)
# 11      14       0                           애쓰지 마요                   박보람
# 12      15       5                           My Way            이수(엠씨더맥스)
# 13      16       0                        그때 헤어지면 돼                   로이킴
# 14      17      10                   Roller Coaster                    청하
# 15      18      10                         HandClap   Fitz & The Tantrums
# 16      20      31                           밤이 되니까             펀치(Punch)
# 17      21      18                          네가 없는 곳                   양요섭
# 18      22      30                          Bad Boy     Red Velvet (레드벨벳)
# 19      24      25                               선물       멜로망스(Melomance)
# 20      25       4                        instagram                  DEAN
# 21      26       5                          MIANHAE            헤이즈(Heize)
# 22      27      28                              눈사람                   정승환
# 23      28       5                         너 없는 시간들                   다비치
# 24      29       3                              비행운          문문(MoonMoon)
# 25      30       5                             오늘밤도             펀치(Punch)
# 26      31      28                   all of my life                    박원
# 27      32      16                          Thunder       Imagine Dragons
# 28      34       1                             #첫사랑                볼빨간사춘기
# 29      36      21        Havana (Feat. Young Thug)        Camila Cabello
# 30      37       8                        별 바람 꽃 태양          마마무(Mamamoo)
# 31      38      12  There`s Nothing Holdin` Me Back          Shawn Mendes
# 32      40     100            비도 오고 그래서 (Feat. 신용재)            헤이즈(Heize)
# 33      41       7             Action! (Feat. GRAY)              DPR LIVE
# 34      42     100                              이 별                  길구봉구
# 35      43      21                              주인공                    선미
# 36      44      20                             BOSS                 NCT U
# 37      45       9                            가을 안부     먼데이키즈(Monday Kiz)
# 38      46      15                      눈 떠보니 이별이더라                    포맨
# 39      50       9                               봄날                 방탄소년단
# 40      52      14                            LIKEY           TWICE(트와이스)
# 41      55     100                             그날처럼                   장덕철
# 42      56       4                             비밀정원      오마이걸(OH MY GIRL)
# 43      57      22                    다른사람을 사랑하고 있어              수지(SUZY)
# 44      62       9                     Heart Shaker           TWICE(트와이스)
# 45      63      27                       The Reason            GOT7 (갓세븐)
# 46      64      19                               답장                   김동률
# 47      67      29                             망설이다            GOT7 (갓세븐)
# 48      69      13                          기억의 빈자리                    나얼
# 49      70      26                               우리            GOT7 (갓세븐)
# 50      71      31                              고마워            GOT7 (갓세븐)
# 51      79     100                    그때의 나, 그때의 우리  어반 자카파(Urban Zakapa)
# 52      86     100                    REALLY REALLY                WINNER
# 53      87     100                               노력                    박원
# 54      88       6                              미안해                   양다일
# 55      91     100                         나의 사춘기에게                볼빨간사춘기
# 56      95       8                        Beautiful            크러쉬(CRUSH)
#
#                                                   앨범         발매일  melon순위  \
# 0                                                꽃 길  2018.03.13        1
# 1                                      Yellow Flower  2018.03.07        2
# 2                                        Eyes On You  2018.03.12       42
# 3                                                 바람  2018.03.08        3
# 4                                                 바람  2018.03.08        7
# 5                                             Return  2018.01.25        4
# 6                                               나타나줘  2018.03.14       14
# 7                              투유 프로젝트 - 슈가맨2 Part 2  2018.01.22       26
# 8                                             GREAT!  2018.01.03        5
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05       15
# 10                                       Eyes On You  2018.03.12       77
# 11                                            애쓰지 마요  2018.02.13       72
# 12                                     돈꽃 OST Part 1  2017.11.11       18
# 13                                         그때 헤어지면 돼  2018.02.12        8
# 14                                            Offset  2018.01.17       11
# 15                    Fitz and The Tantrums (Deluxe)  2017.07.28        9
# 16                                            밤이 되니까  2017.09.29       21
# 17                    YANG YOSEOP 2ND MINI ALBUM `白`  2018.02.19       81
# 18  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29       10
# 19                                         Moonlight  2017.07.10       12
# 20                                         instagram  2017.12.26       20
# 21                                                바람  2018.03.08       85
# 22                                             그리고 봄  2018.02.19       19
# 23                                           &10      2018.01.25       64
# 24                               LIFE IS BEAUTY FULL  2016.11.10       17
# 25                                              오늘밤도  2018.02.06       78
# 26                                                0M  2017.07.27       34
# 27                                            Evolve  2018.02.22       62
# 28                                              #첫사랑  2018.01.10       25
# 29                                            Camila  2018.01.12       13
# 30                                     Yellow Flower  2018.03.07       71
# 31                      Illuminate (New Deluxe Ver.)  2017.04.21       48
# 32                                     /// (너 먹구름 비)  2017.06.26       23
# 33                                           Action!  2018.03.13       94
# 34                                              Star  2017.09.18       27
# 35                                               주인공  2018.01.18       24
# 36                                  NCT 2018 EMPATHY  2018.03.14       90
# 37                                             가을 안부  2017.10.14       28
# 38                                       REMEMBER ME  2017.10.24       35
# 39                              YOU NEVER WALK ALONE  2017.02.13       38
# 40                                       twicetagram  2017.10.30       39
# 41                                              그날처럼  2017.11.28        6
# 42                                              비밀정원  2018.01.09       93
# 43                                     Faces of Love  2018.01.29       43
# 44                                     Merry & Happy  2017.12.11       31
# 45                                       Eyes On You  2018.03.12       83
# 46                                                답장  2018.01.11       54
# 47                                       Eyes On You  2018.03.12       86
# 48                                           기억의 빈자리  2017.11.29       41
# 49                                       Eyes On You  2018.03.12       98
# 50                                       Eyes On You  2018.03.12       97
# 51                                     그때의 나, 그때의 우리  2017.11.08       50
# 52                                   FATE NUMBER FOR  2017.04.04       65
# 53                                              1/24  2016.11.17       53
# 54                                            inside  2017.12.29       61
# 55                                  Red Diary Page.1  2017.09.28       73
# 56                                    도깨비 OST Part 4  2016.12.17       22
#
#     melon변동폭              melon가수  \
# 0          0              BIGBANG
# 1          0                  마마무
# 2         12           GOT7 (갓세븐)
# 3          0          헤이즈 (Heize)
# 4          0          헤이즈 (Heize)
# 5          0                 iKON
# 6          2                   로꼬
# 7          0                 멜로망스
# 8          0      모모랜드 (MOMOLAND)
# 9          0      Wanna One (워너원)
# 10         8           GOT7 (갓세븐)
# 11         8                  박보람
# 12         0         이수 (엠씨 더 맥스)
# 13         0                  로이킴
# 14         0                   청하
# 15         0  Fitz & The Tantrums
# 16         2           펀치 (Punch)
# 17         2                  양요섭
# 18         0    Red Velvet (레드벨벳)
# 19         1                 멜로망스
# 20         2                 DEAN
# 21         8          헤이즈 (Heize)
# 22         0                  정승환
# 23         3                  다비치
# 24         0        문문 (MoonMoon)
# 25         0           펀치 (Punch)
# 26         2                   박원
# 27         5      Imagine Dragons
# 28         1               볼빨간사춘기
# 29         1       Camila Cabello
# 30         6                  마마무
# 31         2         Shawn Mendes
# 32         3          헤이즈 (Heize)
# 33         6             DPR LIVE
# 34         0                 길구봉구
# 35         1                   선미
# 36         6                NCT U
# 37         0               먼데이 키즈
# 38         2                   포맨
# 39         1                방탄소년단
# 40         4         TWICE (트와이스)
# 41         0                  장덕철
# 42         3                 오마이걸
# 43         2            수지 (SUZY)
# 44         0         TWICE (트와이스)
# 45         4           GOT7 (갓세븐)
# 46         5                  김동률
# 47         7           GOT7 (갓세븐)
# 48         1                   나얼
# 49         0           GOT7 (갓세븐)
# 50         3           GOT7 (갓세븐)
# 51         0                어반자카파
# 52        10               WINNER
# 53         5                   박원
# 54         6                  양다일
# 55         3               볼빨간사춘기
# 56         1      Wanna One (워너원)
#
#                                             melon앨범명    melon발매일
# 0                                                꽃 길  2018.03.13
# 1                                      Yellow Flower  2018.03.07
# 2                                        Eyes On You  2018.03.12
# 3                                                 바람  2018.03.08
# 4                                                 바람  2018.03.08
# 5                                             Return  2018.01.25
# 6                                               나타나줘  2018.03.14
# 7                              투유 프로젝트 - 슈가맨2 Part.2  2018.01.22
# 8                                             GREAT!  2018.01.03
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05
# 10                                       Eyes On You  2018.03.12
# 11                                            애쓰지 마요  2018.02.13
# 12                                     돈꽃 OST Part.1  2017.11.11
# 13                                         그때 헤어지면 돼  2018.02.12
# 14                                            Offset  2018.01.17
# 15                    Fitz and The Tantrums (Deluxe)  2016.07.28
# 16                                            밤이 되니까  2017.09.29
# 17                    YANG YOSEOP 2ND MINI ALBUM `白`  2018.02.19
# 18  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29
# 19                                         Moonlight  2017.07.10
# 20                                         instagram  2017.12.26
# 21                                                바람  2018.03.08
# 22                                             그리고 봄  2018.02.19
# 23                                               &10  2018.01.25
# 24                               LIFE IS BEAUTY FULL  2016.11.10
# 25                                              오늘밤도  2018.02.06
# 26                                                0M  2017.07.27
# 27                                            Evolve  2018.02.22
# 28                                              #첫사랑  2018.01.10
# 29                                            Camila  2018.01.12
# 30                                     Yellow Flower  2018.03.07
# 31                      Illuminate (New Deluxe Ver.)  2017.04.21
# 32                                     /// (너 먹구름 비)  2017.06.26
# 33                                           Action!  2018.03.13
# 34                                              Star  2017.09.18
# 35                                               주인공  2018.01.18
# 36                                  NCT 2018 EMPATHY  2018.03.14
# 37                                             가을 안부  2017.10.14
# 38                                       REMEMBER ME  2017.10.24
# 39                              YOU NEVER WALK ALONE  2017.02.13
# 40                                       twicetagram  2017.10.30
# 41                                              그날처럼  2017.11.28
# 42                                              비밀정원  2018.01.09
# 43                                     Faces of Love  2018.01.29
# 44                                     Merry & Happy  2017.12.11
# 45                                       Eyes On You  2018.03.12
# 46                                                답장  2018.01.11
# 47                                       Eyes On You  2018.03.12
# 48                                           기억의 빈자리  2017.11.29
# 49                                       Eyes On You  2018.03.12
# 50                                       Eyes On You  2018.03.12
# 51                                     그때의 나, 그때의 우리  2017.11.08
# 52                                   FATE NUMBER FOR  2017.04.04
# 53                                              1/24  2016.11.17
# 54                                            inside  2017.12.29
# 55                                  Red Diary Page.1  2017.09.28
# 56                       1-1=0 (NOTHING WITHOUT YOU)  2017.11.13

# %%
result_df = pd.merge(result_df, bugs_df, on='곡') # 3사의 차트 정보를 곡명을 기준으로 합친다.
result_df
# Out:
#     mnet순위  mnet등락                       곡                    가수  \
# 0        1       0                     꽃 길               BIGBANG
# 1        2       0                별이 빛나는 밤          마마무(Mamamoo)
# 2        3       1                    Look            GOT7 (갓세븐)
# 3        4       1     Jenga (Feat. Gaeko)            헤이즈(Heize)
# 4        5       0                 내가 더 나빠            헤이즈(Heize)
# 5        6       5  사랑을 했다 (LOVE SCENARIO)                  iKON
# 6        7       0        나타나줘 (Feat. 박재범)                    로꼬
# 7        8       2                     You       멜로망스(Melomance)
# 8       11       1                      뿜뿜        모모랜드(MOMOLAND)
# 9       12       1           약속해요 (I.P.U.)        Wanna One(워너원)
# 10      14       0                  애쓰지 마요                   박보람
# 11      15       5                  My Way            이수(엠씨더맥스)
# 12      16       0               그때 헤어지면 돼                   로이킴
# 13      17      10          Roller Coaster                    청하
# 14      20      31                  밤이 되니까             펀치(Punch)
# 15      22      30                 Bad Boy     Red Velvet (레드벨벳)
# 16      24      25                      선물       멜로망스(Melomance)
# 17      25       4               instagram                  DEAN
# 18      26       5                 MIANHAE            헤이즈(Heize)
# 19      27      28                     눈사람                   정승환
# 20      28       5                너 없는 시간들                   다비치
# 21      29       3                     비행운          문문(MoonMoon)
# 22      30       5                    오늘밤도             펀치(Punch)
# 23      31      28          all of my life                    박원
# 24      32      16                 Thunder       Imagine Dragons
# 25      34       1                    #첫사랑                볼빨간사춘기
# 26      37       8               별 바람 꽃 태양          마마무(Mamamoo)
# 27      40     100   비도 오고 그래서 (Feat. 신용재)            헤이즈(Heize)
# 28      42     100                     이 별                  길구봉구
# 29      43      21                     주인공                    선미
# 30      44      20                    BOSS                 NCT U
# 31      45       9                   가을 안부     먼데이키즈(Monday Kiz)
# 32      46      15             눈 떠보니 이별이더라                    포맨
# 33      50       9                      봄날                 방탄소년단
# 34      52      14                   LIKEY           TWICE(트와이스)
# 35      55     100                    그날처럼                   장덕철
# 36      56       4                    비밀정원      오마이걸(OH MY GIRL)
# 37      57      22           다른사람을 사랑하고 있어              수지(SUZY)
# 38      62       9            Heart Shaker           TWICE(트와이스)
# 39      64      19                      답장                   김동률
# 40      69      13                 기억의 빈자리                    나얼
# 41      79     100           그때의 나, 그때의 우리  어반 자카파(Urban Zakapa)
# 42      86     100           REALLY REALLY                WINNER
# 43      87     100                      노력                    박원
# 44      88       6                     미안해                   양다일
# 45      91     100                나의 사춘기에게                볼빨간사춘기
# 46      95       8               Beautiful            크러쉬(CRUSH)
#
#                                                   앨범         발매일  melon순위  \
# 0                                                꽃 길  2018.03.13        1
# 1                                      Yellow Flower  2018.03.07        2
# 2                                        Eyes On You  2018.03.12       42
# 3                                                 바람  2018.03.08        3
# 4                                                 바람  2018.03.08        7
# 5                                             Return  2018.01.25        4
# 6                                               나타나줘  2018.03.14       14
# 7                              투유 프로젝트 - 슈가맨2 Part 2  2018.01.22       26
# 8                                             GREAT!  2018.01.03        5
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05       15
# 10                                            애쓰지 마요  2018.02.13       72
# 11                                     돈꽃 OST Part 1  2017.11.11       18
# 12                                         그때 헤어지면 돼  2018.02.12        8
# 13                                            Offset  2018.01.17       11
# 14                                            밤이 되니까  2017.09.29       21
# 15  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29       10
# 16                                         Moonlight  2017.07.10       12
# 17                                         instagram  2017.12.26       20
# 18                                                바람  2018.03.08       85
# 19                                             그리고 봄  2018.02.19       19
# 20                                           &10      2018.01.25       64
# 21                               LIFE IS BEAUTY FULL  2016.11.10       17
# 22                                              오늘밤도  2018.02.06       78
# 23                                                0M  2017.07.27       34
# 24                                            Evolve  2018.02.22       62
# 25                                              #첫사랑  2018.01.10       25
# 26                                     Yellow Flower  2018.03.07       71
# 27                                     /// (너 먹구름 비)  2017.06.26       23
# 28                                              Star  2017.09.18       27
# 29                                               주인공  2018.01.18       24
# 30                                  NCT 2018 EMPATHY  2018.03.14       90
# 31                                             가을 안부  2017.10.14       28
# 32                                       REMEMBER ME  2017.10.24       35
# 33                              YOU NEVER WALK ALONE  2017.02.13       38
# 34                                       twicetagram  2017.10.30       39
# 35                                              그날처럼  2017.11.28        6
# 36                                              비밀정원  2018.01.09       93
# 37                                     Faces of Love  2018.01.29       43
# 38                                     Merry & Happy  2017.12.11       31
# 39                                                답장  2018.01.11       54
# 40                                           기억의 빈자리  2017.11.29       41
# 41                                     그때의 나, 그때의 우리  2017.11.08       50
# 42                                   FATE NUMBER FOR  2017.04.04       65
# 43                                              1/24  2016.11.17       53
# 44                                            inside  2017.12.29       61
# 45                                  Red Diary Page.1  2017.09.28       73
# 46                                    도깨비 OST Part 4  2016.12.17       22
#
#     melon변동폭            melon가수  \
# 0          0            BIGBANG
# 1          0                마마무
# 2         12         GOT7 (갓세븐)
# 3          0        헤이즈 (Heize)
# 4          0        헤이즈 (Heize)
# 5          0               iKON
# 6          2                 로꼬
# 7          0               멜로망스
# 8          0    모모랜드 (MOMOLAND)
# 9          0    Wanna One (워너원)
# 10         8                박보람
# 11         0       이수 (엠씨 더 맥스)
# 12         0                로이킴
# 13         0                 청하
# 14         2         펀치 (Punch)
# 15         0  Red Velvet (레드벨벳)
# 16         1               멜로망스
# 17         2               DEAN
# 18         8        헤이즈 (Heize)
# 19         0                정승환
# 20         3                다비치
# 21         0      문문 (MoonMoon)
# 22         0         펀치 (Punch)
# 23         2                 박원
# 24         5    Imagine Dragons
# 25         1             볼빨간사춘기
# 26         6                마마무
# 27         3        헤이즈 (Heize)
# 28         0               길구봉구
# 29         1                 선미
# 30         6              NCT U
# 31         0             먼데이 키즈
# 32         2                 포맨
# 33         1              방탄소년단
# 34         4       TWICE (트와이스)
# 35         0                장덕철
# 36         3               오마이걸
# 37         2          수지 (SUZY)
# 38         0       TWICE (트와이스)
# 39         5                김동률
# 40         1                 나얼
# 41         0              어반자카파
# 42        10             WINNER
# 43         5                 박원
# 44         6                양다일
# 45         3             볼빨간사춘기
# 46         1    Wanna One (워너원)
#
#                                             melon앨범명    melon발매일  bugs순위  \
# 0                                                꽃 길  2018.03.13       1
# 1                                      Yellow Flower  2018.03.07       3
# 2                                        Eyes On You  2018.03.12      67
# 3                                                 바람  2018.03.08       4
# 4                                                 바람  2018.03.08       7
# 5                                             Return  2018.01.25       9
# 6                                               나타나줘  2018.03.14       2
# 7                              투유 프로젝트 - 슈가맨2 Part.2  2018.01.22       6
# 8                                             GREAT!  2018.01.03      11
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05      31
# 10                                            애쓰지 마요  2018.02.13      76
# 11                                     돈꽃 OST Part.1  2017.11.11      23
# 12                                         그때 헤어지면 돼  2018.02.12       8
# 13                                            Offset  2018.01.17      16
# 14                                            밤이 되니까  2017.09.29      39
# 15  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29      15
# 16                                         Moonlight  2017.07.10      19
# 17                                         instagram  2017.12.26      18
# 18                                                바람  2018.03.08      28
# 19                                             그리고 봄  2018.02.19      14
# 20                                               &10  2018.01.25      37
# 21                               LIFE IS BEAUTY FULL  2016.11.10      41
# 22                                              오늘밤도  2018.02.06      87
# 23                                                0M  2017.07.27      33
# 24                                            Evolve  2018.02.22      57
# 25                                              #첫사랑  2018.01.10      32
# 26                                     Yellow Flower  2018.03.07      20
# 27                                     /// (너 먹구름 비)  2017.06.26      29
# 28                                              Star  2017.09.18      35
# 29                                               주인공  2018.01.18      56
# 30                                  NCT 2018 EMPATHY  2018.03.14      13
# 31                                             가을 안부  2017.10.14      40
# 32                                       REMEMBER ME  2017.10.24      36
# 33                              YOU NEVER WALK ALONE  2017.02.13      68
# 34                                       twicetagram  2017.10.30      80
# 35                                              그날처럼  2017.11.28      10
# 36                                              비밀정원  2018.01.09      43
# 37                                     Faces of Love  2018.01.29      61
# 38                                     Merry & Happy  2017.12.11      81
# 39                                                답장  2018.01.11      49
# 40                                           기억의 빈자리  2017.11.29      42
# 41                                     그때의 나, 그때의 우리  2017.11.08      84
# 42                                   FATE NUMBER FOR  2017.04.04      60
# 43                                              1/24  2016.11.17      44
# 44                                            inside  2017.12.29      38
# 45                                  Red Diary Page.1  2017.09.28      72
# 46                       1-1=0 (NOTHING WITHOUT YOU)  2017.11.13      93
#
#     bugs등락                     bugs가수  \
# 0        0                    BIGBANG
# 1        0               마마무(Mamamoo)
# 2       12                 GOT7 (갓세븐)
# 3        0                 헤이즈(HEIZE)
# 4        0                 헤이즈(HEIZE)
# 5        1                       iKON
# 6        0                         로꼬
# 7        0            멜로망스(MeloMance)
# 8        1             모모랜드(MOMOLAND)
# 9        7             Wanna One(워너원)
# 10      20                        박보람
# 11       4                         이수
# 12       1                        로이킴
# 13       0                         청하
# 14       8                 펀치 (Punch)
# 15       0          Red Velvet (레드벨벳)
# 16       2            멜로망스(MeloMance)
# 17       0                    DEAN(딘)
# 18       4                 헤이즈(HEIZE)
# 19       0                        정승환
# 20       1                        다비치
# 21       2               문문(MoonMoon)
# 22      22                 펀치 (Punch)
# 23      13                         박원
# 24      16  Imagine Dragons(이매진 드래곤스)
# 25       2                     볼빨간사춘기
# 26       3               마마무(Mamamoo)
# 27       3                 헤이즈(HEIZE)
# 28       0                       길구봉구
# 29      27                         선미
# 30       0                      NCT U
# 31       5         먼데이 키즈(Monday Kiz)
# 32      21                         포맨
# 33      28                      방탄소년단
# 34      38               TWICE (트와이스)
# 35       0                        장덕철
# 36      25           오마이걸(OH MY GIRL)
# 37      10                   수지(SUZY)
# 38      47               TWICE (트와이스)
# 39       6                        김동률
# 40       7                  나얼(Na-Ul)
# 41       8       어반 자카파(Urban Zakapa)
# 42       6                     WINNER
# 43       4                         박원
# 44       5                        양다일
# 45      17                     볼빨간사춘기
# 46       5             Wanna One(워너원)
#
#                                               bugs앨범     bugs발매일
# 0                                                꽃 길  2018.03.13
# 1                                      Yellow Flower  2018.03.07
# 2                                        Eyes On You  2018.03.12
# 3                                                 바람  2018.03.08
# 4                                                 바람  2018.03.08
# 5                                             Return  2018.01.25
# 6                                               나타나줘  2018.03.14
# 7                              투유 프로젝트 - 슈가맨2 Part.2  2018.01.22
# 8                                             GREAT!  2018.01.03
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05
# 10                                            애쓰지 마요  2018.02.13
# 11                       돈꽃 (MBC 토요드라마) OST - Part.1  2017.11.11
# 12                                         그때 헤어지면 돼  2018.02.12
# 13                                            Offset  2018.01.17
# 14                                            밤이 되니까  2017.09.29
# 15  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29
# 16                                         Moonlight  2017.07.10
# 17                                         instagram  2017.12.26
# 18                                                바람  2018.03.08
# 19                                             그리고 봄  2018.02.19
# 20                                               &10  2018.01.25
# 21                               LIFE IS BEAUTY FULL  2016.11.10
# 22                                              오늘밤도  2018.02.06
# 23                                                0M  2017.07.27
# 24                                            Evolve  2018.02.22
# 25                                              #첫사랑  2018.01.10
# 26                                     Yellow Flower  2018.03.07
# 27                                     /// (너 먹구름 비)  2017.06.26
# 28                                              Star  2017.09.18
# 29                                               주인공  2018.01.18
# 30                                  NCT 2018 EMPATHY  2018.03.14
# 31                                             가을 안부  2017.10.14
# 32                                       REMEMBER ME  2017.10.24
# 33                              YOU NEVER WALK ALONE  2017.02.13
# 34                                       twicetagram  2017.10.30
# 35                                              그날처럼  2017.11.28
# 36                                              비밀정원  2018.01.09
# 37                                     Faces of Love  2018.01.29
# 38                                     Merry & Happy  2017.12.11
# 39                                                답장  2018.01.11
# 40                                           기억의 빈자리  2017.11.29
# 41                                     그때의 나, 그때의 우리  2017.11.08
# 42                                   FATE NUMBER FOR  2017.04.04
# 43                                              1/24  2016.11.17
# 44                                            inside  2017.12.29
# 45                                  Red Diary Page.1  2017.09.28
# 46                       1-1=0 (NOTHING WITHOUT YOU)  2017.11.13

# %%
del result_df['melon가수'] # 필요없는 컬럼들 지우기
del result_df['melon앨범명']
del result_df['melon발매일']

# %%
del result_df['bugs가수']
del result_df['bugs앨범']
del result_df['bugs발매일']

# %%
result_df.head()
# Out:
#    mnet순위  mnet등락                    곡            가수             앨범  \
# 0       1       0                  꽃 길       BIGBANG            꽃 길
# 1       2       0             별이 빛나는 밤  마마무(Mamamoo)  Yellow Flower
# 2       3       1                 Look    GOT7 (갓세븐)    Eyes On You
# 3       4       1  Jenga (Feat. Gaeko)    헤이즈(Heize)             바람
# 4       5       0              내가 더 나빠    헤이즈(Heize)             바람
#
#           발매일  melon순위  melon변동폭  bugs순위  bugs등락
# 0  2018.03.13        1         0       1       0
# 1  2018.03.07        2         0       3       0
# 2  2018.03.12       42        12      67      12
# 3  2018.03.08        3         0       4       0
# 4  2018.03.08        7         0       7       0

# %%
# 각 곡들의 순위 평균과 변동폭 평균을 구한다
result_df['순위_평균'] = (result_df['mnet순위'] + result_df['melon순위'] + result_df['bugs순위']) / 3
result_df['등락_변동폭_평균'] = (result_df['mnet등락'] + result_df['melon변동폭'] + result_df['bugs등락']) / 3

result_df.head()
# Out:
#    mnet순위  mnet등락                    곡            가수             앨범  \
# 0       1       0                  꽃 길       BIGBANG            꽃 길
# 1       2       0             별이 빛나는 밤  마마무(Mamamoo)  Yellow Flower
# 2       3       1                 Look    GOT7 (갓세븐)    Eyes On You
# 3       4       1  Jenga (Feat. Gaeko)    헤이즈(Heize)             바람
# 4       5       0              내가 더 나빠    헤이즈(Heize)             바람
#
#           발매일  melon순위  melon변동폭  bugs순위  bugs등락      순위_평균  등락_변동폭_평균
# 0  2018.03.13        1         0       1       0   1.000000   0.000000
# 1  2018.03.07        2         0       3       0   2.333333   0.000000
# 2  2018.03.12       42        12      67      12  37.333333   8.333333
# 3  2018.03.08        3         0       4       0   3.666667   0.333333
# 4  2018.03.08        7         0       7       0   6.333333   0.000000

# %%
del result_df['mnet순위'] # 필요없는 컬럼들 지우기
del result_df['mnet등락']
del result_df['melon순위']
del result_df['melon변동폭']
del result_df['bugs순위']
del result_df['bugs등락']

# %%
result_df.sort_values('순위_평균')
# Out:
#                          곡                    가수  \
# 0                      꽃 길               BIGBANG
# 1                 별이 빛나는 밤          마마무(Mamamoo)
# 3      Jenga (Feat. Gaeko)            헤이즈(Heize)
# 4                  내가 더 나빠            헤이즈(Heize)
# 5   사랑을 했다 (LOVE SCENARIO)                  iKON
# 6         나타나줘 (Feat. 박재범)                    로꼬
# 8                       뿜뿜        모모랜드(MOMOLAND)
# 12               그때 헤어지면 돼                   로이킴
# 7                      You       멜로망스(Melomance)
# 13          Roller Coaster                    청하
# 15                 Bad Boy     Red Velvet (레드벨벳)
# 16                      선물       멜로망스(Melomance)
# 11                  My Way            이수(엠씨더맥스)
# 9            약속해요 (I.P.U.)        Wanna One(워너원)
# 19                     눈사람                   정승환
# 17               instagram                  DEAN
# 35                    그날처럼                   장덕철
# 14                  밤이 되니까             펀치(Punch)
# 21                     비행운          문문(MoonMoon)
# 25                    #첫사랑                볼빨간사춘기
# 27   비도 오고 그래서 (Feat. 신용재)            헤이즈(Heize)
# 23          all of my life                    박원
# 28                     이 별                  길구봉구
# 2                     Look            GOT7 (갓세븐)
# 31                   가을 안부     먼데이키즈(Monday Kiz)
# 32             눈 떠보니 이별이더라                    포맨
# 29                     주인공                    선미
# 26               별 바람 꽃 태양          마마무(Mamamoo)
# 20                너 없는 시간들                   다비치
# 18                 MIANHAE            헤이즈(Heize)
# 30                    BOSS                 NCT U
# 24                 Thunder       Imagine Dragons
# 40                 기억의 빈자리                    나얼
# 33                      봄날                 방탄소년단
# 37           다른사람을 사랑하고 있어              수지(SUZY)
# 10                  애쓰지 마요                   박보람
# 39                      답장                   김동률
# 34                   LIKEY           TWICE(트와이스)
# 38            Heart Shaker           TWICE(트와이스)
# 43                      노력                    박원
# 44                     미안해                   양다일
# 36                    비밀정원      오마이걸(OH MY GIRL)
# 22                    오늘밤도             펀치(Punch)
# 46               Beautiful            크러쉬(CRUSH)
# 42           REALLY REALLY                WINNER
# 41           그때의 나, 그때의 우리  어반 자카파(Urban Zakapa)
# 45                나의 사춘기에게                볼빨간사춘기
#
#                                                   앨범         발매일      순위_평균  \
# 0                                                꽃 길  2018.03.13   1.000000
# 1                                      Yellow Flower  2018.03.07   2.333333
# 3                                                 바람  2018.03.08   3.666667
# 4                                                 바람  2018.03.08   6.333333
# 5                                             Return  2018.01.25   6.333333
# 6                                               나타나줘  2018.03.14   7.666667
# 8                                             GREAT!  2018.01.03   9.000000
# 12                                         그때 헤어지면 돼  2018.02.12  10.666667
# 7                              투유 프로젝트 - 슈가맨2 Part 2  2018.01.22  13.333333
# 13                                            Offset  2018.01.17  14.666667
# 15  The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29  15.666667
# 16                                         Moonlight  2017.07.10  18.333333
# 11                                     돈꽃 OST Part 1  2017.11.11  18.666667
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05  19.333333
# 19                                             그리고 봄  2018.02.19  20.000000
# 17                                         instagram  2017.12.26  21.000000
# 35                                              그날처럼  2017.11.28  23.666667
# 14                                            밤이 되니까  2017.09.29  26.666667
# 21                               LIFE IS BEAUTY FULL  2016.11.10  29.000000
# 25                                              #첫사랑  2018.01.10  30.333333
# 27                                     /// (너 먹구름 비)  2017.06.26  30.666667
# 23                                                0M  2017.07.27  32.666667
# 28                                              Star  2017.09.18  34.666667
# 2                                        Eyes On You  2018.03.12  37.333333
# 31                                             가을 안부  2017.10.14  37.666667
# 32                                       REMEMBER ME  2017.10.24  39.000000
# 29                                               주인공  2018.01.18  41.000000
# 26                                     Yellow Flower  2018.03.07  42.666667
# 20                                           &10      2018.01.25  43.000000
# 18                                                바람  2018.03.08  46.333333
# 30                                  NCT 2018 EMPATHY  2018.03.14  49.000000
# 24                                            Evolve  2018.02.22  50.333333
# 40                                           기억의 빈자리  2017.11.29  50.666667
# 33                              YOU NEVER WALK ALONE  2017.02.13  52.000000
# 37                                     Faces of Love  2018.01.29  53.666667
# 10                                            애쓰지 마요  2018.02.13  54.000000
# 39                                                답장  2018.01.11  55.666667
# 34                                       twicetagram  2017.10.30  57.000000
# 38                                     Merry & Happy  2017.12.11  58.000000
# 43                                              1/24  2016.11.17  61.333333
# 44                                            inside  2017.12.29  62.333333
# 36                                              비밀정원  2018.01.09  64.000000
# 22                                              오늘밤도  2018.02.06  65.000000
# 46                                    도깨비 OST Part 4  2016.12.17  70.000000
# 42                                   FATE NUMBER FOR  2017.04.04  70.333333
# 41                                     그때의 나, 그때의 우리  2017.11.08  71.000000
# 45                                  Red Diary Page.1  2017.09.28  78.666667
#
#     등락_변동폭_평균
# 0    0.000000
# 1    0.000000
# 3    0.333333
# 4    0.000000
# 5    2.000000
# 6    0.666667
# 8    0.666667
# 12   0.333333
# 7    0.666667
# 13   3.333333
# 15  10.000000
# 16   9.333333
# 11   3.000000
# 9    2.666667
# 19   9.333333
# 17   2.000000
# 35  33.333333
# 14  13.666667
# 21   1.666667
# 25   1.333333
# 27  35.333333
# 23  14.333333
# 28  33.333333
# 2    8.333333
# 31   4.666667
# 32  12.666667
# 29  16.333333
# 26   5.666667
# 20   3.000000
# 18   5.666667
# 30   8.666667
# 24  12.333333
# 40   7.000000
# 33  12.666667
# 37  11.333333
# 10   9.333333
# 39  10.000000
# 34  18.666667
# 38  18.666667
# 43  36.333333
# 44   5.666667
# 36  10.666667
# 22   9.000000
# 46   4.666667
# 42  38.666667
# 41  36.000000
# 45  40.000000

# %%
np.corrcoef(result_df['순위_평균'], result_df['등락_변동폭_평균'])
# 각 곡의 3사 순위 평균과 등락폭 평균은 관계가 있다.
# Out:
# array([[1.        , 0.54904463],
#        [0.54904463, 1.        ]])

# %%
fp1 = np.polyfit(result_df['순위_평균'], result_df['등락_변동폭_평균'], 1)

f1 = np.poly1d(fp1) # y축 데이터 만들기(CCTV 개수 표현을 위한 데이터 축)
fx = np.linspace(0,100,100) # x축 데이터 만들기 (인구수 표현을 위한 데이터 축)

plt.figure(figsize=(10,10))
plt.scatter(result_df['순위_평균'], result_df['등락_변동폭_평균'], c=result_df['순위_평균'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g') # 기준 직선 그려주기

plt.xlabel('순위_평균')
plt.ylabel('등락_변동폭_평균')

plt.colorbar()
plt.grid()
plt.show()

# %%
# pivot_table을 위해 모든 데이터 프레임들이 같은 컬럼의 이름을 가지도록 설정한다.

mnet_df=pd.DataFrame(mnet, columns=['순위','등락','곡','가수','앨범','발매일'])
melon_df = pd.DataFrame(melon, columns=['순위','등락','곡','가수','앨범','발매일'])
bugs_df = pd.DataFrame(bugs, columns=['순위','등락','곡','가수','앨범','발매일'])

# %%
result_df = pd.concat([mnet_df, melon_df, bugs_df], ignore_index=True)
# 각 음악 사이트들의 데이터 프레임들을 세로로 붙인다.
result_df
# Out:
#       순위  등락                                   곡                      가수  \
# 0      1   0                                 꽃 길                 BIGBANG
# 1      2   0                            별이 빛나는 밤            마마무(Mamamoo)
# 2      3   1                                Look              GOT7 (갓세븐)
# 3      4   1                 Jenga (Feat. Gaeko)              헤이즈(Heize)
# 4      5   0                             내가 더 나빠              헤이즈(Heize)
# 5      6   5              사랑을 했다 (LOVE SCENARIO)                    iKON
# 6      7   0                    나타나줘 (Feat. 박재범)                      로꼬
# 7      8   2                                 You         멜로망스(Melomance)
# 8      9   1                          My Blossom               소유(SOYOU)
# 9     10   1                               괜찮냐고               헤이즈(Heize)
# 10    11   1                                  뿜뿜          모모랜드(MOMOLAND)
# 11    12   1                       약속해요 (I.P.U.)          Wanna One(워너원)
# 12    13   4                    너 하나만 (Feat. 효린)              GOT7 (갓세븐)
# 13    14   0                              애쓰지 마요                     박보람
# 14    15   5                              My Way              이수(엠씨더맥스)
# 15    16   0                           그때 헤어지면 돼                     로이킴
# 16    17  10                      Roller Coaster                      청하
# 17    18  10                            HandClap     Fitz & The Tantrums
# 18    19   0                잘 살길 바래 (With DAVII)              헤이즈(Heize)
# 19    20  31                              밤이 되니까               펀치(Punch)
# 20    21  18                             네가 없는 곳                     양요섭
# 21    22  30                             Bad Boy       Red Velvet (레드벨벳)
# 22    23   5                                 후유증                     민경훈
# 23    24  25                                  선물         멜로망스(Melomance)
# 24    25   4                           instagram                    DEAN
# 25    26   5                             MIANHAE              헤이즈(Heize)
# 26    27  28                                 눈사람                     정승환
# 27    28   5                            너 없는 시간들                     다비치
# 28    29   3                                 비행운            문문(MoonMoon)
# 29    30   5                                오늘밤도               펀치(Punch)
# ..   ...  ..                                 ...                     ...
# 270   71   6                            다시 쓰고 싶어              에일리(Ailee)
# 271   72  17                            나의 사춘기에게                  볼빨간사춘기
# 272   73  23                     Baby Don't Stop                   NCT U
# 273   74  25                   Lonely (Feat. 태연)           종현 (JONGHYUN)
# 274   75  20                                  결혼            문문(MoonMoon)
# 275   76  20                              애쓰지 마요                     박보람
# 276   77  10       시차 (We Are) (Feat. 로꼬 & GRAY)                     우원재
# 277   78   4                               벚꽃 엔딩  버스커 버스커(Busker Busker)
# 278   79  16                    피카부 (Peek-A-Boo)       Red Velvet (레드벨벳)
# 279   80  38                               LIKEY            TWICE (트와이스)
# 280   81  47                        Heart Shaker            TWICE (트와이스)
# 281   82   9                                  한숨                     이하이
# 282   83  10                             고민보다 Go                   방탄소년단
# 283   84   8                       그때의 나, 그때의 우리    어반 자카파(Urban Zakapa)
# 284   85   9                    연애소설 (Feat. 아이유)        에픽하이 (EPIK HIGH)
# 285   86   5                고무줄다리기 (Rubber Band)                    iKON
# 286   87  22                                오늘밤도              펀치 (Punch)
# 287   88   1                Action! (feat. GRAY)                DPR LIVE
# 288   89  35     There's Nothing Holdin' Me Back     Shawn Mendes(션 멘데스)
# 289   90   7  Perhaps Love (사랑인가요) (Prod.By 박근태)           에릭남(Eric Nam)
# 290   91  54                   빨간 맛 (Red Flavor)       Red Velvet (레드벨벳)
# 291   92   9                             FRIENDS        Marshmello(마시멜로)
# 292   93   5                           Beautiful          Wanna One(워너원)
# 293   94   4                               이별 뒷면                     권진아
# 294   95  26                            YESTODAY                   NCT U
# 295   96   2                           True Love                     김성규
# 296   97  17                            꿈꾸는 마음으로                    우주소녀
# 297   98  10                          Candy (캔디)                  H.O.T.
# 298   99   5                                Blue                  볼빨간사춘기
# 299  100   1            HOLIDAY (Feat. DPR LIVE)                수지(SUZY)
#
#                                                    앨범         발매일
# 0                                                 꽃 길  2018.03.13
# 1                                       Yellow Flower  2018.03.07
# 2                                         Eyes On You  2018.03.12
# 3                                                  바람  2018.03.08
# 4                                                  바람  2018.03.08
# 5                                              Return  2018.01.25
# 6                                                나타나줘  2018.03.14
# 7                               투유 프로젝트 - 슈가맨2 Part 2  2018.01.22
# 8                                          My Blossom  2018.03.12
# 9                                                  바람  2018.03.08
# 10                                             GREAT!  2018.01.03
# 11                약속해요 (I.P.U.) - Special Theme Track  2018.03.05
# 12                                        Eyes On You  2018.03.12
# 13                                             애쓰지 마요  2018.02.13
# 14                                      돈꽃 OST Part 1  2017.11.11
# 15                                          그때 헤어지면 돼  2018.02.12
# 16                                             Offset  2018.01.17
# 17                     Fitz and The Tantrums (Deluxe)  2017.07.28
# 18                                                 바람  2018.03.08
# 19                                             밤이 되니까  2017.09.29
# 20                     YANG YOSEOP 2ND MINI ALBUM `白`  2018.02.19
# 21   The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29
# 22                                                후유증  2018.02.17
# 23                                          Moonlight  2017.07.10
# 24                                          instagram  2017.12.26
# 25                                                 바람  2018.03.08
# 26                                              그리고 봄  2018.02.19
# 27                                            &10      2018.01.25
# 28                                LIFE IS BEAUTY FULL  2016.11.10
# 29                                               오늘밤도  2018.02.06
# ..                                                ...         ...
# 270                    이런 꽃 같은 엔딩 (웹드라마) OST - Part.3  2018.02.09
# 271                                  Red Diary Page.1  2017.09.28
# 272                                  NCT 2018 EMPATHY  2018.03.14
# 273                                 종현 소품집 '이야기 Op.2'  2017.04.24
# 274               이번 생은 처음이라 (tvN 월화드라마) OST - Part.4  2017.10.24
# 275                                            애쓰지 마요  2018.02.13
# 276                                       시차 (We Are)  2017.09.04
# 277                                        버스커 버스커 1집  2012.03.29
# 278                    Perfect Velvet - The 2nd Album  2017.11.17
# 279                                       twicetagram  2017.10.30
# 280                                     Merry & Happy  2017.12.11
# 281                                          SEOULITE  2016.03.09
# 282                             LOVE YOURSELF 承 'Her'  2017.09.18
# 283                                     그때의 나, 그때의 우리  2017.11.08
# 284                    WE'VE DONE SOMETHING WONDERFUL  2017.10.23
# 285                              고무줄다리기 (Rubber Band)  2018.03.05
# 286                                              오늘밤도  2018.02.06
# 287                                           Action!  2018.03.13
# 288                      Illuminate [New Deluxe Ver.]  2017.04.21
# 289                                    Your BGM Vol.1  2017.09.29
# 290                The Red Summer - Summer Mini Album  2017.07.09
# 291                                           FRIENDS  2018.02.09
# 292                       1-1=0 (NOTHING WITHOUT YOU)  2017.11.13
# 293                    이런 꽃 같은 엔딩 (웹드라마) OST - Part.2  2018.02.02
# 294                                  NCT 2018 EMPATHY  2018.03.14
# 295                            1st Album '10 Stories'  2018.02.26
# 296                                  Dream Your Dream  2018.02.27
# 297                     We Hate All Kinds Of Violence     1996.09
# 298                                  Red Diary Page.1  2017.09.28
# 299                                     Faces of Love  2018.01.29
#
# [300 rows x 6 columns]

# %%
#순위와 등락폭의 평균을 pivot_table을 이용하여 구한다
pivot_result_df = pd.pivot_table(result_df, index=["곡"], values=["순위", "등락"], aggfunc=[np.mean])

# %%
pivot_result_df.head()
# Out:
#                                                  mean
#                                                    등락         순위
# 곡
# #첫사랑                                         1.333333  30.333333
# Action! (Feat. GRAY)                         6.500000  67.500000
# Action! (feat. GRAY)                         1.000000  88.000000
# All Falls Down (Feat. Noah Cyrus, Digit ..  11.000000  39.000000
# All The Stars (영화 '블랙 팬서' OST)               6.000000  64.000000

# %%
pivot_result_df.columns = pivot_result_df.columns.droplevel()
#컬럼 위쪽에 붙은 mean 제거
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-e0b2ef23d42a> in <module>()
# ----> 1 pivot_result_df.columns = pivot_result_df.columns.droplevel()
#       2 pivot_result_df.head()
#
# AttributeError: 'Index' object has no attribute 'droplevel'

# %%
pivot_result_df.head()
# Out:
#                                                    등락         순위
# 곡
# #첫사랑                                         1.333333  30.333333
# Action! (Feat. GRAY)                         6.500000  67.500000
# Action! (feat. GRAY)                         1.000000  88.000000
# All Falls Down (Feat. Noah Cyrus, Digit ..  11.000000  39.000000
# All The Stars (영화 '블랙 팬서' OST)               6.000000  64.000000

# %%
np.corrcoef(pivot_result_df['순위'], pivot_result_df['등락'])
# 순위와 등락의 변동폭은 관계가 있다.
# Out:
# array([[1.        , 0.31381532],
#        [0.31381532, 1.        ]])

# %%
fp1 = np.polyfit(pivot_result_df['순위'], pivot_result_df['등락'], 1)

f1 = np.poly1d(fp1) # y축 데이터 만들기(CCTV 개수 표현을 위한 데이터 축)
fx = np.linspace(0,100,100) # x축 데이터 만들기 (인구수 표현을 위한 데이터 축)

plt.figure(figsize=(10,10))
plt.scatter(pivot_result_df['순위'], pivot_result_df['등락'], c=pivot_result_df['순위'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g') # 기준 직선 그려주기

plt.xlabel('순위_평균')
plt.ylabel('등락_변동폭_평균')

plt.colorbar()
plt.grid()
plt.show()
