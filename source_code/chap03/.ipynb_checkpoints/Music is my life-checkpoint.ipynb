# %%
#웹 크롤링을 쉽게 해주는 BeautifulSoup
#크롤링: 웹 사이트의 HTML문서에서 필요한 정보를 수집하는 것
#스크래이핑: 실제 HTML만을 이용해 수집하는 것(크롤링의 일종)

#Anaconda 설치 시 BeautifulSoup 라이브러리가 자동으로 포함됨
from bs4 import BeautifulSoup
from urllib.request import urlopen

page = urlopen('http://www.mnet.com/chart/TOP100/') #url의 페이지(html) 불러오기
page2 = urlopen('http://www.mnet.com/chart/TOP100/2018031314?pNum=2')

soup = BeautifulSoup(page, 'html.parser')
soup2 = BeautifulSoup(page2, 'html.parser')

song_list = soup.find(class_='MMLTable jQMMLTable').table.tbody.find_all('tr')
song_list

song_list2 = soup2.find(class_='MMLTable jQMMLTable').table.tbody.find_all('tr')
song_list2
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [<tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Jenga (Feat. Gaeko) - 선택" type="checkbox" value="30617665"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNumBest MMLI_RankNumBest_1">1위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828127 " target="_self"><img alt="바람 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828127', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828127.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617665" target="_self">Jenga (Feat. Gaeko) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617665');" title="Jenga (Feat. Gaeko) 새창">Jenga (Feat. Gaeko)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/318200 " target="_self" title="헤이즈(Heize) - 아티스트">헤이즈(Heize)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828127 " target="_self" title="바람 - 앨범">바람</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617665','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617665');" title="Jenga (Feat. Gaeko) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617665" title="마이앨범 담기">30617665</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30617665');" title="Jenga (Feat. Gaeko) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617665');" title="Jenga (Feat. Gaeko) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617665','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617665','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  <div class="mqs_info" style="display:block;">
#  <div class="mqs_infoTxt">
#  <a href="javascript:;" onclick="$('#mqsInfo').show();">원음 이용안내</a>
#  <button onclick="$(this).parent('.mqs_infoTxt').parent('.mqs_info').hide();mnetCookie.setCookie('mqsLayer','Y',7);" type="button">닫기</button>
#  </div>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Look - 선택" type="checkbox" value="30628075"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNumBest MMLI_RankNumBest_2">2위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628075" target="_self">Look - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628075');" title="Look 새창">Look</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628075','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628075');" title="Look - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628075" title="마이앨범 담기">30628075</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30628075');" title="Look - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628075');" title="Look - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30628075','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30628075','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="별이 빛나는 밤 - 선택" type="checkbox" value="30617310"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNumBest MMLI_RankNumBest_3">3위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828085 " target="_self"><img alt="Yellow Flower - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828085', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828085.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617310" target="_self">별이 빛나는 밤 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617310');" title="별이 빛나는 밤 새창">별이 빛나는 밤</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317059 " target="_self" title="마마무(Mamamoo) - 아티스트">마마무(Mamamoo)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828085 " target="_self" title="Yellow Flower - 앨범">Yellow Flower</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617310','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617310');" title="별이 빛나는 밤 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617310" title="마이앨범 담기">30617310</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30617310');" title="별이 빛나는 밤 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617310');" title="별이 빛나는 밤 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617310','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617310','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="뿜뿜 - 선택" type="checkbox" value="26943963"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_4">4위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">2</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2718989 " target="_self"><img alt="GREAT! - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2718989', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/718/2718989.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/26943963" target="_self">뿜뿜 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('26943963');" title="뿜뿜 새창">뿜뿜</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/1102571 " target="_self" title="모모랜드(MOMOLAND) - 아티스트">모모랜드(MOMOLAND)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2718989 " target="_self" title="GREAT! - 앨범">GREAT!</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('26943963','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('26943963');" title="뿜뿜 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_26943963" title="마이앨범 담기">26943963</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('26943963');" title="뿜뿜 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('26943963');" title="뿜뿜 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="내가 더 나빠 - 선택" type="checkbox" value="30617667"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_5">5위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown">보합</span><span class="MMLI_UpdownNum">0</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828127 " target="_self"><img alt="바람 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828127', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828127.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617667" target="_self">내가 더 나빠 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617667');" title="내가 더 나빠 새창">내가 더 나빠</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/318200 " target="_self" title="헤이즈(Heize) - 아티스트">헤이즈(Heize)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828127 " target="_self" title="바람 - 앨범">바람</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617667','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617667');" title="내가 더 나빠 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617667" title="마이앨범 담기">30617667</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30617667');" title="내가 더 나빠 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617667');" title="내가 더 나빠 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617667','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617667','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="사랑을 했다 (LOVE SCENARIO) - 선택" type="checkbox" value="29700380"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_6">6위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">3</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2781611 " target="_self"><img alt="Return - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2781611', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/781/2781611.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/29700380" target="_self">사랑을 했다 (LOVE SCENARIO) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('29700380');" title="사랑을 했다 (LOVE SCENARIO) 새창">사랑을 했다 (LOVE SCENARIO)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/460027 " target="_self" title="iKON - 아티스트">iKON</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2781611 " target="_self" title="Return - 앨범">Return</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('29700380','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('29700380');" title="사랑을 했다 (LOVE SCENARIO) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_29700380" title="마이앨범 담기">29700380</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('29700380');" title="사랑을 했다 (LOVE SCENARIO) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('29700380');" title="사랑을 했다 (LOVE SCENARIO) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('29700380','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="HandClap - 선택" type="checkbox" value="5257815"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_7">7위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown">보합</span><span class="MMLI_UpdownNum">0</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/537638 " target="_self"><img alt="Fitz and The Tantrums (Deluxe) - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '537638', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/000/537/537638.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/5257815" target="_self">HandClap - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('5257815');" title="HandClap 새창">HandClap</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/267287 " target="_self" title="Fitz &amp; The Tantrums - 아티스트">Fitz &amp; The Tantrums</a> /
#  							<a class="MMLIInfo_Album" href=" /album/537638 " target="_self" title="Fitz and The Tantrums (Deluxe) - 앨범">Fitz and The Tantrums (Deluxe)</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('5257815','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('5257815');" title="HandClap - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_5257815" title="마이앨범 담기">5257815</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('5257815');" title="HandClap - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="너 하나만 (Feat. 효린) - 선택" type="checkbox" value="30418690"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_8">8위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown">보합</span><span class="MMLI_UpdownNum">0</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30418690" target="_self">너 하나만 (Feat. 효린) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30418690');" title="너 하나만 (Feat. 효린) 새창">너 하나만 (Feat. 효린)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30418690','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30418690');" title="너 하나만 (Feat. 효린) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30418690" title="마이앨범 담기">30418690</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30418690');" title="너 하나만 (Feat. 효린) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30418690');" title="너 하나만 (Feat. 효린) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30418690','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30418690','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Bad Boy - 선택" type="checkbox" value="29903841"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_9">9위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2782587 " target="_self"><img alt="The Perfect Red Velvet - The 2nd Album Repackage - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2782587', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/782/2782587.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/29903841" target="_self">Bad Boy - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('29903841');" title="Bad Boy 새창">Bad Boy</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/346426 " target="_self" title="Red Velvet (레드벨벳) - 아티스트">Red Velvet (레드벨벳)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2782587 " target="_self" title="The Perfect Red Velvet - The 2nd Album Repackage - 앨범">The Perfect Red Velvet - The 2nd Album Repackage</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('29903841','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('29903841');" title="Bad Boy - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_29903841" title="마이앨범 담기">29903841</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('29903841');" title="Bad Boy - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('29903841');" title="Bad Boy - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('29903841','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="그때 헤어지면 돼 - 선택" type="checkbox" value="30383559"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_10">10위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2787157 " target="_self"><img alt="그때 헤어지면 돼 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2787157', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/787/2787157.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30383559" target="_self">그때 헤어지면 돼 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30383559');" title="그때 헤어지면 돼 새창">그때 헤어지면 돼</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/248614 " target="_self" title="로이킴 - 아티스트">로이킴</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2787157 " target="_self" title="그때 헤어지면 돼 - 앨범">그때 헤어지면 돼</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30383559','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30383559');" title="그때 헤어지면 돼 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30383559" title="마이앨범 담기">30383559</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30383559');" title="그때 헤어지면 돼 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30383559');" title="그때 헤어지면 돼 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30383559','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="You - 선택" type="checkbox" value="28960549"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_11">11위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">2</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2779017 " target="_self"><img alt="투유 프로젝트 - 슈가맨2 Part 2 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2779017', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/779/2779017.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/28960549" target="_self">You - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('28960549');" title="You 새창">You</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/380336 " target="_self" title="멜로망스(Melomance) - 아티스트">멜로망스(Melomance)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2779017 " target="_self" title="투유 프로젝트 - 슈가맨2 Part 2 - 앨범">투유 프로젝트 - 슈가맨2 Part 2</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('28960549','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('28960549');" title="You - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_28960549" title="마이앨범 담기">28960549</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('28960549');" title="You - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('28960549','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Roller Coaster - 선택" type="checkbox" value="28508138"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_12">12위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">2</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2762868 " target="_self"><img alt="Offset - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2762868', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/762/2762868.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/28508138" target="_self">Roller Coaster - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('28508138');" title="Roller Coaster 새창">Roller Coaster</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/487272 " target="_self" title="청하 - 아티스트">청하</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2762868 " target="_self" title="Offset - 앨범">Offset</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('28508138','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('28508138');" title="Roller Coaster - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_28508138" title="마이앨범 담기">28508138</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('28508138');" title="Roller Coaster - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('28508138');" title="Roller Coaster - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('28508138','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('28508138','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="그날처럼 - 선택" type="checkbox" value="22972170"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_13">13위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">2</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2515484 " target="_self"><img alt="그날처럼 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2515484', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/515/2515484.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/22972170" target="_self">그날처럼 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('22972170');" title="그날처럼 새창">그날처럼</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/372831 " target="_self" title="장덕철 - 아티스트">장덕철</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2515484 " target="_self" title="그날처럼 - 앨범">그날처럼</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('22972170','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('22972170');" title="그날처럼 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_22972170" title="마이앨범 담기">22972170</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('22972170');" title="그날처럼 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('22972170');" title="그날처럼 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('22972170','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('22972170','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Havana (Feat. Young Thug) - 선택" type="checkbox" value="19003732"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_14">14위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">2</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2132151 " target="_self"><img alt="Camila - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2132151', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/132/2132151.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/19003732" target="_self">Havana (Feat. Young Thug) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('19003732');" title="Havana (Feat. Young Thug) 새창">Havana (Feat. Young Thug)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/476588 " target="_self" title="Camila Cabello - 아티스트">Camila Cabello</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2132151 " target="_self" title="Camila - 앨범">Camila</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('19003732','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('19003732');" title="Havana (Feat. Young Thug) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_19003732" title="마이앨범 담기">19003732</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('19003732');" title="Havana (Feat. Young Thug) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('19003732');" title="Havana (Feat. Young Thug) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="약속해요 (I.P.U.) - 선택" type="checkbox" value="30613192"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_15">15위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">1</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2827401 " target="_self"><img alt="약속해요 (I.P.U.) - Special Theme Track - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2827401', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/827/2827401.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30613192" target="_self">약속해요 (I.P.U.) - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30613192');" title="약속해요 (I.P.U.) 새창">약속해요 (I.P.U.)</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/1761090 " target="_self" title="Wanna One(워너원) - 아티스트">Wanna One(워너원)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2827401 " target="_self" title="약속해요 (I.P.U.) - Special Theme Track - 앨범">약속해요 (I.P.U.) - Special Theme Track</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30613192','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30613192');" title="약속해요 (I.P.U.) - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30613192" title="마이앨범 담기">30613192</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30613192');" title="약속해요 (I.P.U.) - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30613192');" title="약속해요 (I.P.U.) - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30613192','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="주인공 - 선택" type="checkbox" value="28844570"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_16">16위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">5</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2778228 " target="_self"><img alt="주인공 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2778228', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/778/2778228.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/28844570" target="_self">주인공 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('28844570');" title="주인공 새창">주인공</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/146749 " target="_self" title="선미 - 아티스트">선미</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2778228 " target="_self" title="주인공 - 앨범">주인공</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('28844570','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('28844570');" title="주인공 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_28844570" title="마이앨범 담기">28844570</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('28844570');" title="주인공 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('28844570');" title="주인공 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('28844570','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('28844570','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="Heart Shaker - 선택" type="checkbox" value="25021489"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_17">17위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">10</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2637695 " target="_self"><img alt="Merry &amp; Happy - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2637695', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/637/2637695.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/25021489" target="_self">Heart Shaker - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('25021489');" title="Heart Shaker 새창">Heart Shaker</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/463178 " target="_self" title="TWICE(트와이스) - 아티스트">TWICE(트와이스)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2637695 " target="_self" title="Merry &amp; Happy - 앨범">Merry &amp; Happy</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('25021489','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('25021489');" title="Heart Shaker - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_25021489" title="마이앨범 담기">25021489</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('25021489');" title="Heart Shaker - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
# ...
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('21387157');" title="그때의 나, 그때의 우리 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('21387157');" title="그때의 나, 그때의 우리 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('21387157','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('21387157','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="MIANHAE - 선택" type="checkbox" value="30617670"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_46">46위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">21</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828127 " target="_self"><img alt="바람 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828127', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828127.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617670" target="_self">MIANHAE - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617670');" title="MIANHAE 새창">MIANHAE</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/318200 " target="_self" title="헤이즈(Heize) - 아티스트">헤이즈(Heize)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828127 " target="_self" title="바람 - 앨범">바람</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617670','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617670');" title="MIANHAE - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617670" title="마이앨범 담기">30617670</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('30617670');" title="MIANHAE - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617670');" title="MIANHAE - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617670','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617670','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="바람 - 선택" type="checkbox" value="30617669"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_47">47위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">22</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2828127 " target="_self"><img alt="바람 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2828127', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/828/2828127.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30617669" target="_self">바람 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30617669');" title="바람 새창">바람</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/318200 " target="_self" title="헤이즈(Heize) - 아티스트">헤이즈(Heize)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2828127 " target="_self" title="바람 - 앨범">바람</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30617669','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30617669');" title="바람 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30617669" title="마이앨범 담기">30617669</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30617669');" title="바람 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30617669','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30617669','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="망설이다 - 선택" type="checkbox" value="30628077"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_48">48위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">3</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628077" target="_self">망설이다 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628077');" title="망설이다 새창">망설이다</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628077','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628077');" title="망설이다 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628077" title="마이앨범 담기">30628077</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628077');" title="망설이다 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30628077','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30628077','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="노력 - 선택" type="checkbox" value="13851747"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_49">49위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Up">상승</span><span class="MMLI_UpdownNum">30</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/1509782 " target="_self"><img alt="1/24 - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '1509782', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/001/509/1509782.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/13851747" target="_self">노력 - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('13851747');" title="노력 새창">노력</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/174923 " target="_self" title="박원 - 아티스트">박원</a> /
#  							<a class="MMLIInfo_Album" href=" /album/1509782 " target="_self" title="1/24 - 앨범">1/24</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('13851747','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('13851747');" title="노력 - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_13851747" title="마이앨범 담기">13851747</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <a class="btn_avi" href="javascript:mnetCom.vodPlay('13851747');" title="노력 - 영상">영상</a>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('13851747');" title="노력 - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a class="disabled" href="javascript:;" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('13851747','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" class="disabled">MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>, <tr>
#  <td class="MMLItemCheck"><input id="" name="songIdx" title="The Reason - 선택" type="checkbox" value="30628076"/></td>
#  <td class="MMLItemRank"><div class="MMLIRankNum_Box"><span class="MMLI_RankNum MMLI_RankNum_50">50위</span></div><td class="MMLItemUpdown"><div class="MMLIUpdown_Box"><span class="MMLI_Updown MMLI_Updown_Down">상승</span><span class="MMLI_UpdownNum">4</span></div></td></td>
#  <td class="MMLItemTitle">
#  <div class="MMLITitle_Wrap">
#  <div class="MMLITitle_Album">
#  <a href="/album/2792052 " target="_self"><img alt="Eyes On You - 앨범" onerror="javascript:mnetImage.fnSetClipUrl(this, '0202' , '2792052', '50')" src="http://cmsimg.mnet.com/clipimage/album/50/002/792/2792052.jpg"/><span class="photoLine"></span></a>
#  </div>
#  <div class="MMLITitle_Box info">
#  <div class="MMLITitleSong_Box">
#  <a class="MMLI_SongInfo" href="/track/30628076" target="_self">The Reason - 곡정보</a><a class="MMLI_Song" href="javascript:mnetCom.aodPlay('30628076');" title="The Reason 새창">The Reason</a>
#  </div>
#  <div class="MMLITitle_Info">
#  <a class="MMLIInfo_Artist" href=" /artist/317880 " target="_self" title="GOT7 (갓세븐) - 아티스트">GOT7 (갓세븐)</a> /
#  							<a class="MMLIInfo_Album" href=" /album/2792052 " target="_self" title="Eyes On You - 앨범">Eyes On You</a>
#  </div>
#  <a class="MMLI_Mp3Add" href="javascript:mnetCom.aodPlay('30628076','add');" title="곡추가">곡추가</a>
#  </div>
#  </div>
#  </td>
#  <td class="MMLItemRecommend">
#  <div class="MMLIRecommend_Box">
#  <a class="btn_recom" href="javascript:mnetCom.recomPlay('30628076');" title="The Reason - 추천곡 (새창)">추천</a>
#  </div>
#  </td>
#  <td class="MMLItemMy">
#  <div class="MMLIMy_Box">
#  <a class="btn_add" href="javascript:;" mid="mnet_plugin" mtype="myalbum" mval="0203_30628076" title="마이앨범 담기">30628076</a>
#  </div>
#  </td>
#  <td class="MMLItemVideo">
#  <div class="MMLIVideo_Box">
#  <span class="btn_avi_off">영상이 없습니다.</span>
#  </div>
#  </td>
#  <td class="MMLItemDown">
#  <div class="MMLIDown_Box">
#  <a class="btn_mp3" href="javascript:mnetCom.mp3Down('30628076');" title="The Reason - MP3 다운로드 (새창)">MP3</a>
#  </div>
#  </td>
#  <td class="MMLItemMQS">
#  <div class="MMLmqsSel" style="display:none;">
#  <ul>
#  <li><a href="javascript:mnetCom.mp3Down('30628076','mqs');" onclick="$('.MMLmqsSel').hide();">MAQ</a></li>
#  <li><a href="javascript:mnetCom.mp3Down('30628076','cdq');" onclick="$('.MMLmqsSel').hide();">CDQ</a></li>
#  <!--li><a href="#" >MQS</a></li>
#  					<li><a href="#" >CDQ</a></li-->
#  </ul>
#  </div>
#  <div class="MMLItemMQS_Box">
#  <!--a href="javascript:mnetCom.mqsDownLayer(this);" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parent().siblings('.MMLmqsSel').show();" class="btn_mqs">원음</a-->
#  <!--a href="javascript:;" onclick="$(this).parents().siblings('.MMLmqsSel').fadeToggle();" class="btn_mqs">원음</a-->
#  <a class="btn_mqs" href="javascript:;" onclick="$('.MMLmqsSel').hide();$(this).parents().siblings('.MMLmqsSel').fadeToggle();">원음</a>
#  </div>
#  </td>
#  </tr>]

# %%
mnet=[]

for song in song_list:
    
    rank= song.find('span', class_='MMLI_RankNum').get_text().strip('위')
    num= song.find('td', class_='MMLItemUpdown').get_text()
    song_name= song.find('a', class_='MMLI_Song').get_text()
    singer= song.find('a', class_='MMLIInfo_Artist').get_text()
    album= song.find('a', class_='MMLIInfo_Album').get_text()
   
    page3 = song.find('a')['href']
    page3 = urlopen('http://www.mnet.com' + page3)
    soup3 = BeautifulSoup(page3, 'html.parser')
    s_date= soup.find('dd').find_all('p')[1].find(class_='right').get_text()
    s_date
    
    
    num=num.replace('보합0','=')
    num=num.replace('상승','+')
    num=num.replace('하락','-')
    
    mnet.append([rank, num, song_name, singer, album, s_date])
    
    print('순위: ', rank)
    print('등락: ', num)
    print('곡: ', song_name)
    print('가수: ', singer)
    print('앨범: ', album)
    print('발매일: ', s_date)
    print()
    
for song in song_list2:
    
    rank= song.find('span', class_='MMLI_RankNum').get_text().strip('위')
    num= song.find('td', class_='MMLItemUpdown').get_text()
    song_name= song.find('a', class_='MMLI_Song').get_text()
    singer= song.find('a', class_='MMLIInfo_Artist').get_text()
    album= song.find('a', class_='MMLIInfo_Album').get_text()
    
    page3 = song.find('a')['href']
    page3 = urlopen('http://www.mnet.com' + page3)
    soup3 = BeautifulSoup(page3, 'html.parser')
    s_date= soup.find('dd').find_all('p')[1].find(class_='right').get_text()
    s_date
    
    num=num.replace('보합0','=')
    num=num.replace('상승','+')
    num=num.replace('하락','-')
    
    
    mnet.append([rank, num, song_name, singer, album, s_date])
    
    print('순위: ', rank)
    print('등락: ', num)
    print('곡: ', song_name)
    print('가수: ', singer)
    print('앨범: ', album)
    print('발매일: ', s_date)
    print()
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  1
# 등락:  =
# 곡:  Look
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  2
# 등락:  =
# 곡:  사랑을 했다 (LOVE SCENARIO)
# 가수:  iKON
# 앨범:  Return
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  3
# 등락:  =
# 곡:  Jenga (Feat. Gaeko)
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  4
# 등락:  =
# 곡:  뿜뿜
# 가수:  모모랜드(MOMOLAND)
# 앨범:  GREAT!
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  5
# 등락:  =
# 곡:  별이 빛나는 밤
# 가수:  마마무(Mamamoo)
# 앨범:  Yellow Flower
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  6
# 등락:  =
# 곡:  그날처럼
# 가수:  장덕철
# 앨범:  그날처럼
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  7
# 등락:  =
# 곡:  HandClap
# 가수:  Fitz & The Tantrums
# 앨범:  Fitz and The Tantrums (Deluxe)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  8
# 등락:  +2
# 곡:  Havana (Feat. Young Thug)
# 가수:  Camila Cabello
# 앨범:  Camila
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  9
# 등락:  +1
# 곡:  그때 헤어지면 돼
# 가수:  로이킴
# 앨범:  그때 헤어지면 돼
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  10
# 등락:  +1
# 곡:  Roller Coaster
# 가수:  청하
# 앨범:  Offset
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  11
# 등락:  +2
# 곡:  내가 더 나빠
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  12
# 등락:  =
# 곡:  선물
# 가수:  멜로망스(Melomance)
# 앨범:  Moonlight
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  13
# 등락:  +1
# 곡:  비행운
# 가수:  문문(MoonMoon)
# 앨범:  LIFE IS BEAUTY FULL
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  14
# 등락:  +1
# 곡:  Bad Boy
# 가수:  Red Velvet (레드벨벳)
# 앨범:  The Perfect Red Velvet - The 2nd Album Repackage
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  15
# 등락:  =
# 곡:  너 하나만 (Feat. 효린)
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  16
# 등락:  =
# 곡:  밤이 되니까
# 가수:  펀치(Punch)
# 앨범:  밤이 되니까
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  17
# 등락:  +1
# 곡:  instagram
# 가수:  DEAN
# 앨범:  instagram
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  18
# 등락:  +3
# 곡:  You
# 가수:  멜로망스(Melomance)
# 앨범:  투유 프로젝트 - 슈가맨2 Part 2
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  19
# 등락:  +2
# 곡:  이 별
# 가수:  길구봉구
# 앨범:  Star
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  20
# 등락:  +17
# 곡:  기억의 빈자리
# 가수:  나얼
# 앨범:  기억의 빈자리
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  21
# 등락:  +1
# 곡:  너 없는 시간들
# 가수:  다비치
# 앨범:  &10
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  22
# 등락:  +1
# 곡:  Heart Shaker
# 가수:  TWICE(트와이스)
# 앨범:  Merry & Happy
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  23
# 등락:  +4
# 곡:  주인공
# 가수:  선미
# 앨범:  주인공
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  24
# 등락:  +1
# 곡:  Beautiful
# 가수:  Wanna One(워너원)
# 앨범:  1-1=0 (NOTHING WITHOUT YOU)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  25
# 등락:  +1
# 곡:  약속해요 (I.P.U.)
# 가수:  Wanna One(워너원)
# 앨범:  약속해요 (I.P.U.) - Special Theme Track
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  26
# 등락:  +4
# 곡:  Shape of You
# 가수:  Ed Sheeran
# 앨범:  ÷ (Deluxe)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  27
# 등락:  +11
# 곡:  all of my life
# 가수:  박원
# 앨범:  0M
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  28
# 등락:  +4
# 곡:  시차 (We Are) (Feat. 로꼬 & GRAY)
# 가수:  우원재
# 앨범:  시차 (We Are)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  29
# 등락:  +1
# 곡:  좋니
# 가수:  윤종신
# 앨범:  LISTEN 010 좋니
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  30
# 등락:  +3
# 곡:  LIKEY
# 가수:  TWICE(트와이스)
# 앨범:  twicetagram
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  31
# 등락:  +24
# 곡:  피카부 (Peek-A-Boo)
# 가수:  Red Velvet (레드벨벳)
# 앨범:  Perfect Velvet - The 2nd Album
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  32
# 등락:  +2
# 곡:  비도 오고 그래서 (Feat. 신용재)
# 가수:  헤이즈(Heize)
# 앨범:  /// (너 먹구름 비)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  33
# 등락:  +1
# 곡:  첫눈처럼 너에게 가겠다
# 가수:  에일리
# 앨범:  도깨비 OST Part 9
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  34
# 등락:  +10
# 곡:  #첫사랑
# 가수:  볼빨간사춘기
# 앨범:  #첫사랑
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  35
# 등락:  =
# 곡:  좋아
# 가수:  민서
# 앨범:  2017 월간 윤종신 11월호
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  36
# 등락:  +7
# 곡:  눈사람
# 가수:  정승환
# 앨범:  그리고 봄
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  37
# 등락:  +6
# 곡:  에너제틱 (Energetic)
# 가수:  Wanna One(워너원)
# 앨범:  1X1=1(TO BE ONE)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  38
# 등락:  +14
# 곡:  You Are
# 가수:  GOT7 (갓세븐)
# 앨범:  7 for 7
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  39
# 등락:  =
# 곡:  가을 안부
# 가수:  먼데이키즈(Monday Kiz)
# 앨범:  가을 안부
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  40
# 등락:  +4
# 곡:  밤편지
# 가수:  아이유(IU)
# 앨범:  밤편지
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  41
# 등락:  +15
# 곡:  Tell Me
# 가수:  인피니트
# 앨범:  TOP SEED
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  42
# 등락:  +7
# 곡:  괜찮냐고
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  43
# 등락:  +14
# 곡:  연애소설 (Feat. 아이유)
# 가수:  에픽하이 (EPIK HIGH)
# 앨범:  WE'VE DONE SOMETHING WONDERFUL
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  44
# 등락:  +4
# 곡:  네가 없는 곳
# 가수:  양요섭
# 앨범:  YANG YOSEOP 2ND MINI ALBUM `白`
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  45
# 등락:  +2
# 곡:  우리도 그들처럼
# 가수:  XIA(준수)
# 앨범:  우리도 그들처럼
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  46
# 등락:  +16
# 곡:  그리워하다
# 가수:  비투비(BTOB)
# 앨범:  Brother Act.
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  47
# 등락:  +19
# 곡:  DNA
# 가수:  방탄소년단
# 앨범:  LOVE YOURSELF 承 `Her`
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  48
# 등락:  +13
# 곡:  Closer (Feat. Halsey)
# 가수:  The Chainsmokers
# 앨범:  Collage EP
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  49
# 등락:  +10
# 곡:  REALLY REALLY
# 가수:  WINNER
# 앨범:  FATE NUMBER FOR
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  50
# 등락:  +4
# 곡:  마지막처럼
# 가수:  BLACKPINK
# 앨범:  마지막처럼
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  51
# 등락:  +8
# 곡:  There`s Nothing Holdin` Me Back
# 가수:  Shawn Mendes
# 앨범:  Illuminate (New Deluxe Ver.)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  52
# 등락:  +16
# 곡:  You Are
# 가수:  GOT7 (갓세븐)
# 앨범:  7 for 7
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  53
# 등락:  +10
# 곡:  그때의 나, 그때의 우리
# 가수:  어반 자카파(Urban Zakapa)
# 앨범:  그때의 나, 그때의 우리
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  54
# 등락:  +3
# 곡:  이슬을 머금은 나무
# 가수:  XIA
# 앨범:  Tarantallegra
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  55
# 등락:  +7
# 곡:  피카부 (Peek-A-Boo)
# 가수:  Red Velvet (레드벨벳)
# 앨범:  Perfect Velvet - The 2nd Album
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  56
# 등락:  +9
# 곡:  Tell Me
# 가수:  인피니트
# 앨범:  TOP SEED
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  57
# 등락:  +1
# 곡:  연애소설 (Feat. 아이유)
# 가수:  에픽하이 (EPIK HIGH)
# 앨범:  WE'VE DONE SOMETHING WONDERFUL
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  58
# 등락:  +18
# 곡:  우리
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  59
# 등락:  +5
# 곡:  REALLY REALLY
# 가수:  WINNER
# 앨범:  FATE NUMBER FOR
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  60
# 등락:  +6
# 곡:  덜덜덜
# 가수:  EXID
# 앨범:  Full Moon
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  61
# 등락:  +9
# 곡:  Closer (Feat. Halsey)
# 가수:  The Chainsmokers
# 앨범:  Collage EP
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  62
# 등락:  +9
# 곡:  그리워하다
# 가수:  비투비(BTOB)
# 앨범:  Brother Act.
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  63
# 등락:  +22
# 곡:  The Reason
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  64
# 등락:  +15
# 곡:  잘 살길 바래 (With DAVII)
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  65
# 등락:  +23
# 곡:  고마워
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  66
# 등락:  +22
# 곡:  DNA
# 가수:  방탄소년단
# 앨범:  LOVE YOURSELF 承 `Her`
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  67
# 등락:  +20
# 곡:  망설이다
# 가수:  GOT7 (갓세븐)
# 앨범:  Eyes On You
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  68
# 등락:  +5
# 곡:  매일 듣는 노래 (A Daily Song)
# 가수:  황치열
# 앨범:  Be ordinary
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  69
# 등락:  +15
# 곡:  MIANHAE
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  70
# 등락:  +2
# 곡:  다른사람을 사랑하고 있어
# 가수:  수지(SUZY)
# 앨범:  Faces of Love
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  71
# 등락:  +1
# 곡:  그 사람을 아나요
# 가수:  임창정
# 앨범:  그 사람을 아나요
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  72
# 등락:  +14
# 곡:  불장난
# 가수:  BLACKPINK
# 앨범:  SQUARE TWO
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  73
# 등락:  +6
# 곡:  노력
# 가수:  박원
# 앨범:  1/24
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  74
# 등락:  +2
# 곡:  봄날
# 가수:  방탄소년단
# 앨범:  YOU NEVER WALK ALONE
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  75
# 등락:  +4
# 곡:  널 너무 모르고
# 가수:  헤이즈(Heize)
# 앨범:  /// (너 먹구름 비)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  76
# 등락:  +5
# 곡:  나의 사춘기에게
# 가수:  볼빨간사춘기
# 앨범:  Red Diary Page.1
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  77
# 등락:  +2
# 곡:  별
# 가수:  양요섭
# 앨범:  YANG YOSEOP 2ND MINI ALBUM `白`
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  78
# 등락:  +10
# 곡:  바보야
# 가수:  허각
# 앨범:  바보야
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  79
# 등락:  +2
# 곡:  남이 될 수 있을까
# 가수:  볼빨간사춘기
# 앨범:  남이 될 수 있을까
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  80
# 등락:  =
# 곡:  너였다면
# 가수:  정승환
# 앨범:  또 오해영 OST Part 5
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  81
# 등락:  +7
# 곡:  Tarantallegra (Feat. Flowsik of Aziatix)
# 가수:  XIA
# 앨범:  Tarantallegra
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  82
# 등락:  +3
# 곡:  Love Yourself
# 가수:  Justin Bieber
# 앨범:  Purpose
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  83
# 등락:  =
# 곡:  좋았을걸
# 가수:  헤이즈(Heize)
# 앨범:  슬기로운 감빵생활 OST Part 5
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  84
# 등락:  +2
# 곡:  Marry Me
# 가수:  마크툽(Maktub)
# 앨범:  마크툽 프로젝트 Vol. 3
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  85
# 등락:  +16
# 곡:  My Blossom
# 가수:  소유(SOYOU)
# 앨범:  My Blossom
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  86
# 등락:  +7
# 곡:  사랑하지 않은 것처럼
# 가수:  버즈
# 앨범:  `Be One` - Buzz The 1st Mini Album
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  87
# 등락:  =
# 곡:  답장
# 가수:  김동률
# 앨범:  답장
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  88
# 등락:  +8
# 곡:  Blue
# 가수:  볼빨간사춘기
# 앨범:  Red Diary Page.1
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  89
# 등락:  +4
# 곡:  팔레트 (Feat. G-DRAGON)
# 가수:  아이유(IU)
# 앨범:  Palette
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  90
# 등락:  +1
# 곡:  애쓰지 마요
# 가수:  박보람
# 앨범:  애쓰지 마요
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  91
# 등락:  +13
# 곡:  꽃이야
# 가수:  JBJ
# 앨범:  True Colors
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  92
# 등락:  +3
# 곡:  좋다고 말해
# 가수:  볼빨간사춘기
# 앨범:  Full Album RED PLANET [Hidden Track]
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  93
# 등락:  +2
# 곡:  후유증
# 가수:  민경훈
# 앨범:  후유증
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  94
# 등락:  +4
# 곡:  갖고 싶어
# 가수:  Wanna One(워너원)
# 앨범:  1-1=0 (NOTHING WITHOUT YOU)
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  95
# 등락:  +1
# 곡:  무제(無題) (Untitled, 2014)
# 가수:  G-DRAGON
# 앨범:  권지용
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  96
# 등락:  +4
# 곡:  처음부터 너와 나
# 가수:  볼빨간사춘기
# 앨범:  군주 - 가면의 주인 OST Part 2
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  97
# 등락:  +1
# 곡:  빈차 (Feat. 오혁)
# 가수:  에픽하이 (EPIK HIGH)
# 앨범:  WE'VE DONE SOMETHING WONDERFUL
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  98
# 등락:  +1
# 곡:  오늘 취하면 (Feat. 창모) (Prod. SUGA)
# 가수:  수란(Suran)
# 앨범:  WINE
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  99
# 등락:  =
# 곡:  얼굴 찌푸리지 말아요
# 가수:  하이라이트(Highlight)
# 앨범:  CAN YOU FEEL IT?
# 발매일:  2018.03.08
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 순위:  100
# 등락:  +4
# 곡:  바람
# 가수:  헤이즈(Heize)
# 앨범:  바람
# 발매일:  2018.03.08

# %%
import pandas as pd

df=pd.DataFrame(mnet, columns=['순위','등락','곡','가수','앨범','발매일'])
df.set_index('순위', inplace=True)

df
# Out:
#       등락                                         곡                   가수  \
# 순위
# 1      =                                      Look           GOT7 (갓세븐)
# 2      =                    사랑을 했다 (LOVE SCENARIO)                 iKON
# 3      =                       Jenga (Feat. Gaeko)           헤이즈(Heize)
# 4      =                                        뿜뿜       모모랜드(MOMOLAND)
# 5      =                                  별이 빛나는 밤         마마무(Mamamoo)
# 6      =                                      그날처럼                  장덕철
# 7      =                                  HandClap  Fitz & The Tantrums
# 8     +2                 Havana (Feat. Young Thug)       Camila Cabello
# 9     +1                                 그때 헤어지면 돼                  로이킴
# 10    +1                            Roller Coaster                   청하
# 11    +2                                   내가 더 나빠           헤이즈(Heize)
# 12     =                                        선물      멜로망스(Melomance)
# 13    +1                                       비행운         문문(MoonMoon)
# 14    +1                                   Bad Boy    Red Velvet (레드벨벳)
# 15     =                          너 하나만 (Feat. 효린)           GOT7 (갓세븐)
# 16     =                                    밤이 되니까            펀치(Punch)
# 17    +1                                 instagram                 DEAN
# 18    +3                                       You      멜로망스(Melomance)
# 19    +2                                       이 별                 길구봉구
# 20   +17                                   기억의 빈자리                   나얼
# 21    +1                                  너 없는 시간들                  다비치
# 22    +1                              Heart Shaker          TWICE(트와이스)
# 23    +4                                       주인공                   선미
# 24    +1                                 Beautiful       Wanna One(워너원)
# 25    +1                             약속해요 (I.P.U.)       Wanna One(워너원)
# 26    +4                              Shape of You           Ed Sheeran
# 27   +11                            all of my life                   박원
# 28    +4             시차 (We Are) (Feat. 로꼬 & GRAY)                  우원재
# 29    +1                                        좋니                  윤종신
# 30    +3                                     LIKEY          TWICE(트와이스)
# ..   ...                                       ...                  ...
# 71    +1                                 그 사람을 아나요                  임창정
# 72   +14                                       불장난            BLACKPINK
# 73    +6                                        노력                   박원
# 74    +2                                        봄날                방탄소년단
# 75    +4                                  널 너무 모르고           헤이즈(Heize)
# 76    +5                                  나의 사춘기에게               볼빨간사춘기
# 77    +2                                         별                  양요섭
# 78   +10                                       바보야                   허각
# 79    +2                                남이 될 수 있을까               볼빨간사춘기
# 80     =                                      너였다면                  정승환
# 81    +7  Tarantallegra (Feat. Flowsik of Aziatix)                  XIA
# 82    +3                             Love Yourself        Justin Bieber
# 83     =                                      좋았을걸           헤이즈(Heize)
# 84    +2                                  Marry Me          마크툽(Maktub)
# 85   +16                                My Blossom            소유(SOYOU)
# 86    +7                               사랑하지 않은 것처럼                   버즈
# 87     =                                        답장                  김동률
# 88    +8                                      Blue               볼빨간사춘기
# 89    +4                      팔레트 (Feat. G-DRAGON)              아이유(IU)
# 90    +1                                    애쓰지 마요                  박보람
# 91   +13                                       꽃이야                  JBJ
# 92    +3                                    좋다고 말해               볼빨간사춘기
# 93    +2                                       후유증                  민경훈
# 94    +4                                     갖고 싶어       Wanna One(워너원)
# 95    +1                   무제(無題) (Untitled, 2014)             G-DRAGON
# 96    +4                                 처음부터 너와 나               볼빨간사춘기
# 97    +1                             빈차 (Feat. 오혁)     에픽하이 (EPIK HIGH)
# 98    +1            오늘 취하면 (Feat. 창모) (Prod. SUGA)            수란(Suran)
# 99     =                               얼굴 찌푸리지 말아요     하이라이트(Highlight)
# 100   +4                                        바람           헤이즈(Heize)
#
#                                                    앨범         발매일
# 순위
# 1                                         Eyes On You  2018.03.08
# 2                                              Return  2018.03.08
# 3                                                  바람  2018.03.08
# 4                                              GREAT!  2018.03.08
# 5                                       Yellow Flower  2018.03.08
# 6                                                그날처럼  2018.03.08
# 7                      Fitz and The Tantrums (Deluxe)  2018.03.08
# 8                                              Camila  2018.03.08
# 9                                           그때 헤어지면 돼  2018.03.08
# 10                                             Offset  2018.03.08
# 11                                                 바람  2018.03.08
# 12                                          Moonlight  2018.03.08
# 13                                LIFE IS BEAUTY FULL  2018.03.08
# 14   The Perfect Red Velvet - The 2nd Album Repackage  2018.03.08
# 15                                        Eyes On You  2018.03.08
# 16                                             밤이 되니까  2018.03.08
# 17                                          instagram  2018.03.08
# 18                              투유 프로젝트 - 슈가맨2 Part 2  2018.03.08
# 19                                               Star  2018.03.08
# 20                                            기억의 빈자리  2018.03.08
# 21                                            &10      2018.03.08
# 22                                      Merry & Happy  2018.03.08
# 23                                                주인공  2018.03.08
# 24                        1-1=0 (NOTHING WITHOUT YOU)  2018.03.08
# 25                약속해요 (I.P.U.) - Special Theme Track  2018.03.08
# 26                                         ÷ (Deluxe)  2018.03.08
# 27                                                 0M  2018.03.08
# 28                                        시차 (We Are)  2018.03.08
# 29                                      LISTEN 010 좋니  2018.03.08
# 30                                        twicetagram  2018.03.08
# ..                                                ...         ...
# 71                                          그 사람을 아나요  2018.03.08
# 72                                         SQUARE TWO  2018.03.08
# 73                                               1/24  2018.03.08
# 74                               YOU NEVER WALK ALONE  2018.03.08
# 75                                      /// (너 먹구름 비)  2018.03.08
# 76                                   Red Diary Page.1  2018.03.08
# 77                     YANG YOSEOP 2ND MINI ALBUM `白`  2018.03.08
# 78                                                바보야  2018.03.08
# 79                                         남이 될 수 있을까  2018.03.08
# 80                                   또 오해영 OST Part 5  2018.03.08
# 81                                      Tarantallegra  2018.03.08
# 82                                            Purpose  2018.03.08
# 83                               슬기로운 감빵생활 OST Part 5  2018.03.08
# 84                                    마크툽 프로젝트 Vol. 3  2018.03.08
# 85                                         My Blossom  2018.03.08
# 86                 `Be One` - Buzz The 1st Mini Album  2018.03.08
# 87                                                 답장  2018.03.08
# 88                                   Red Diary Page.1  2018.03.08
# 89                                            Palette  2018.03.08
# 90                                             애쓰지 마요  2018.03.08
# 91                                        True Colors  2018.03.08
# 92               Full Album RED PLANET [Hidden Track]  2018.03.08
# 93                                                후유증  2018.03.08
# 94                        1-1=0 (NOTHING WITHOUT YOU)  2018.03.08
# 95                                                권지용  2018.03.08
# 96                             군주 - 가면의 주인 OST Part 2  2018.03.08
# 97                     WE'VE DONE SOMETHING WONDERFUL  2018.03.08
# 98                                               WINE  2018.03.08
# 99                                   CAN YOU FEEL IT?  2018.03.08
# 100                                                바람  2018.03.08
#
# [100 rows x 5 columns]

# %%
page3 = song.find('a')['href']
page3 = urlopen('http://www.mnet.com' + page3)

soup3 = BeautifulSoup(page3, 'html.parser')
s_date= soup.find('dd').find_all('p')[1].find(class_='right').get_text()
s_date
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# '2018.03.08'
