# %%
from bs4 import BeautifulSoup

from urllib.request import urlopen

page = urlopen('https://music.bugs.co.kr/chart/track/day/total') # 벅스 노래 차트 페이지 가져옴

soup = BeautifulSoup(page, 'html.parser')

#print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <!-- bgsweb-www903.svr.toastmaker.net -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드" name="keywords">
#    <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" name="description">
#     <!-- bgsweb-www903.svr.toastmaker.net -->
#     <script type="text/javascript">
#      if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlJs = "/js";
# 	var g_urlMe = "https://music.bugs.co.kr/user";
# 	var g_urlThumbnail = "http://nboardr.bugs.co.kr/thumbnail";
# 	var g_urlOpenalbum = "https://music.bugs.co.kr/openalbum";
# 	var g_urlClipimg = "//image.bugsm.co.kr";
# 	//var g_urlLikes = "https://music.bugs.co.kr/like";
# 	//var g_urlPlaylists = "https://music.bugs.co.kr/playlist";
# 	var g_urlAward = "http://award.bugs.co.kr";
# 	var g_urlLikes = "https://music.bugs.co.kr/like";
# 	var g_urlPlaylists = "https://music.bugs.co.kr/playlist"
# 	var g_urlListen = "https://music.bugs.co.kr/listen";
# 	var g_urlMyinfo = "https://music.bugs.co.kr/myinfo";
# 	var g_urlSecureMyinfo = "https://secure.bugs.co.kr/myinfo";
# 	var g_urlSearch = "https://music.bugs.co.kr/search";
# 	var g_urlChart = "https://music.bugs.co.kr/chart";
# 	var g_urlPay = "https://music.bugs.co.kr/pay";
# 	var g_urlBilling = "https://pay.bugs.co.kr";
# 	var g_urlPartner = "https://www.bugs.co.kr/Partner";
# 	var g_urlSecurePay = "https://secure.bugs.co.kr/pay";
# 	var g_urlOtu = "https://notu.bugs.co.kr";
# 	var g_urlBoard = "http://board.bugs.co.kr/notice";
# 	var g_urlEvent = "https://music.bugs.co.kr/event";
# 	var g_storageServerRead = "http://nboardr.bugs.co.kr";
# 	var g_storageServerWrite = "https://nboardw.bugs.co.kr";
# 	var g_urlPanel = "https://music.bugs.co.kr/panel";
# 	var g_urlAjax = "https://music.bugs.co.kr";
# 	var g_urlAppsvr = "http://appsvr.bugs.co.kr";
# 	var g_urlMusicPd = "https://music.bugs.co.kr/musicpd";
# 	var g_urlGenre = "https://music.bugs.co.kr/genre";
# 	var g_urlMLounge = "https://mlounge.bugs.co.kr";
# 	var g_urlNinanoclub = "http://ninanoclub.bugs.co.kr";
# 	var g_urlM = "https://m.bugs.co.kr";
# 	var g_urlDl = "https://dl.bugs.co.kr";
#
# 	var g_env = "svc";
#
# 	var g_isLogged = false;
# 	var g_msrl = false;
#     </script>
#     <!-- cache.filePacking : false -->
#     <!-- [open_lib_js] origin list / start -->
#     <script src="/js/jquery/jquery-1.11.2.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-browser-plugin.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-migrate-1.2.1.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.mousewheel.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.jscrollpane.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-ui-1.11.4.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-bugs-extends.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.animateSprite.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.dotdotdot.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.json.min-2.5.1.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.easing-1.3.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/swiper.jquery.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/lib/js.cookie-1.5.1.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.form.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.fileupload.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.iframe-transport.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/html5/html5shiv.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/code-snippet.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/raphael.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/chart.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <!-- [open_lib_js] origin list / end -->
#     <!-- [bugs_desktopLib_js] origin list / start -->
#     <script src="/js/commons.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/ui.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/utils/music.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/utils/suggest.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/utils/notice.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/me/likes.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/m/kakao-1.0.8.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/log/clickLog.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/me/playlist.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/log/makePCookie.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/player/min/mvHtml5Player.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/lib/kakao.min.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.navigator.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.scroll.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.datepicker.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <!-- [bugs_desktopLib_js] origin list / end -->
#     <!-- [bugs_newLib_js] origin list / start -->
#     <script src="/js/bugs/bugs.alert.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.app.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.sns.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.mobile.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.data.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.layer.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.string.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.object.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.play.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.debug.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.location.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.object.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.utils.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.useragent.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.member.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.html.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.image.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.wiselog.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.userReaction.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.userReport.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.bside.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.comment.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.handler.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.scroll.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.musiccast.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.encryption.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.number.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.story.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.graph.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.recommend.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.like.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.recommend.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.like.js?env=svc&amp;_t_s_=20180315-1606" type="text/javascript">
#     </script>
#     <!-- [bugs_newLib_js] origin list / end -->
#     <!-- clova issue로 분기 -->
#     <script src="/js/swfobject/swfobject.js" type="text/javascript">
#     </script>
#     <!-- java enum to js -->
#     <script src="https://music.bugs.co.kr/js/enumtojs" type="text/javascript">
#     </script>
#     <script src="/js/utils/personMedia.js?version=20161212" type="text/javascript">
#     </script>
#     <script src="/js/me/playlist.js?version=20151102" type="text/javascript">
#     </script>
#     <script src="/js/log/makePCookie.js" type="text/javascript">
#     </script>
#     <script src="/js/player/min/mvHtml5Player.min.js?version=20180315:1606" type="text/javascript">
#     </script>
#     <!-- <script type="text/javascript" src="/js/utils/fileUploader.js"></script> -->
#     <script src="/js/lib/kakao.min.js" type="text/javascript">
#     </script>
#     <!-- <script type="text/javascript" src="/js/lib/kakao.story.min.js"></script> -->
#     <!--[if gt IE 7]>
# 	<script type="text/javascript" src="/js/jquery/jquery.ba-hashchange.min.js"></script>
# <![endif]-->
#     <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/js/html5/html5shiv.min.js"></script>
# 	<script type="text/javascript" src="/js/json2.js"></script>
# <![endif]-->
#     <!-- [bugs_commonStyle_css] origin list / start -->
#     <link href="/css/jquery/jquery.jscrollpane.css?env=svc&amp;_t_s_=20180315-1606" rel="stylesheet" type="text/css"/>
#     <link href="/css/jquery/jquery-ui-1.11.4.css?env=svc&amp;_t_s_=20180315-1606" rel="stylesheet" type="text/css"/>
#     <link href="/css/bugs/bugs.image.css?env=svc&amp;_t_s_=20180315-1606" rel="stylesheet" type="text/css"/>
#     <link href="/css/playerMV.css?env=svc&amp;_t_s_=20180315-1606" rel="stylesheet" type="text/css"/>
#     <link href="/css/toast/tui.chart/chart.min.connect.css?env=svc&amp;_t_s_=20180315-1606" rel="stylesheet" type="text/css"/>
#     <!-- [bugs_commonStyle_css] origin list / end -->
#     <meta content="summary_large_image" name="twitter:card"/>
#     <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:url"/>
#     <meta content="벅스!에서 다양한 음악컨텐츠를 볼 수 있습니다." name="twitter:description"/>
#     <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" name="twitter:image:src"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:iphone"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:ipad"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:googleplay"/>
#     <!-- open graph -->
#     <meta content="122936701116206" property="fb:app_id">
#      <meta content="슈퍼사운드 벅스" property="og:title">
#       <meta content="https://music.bugs.co.kr/chart/track/day/total" property="og:url">
#        <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" property="og:image">
#         <meta content="벅스!" property="og:site_name">
#          <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" property="og:description">
#           <meta content="website" property="og:type">
#            <meta content="ko_KR" property="og:locale"/>
#            <!-- app link -->
#            <meta content="https://music.bugs.co.kr/chart/track/day/total" property="al:ios:url"/>
#            <meta content="348555322" property="al:ios:app_store_id"/>
#            <meta content="벅스(ios)" property="al:ios:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/track/day/total" property="al:iphone:url"/>
#            <meta content="348555322" property="al:iphone:app_store_id"/>
#            <meta content="벅스(iphone)" property="al:iphone:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/track/day/total" property="al:ipad:url"/>
#            <meta content="420598915" property="al:ipad:app_store_id"/>
#            <meta content="벅스(ipad)" property="al:ipad:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/track/day/total" property="al:android:url"/>
#            <meta content="com.neowiz.android.bugs" property="al:android:package"/>
#            <meta content="벅스(android)" property="al:android:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/track/day/total" property="al:web:url">
#             <!-- twitter card -->
#             <meta content="summary_large_image" name="twitter:card"/>
#             <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:url"/>
#             <meta content="@Bugs_play" name="twitter:site"/>
#             <meta content="슈퍼사운드 벅스" name="twitter:title"/>
#             <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" name="twitter:description"/>
#             <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" name="twitter:image:src"/>
#             <meta content="벅스" name="twitter:app:name:iphone"/>
#             <meta content="벅스" name="twitter:app:name:ipad"/>
#             <meta content="벅스" name="twitter:app:name:googleplay"/>
#             <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:app:url:iphone"/>
#             <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:app:url:ipad"/>
#             <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:app:url:googleplay"/>
#             <meta content="348555322" name="twitter:app:id:iphone"/>
#             <meta content="420598915" name="twitter:app:id:ipad"/>
#             <meta content="com.neowiz.android.bugs" name="twitter:app:id:googleplay"/>
#             <link href="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" rel="image_src"/>
#             <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" itemprop="image"/>
#             <!-- bugs.sns 용 공유 파라미터 -->
#             <script>
#              var bugsSnsParam = {
# 		 			url : "https://music.bugs.co.kr/chart/track/day/total",
# 		 			text : "슈퍼사운드 벅스",
# 		 			img : "https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png",
# 		 			hashTag : "#벅스",
# 		 			corner : "벅스"
# 		 		}
#             </script>
#             <span itemscope="" itemtype="http://schema.org/Organization">
#              <link href="https://music.bugs.co.kr" itemprop="url"/>
#              <a href="https://www.facebook.com/bugsplay" itemprop="sameAs">
#              </a>
#              <a href="http://blog.bugs.co.kr" itemprop="sameAs">
#              </a>
#              <a href="https://twitter.com/bugs_play" itemprop="sameAs">
#              </a>
#              <a href="https://itunes.apple.com/kr/app/bugs/id348555322?mt=8" itemprop="sameAs">
#              </a>
#              <a href="https://play.google.com/store/apps/details?id=com.neowiz.android.bugs" itemprop="sameAs">
#              </a>
#             </span>
#             <meta content="ko_KR" property="og:locale">
#              <title>
#               벅스차트 &gt; 곡 차트 &gt; 일간 &gt; 전체 장르 - 벅스
#              </title>
#              <meta content="no-cache" http-equiv="Cache-Control"/>
#              <meta content="no-cache" http-equiv="Pragma"/>
#              <meta content="0" http-equiv="Expires"/>
#              <!-- 네이버 검색용 메타 -->
#              <meta content="0582453e44d4365f5e597d1580911be7a3173ef7" name="naver-site-verification">
#               <link for="bugs" href="/css/wbugsWhatshot.css?version=20180315-16_bgsweb-www903.svr.toastmaker.net" rel="stylesheet" type="text/css"/>
#               <!-- commonUtils.ftl -->
#               <!--[if gt IE 7]>
# 	<link rel="stylesheet" href="/css/fonts.css" type="text/css">
# <![endif]-->
#               <?if !IE?>
#               <link href="/css/fonts.css" rel="stylesheet" type="text/css"/>
#               <?endif?>
#               <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="shortcut icon" type="image/x-icon">
#                <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="icon" type="image/x-icon">
#                 <script src="//wcs.naver.net/wcslog.js" type="text/javascript">
#                 </script>
#                 <script src="/js/log/naver_marketing.js">
#                 </script>
#                 <script src="/js/log/ace_counter.js">
#                 </script>
#                 <script>
#                  $(document).ready(function(){
# 		$("[dotdotdot=Y]").dotdotdot({
# 			watch : "window"
# 		});
# 	});
#                 </script>
#                </link>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="skipNav">
#    <a href="#container" onclick="$('#container').attr('tabIndex','-1');$('#container').focus();$('body,html').scrollTop(0);return false;">
#     <span>
#      본문 바로가기
#     </span>
#    </a>
#    <a href="#gnb" onclick="bugs.navigator.setLeftMenuShow(true,true);$('#gnb').attr('tabIndex','-1');$('#gnb').focus();return false;">
#     <span>
#      메뉴 바로가기
#     </span>
#    </a>
#    <a href="#loginHeader" onclick="$('#loginHeader a:first-of-type').attr('tabIndex','-1');$('#loginHeader a:first-of-type').focus();return false;">
#     <span>
#      로그인 바로가기
#     </span>
#    </a>
#    <a href="#footer" onclick="$('#footer').attr('tabIndex','-1');$('#footer').focus();return false;">
#     <span>
#      하단 정보 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="wrap">
#    <script>
#     $(document).ready(function(){
# 					if('' == ""){
# 				bugs.searchBoxAd.init();
# 				bugs.searchBoxAd.checkInput();
# 				bugs.searchBoxAd.inputBlur();
# 				bugs.searchBoxAd.deleteText();
# 			}
#
# 		popWebPlayerNotification();
#
# 		bugs.suggest.close();
# 		var headerCommonBanner = '[{"content_id2":"","weight":20,"album":null,"link":"http://music.bugs.co.kr/radio/musiccast/episode/10799","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521083209000,"minutes":6,"seconds":49,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"title":"주노드라마 12화","expire_day":0,"regdate":{"time":1521080249000,"minutes":17,"seconds":29,"hours":11,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521255600000,"minutes":0,"seconds":0,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":6,"date":17},"banner_id":51165,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/165/51/0/51165.jpg","upd_dt":"","view_start_date":{"time":1521039600000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15}},{"content_id2":"","weight":20,"album":null,"link":"https://music.bugs.co.kr/musicpd/albumview/26589","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521077323000,"minutes":28,"seconds":43,"hours":10,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"title":"죽기 전에 꼭 들어야 할 쳄발로 명곡","expire_day":0,"regdate":{"time":1521077323000,"minutes":28,"seconds":43,"hours":10,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521428400000,"minutes":0,"seconds":0,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":1,"date":19},"banner_id":51155,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/155/51/0/51155.jpg","upd_dt":"","view_start_date":{"time":1521039600000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15}},{"content_id2":"","weight":20,"album":null,"link":"http://music.bugs.co.kr/musicpd/albumview/26479","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521018546000,"minutes":9,"seconds":6,"hours":18,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14},"title":"NCT 2018 프로젝트 필청트랙 듣고 선물은 덤~","expire_day":0,"regdate":{"time":1521018200000,"minutes":3,"seconds":20,"hours":18,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521126000000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":5,"date":16},"banner_id":51134,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/134/51/0/51134.jpg","upd_dt":"","view_start_date":{"time":1520953200000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14}},{"content_id2":"","weight":20,"album":null,"link":"https://music.bugs.co.kr/specialView/concert/FGOS1OHVD0DAZ6RQC3RY","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521010291000,"minutes":51,"secon ...
#
# 		if(headerCommonBanner != ""){
# 			window._headerCommonBannerMainList = bugs.utils.parseJson(headerCommonBanner.split("||")[0]);
# 			window._headerCommonBannerSubList = bugs.utils.parseJson(headerCommonBanner.split("||")[1]);
# 		}
#
# 		headerCommonBannerLoad(location.href);
#
# 		if(bugs.cookie.get("hasCouponEmailID") == "1"){
# 			$("#no_coupon_text").append('<a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D26048%26categoryNo%3D4600" class="linkFAQ" target="_blank">구매한 이용권이 보이지 않는다면?</a>');
# 		}
# 	});
#
# 	function popWebPlayerNotification() {
# 		var flag = Cookies.get("wpn");
# 		if(!flag)
# 			$(".slogan .tip").show();
# 		else
# 			$(".slogan .tip").hide();
# 	};
#
# 	function closeWebPlayerNotification() {
# 		Cookies.set("wpn", "Y", {expires:365*50, path:"/", domain:document.domain});
# 		$(".slogan .tip").hide();
# 	}
#
# 	function headerCommonBannerLoad(url){
# // 		url = window.location.href; //테스트용
#
# 		if(url.indexOf("?") > 0){
# 			url = url.substring(0,url.indexOf("?"))
# 		}
#
# 		if(url == g_urlWww || url == g_urlWww+"/" || url == g_urlWww+"/index" || url == g_urlMusic){ //main
# 			if(window._headerCommonBannerMainList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerMainList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+ bugs.common_util.setLinkUrlWiseLog(selectedBanner.link, "M_header_03_03") +'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
#
# 		}else{ //sub
# 			if(window._headerCommonBannerSubList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerSubList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+selectedBanner.link+'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
# 		}
#
# 	};
#    </script>
#    <header id="header">
#     <!--[if lte IE 7]>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('#wrap').addClass('commonHeaderIEBrowser');
# 	});
# </script>
#
# <div class="IEBrowserUnavailable">
# 	안정적인 서비스 이용을 위해 브라우저를 최신 버전으로 업데이트 해주세요. <a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D31944%26categoryNo%3D4622">자세한 안내 보기 &gt;</a>
# </div>
#
# <![endif]-->
#     <aside class="layer layerSettingPlayer guide title" style="display:none;">
#      <div class="box-shadow">
#      </div>
#      <header class="layer-title">
#       <h1>
#        안내
#       </h1>
#      </header>
#      <section class="layerContents">
#       <p class="message">
#        음악을 재생할 플레이어를 선택해 주세요.
#        <br/>
#        벅스 웹상단 &gt;
#        <strong>
#         플레이어 선택
#        </strong>
#        에서 플레이어를 변경할 수 있습니다.
#       </p>
#       <fieldset>
#        <div class="radioChk">
#         <input checked="checked" id="radio_player_web2" name="radio_player_type2" type="radio" value="WEB"/>
#         <label for="radio_player_web2">
#          웹 플레이어
#         </label>
#        </div>
#        <div class="radioChk">
#         <input id="radio_player_mac2" name="radio_player_type2" type="radio" value="MAC"/>
#         <label for="radio_player_mac2">
#          벅스 플레이어 (프로그램 설치 필요)
#         </label>
#         <p>
#          v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.
#          <br/>
#          <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">
#           [설치 안내 바로가기]
#          </a>
#         </p>
#        </div>
#       </fieldset>
#       <p class="agreeCheck">
#        <input id="setPlayerSelectionConfirm" name="setPlayer" type="checkbox"/>
#        <label for="setPlayerSelectionConfirm">
#         항상 선택한 플레이어로 재생
#        </label>
#       </p>
#       <p class="btns">
#        <button class="btnNormal" type="ok">
#         확인
#        </button>
#       </p>
#      </section>
#      <button class="btnClose" type="cancel">
#       닫기
#      </button>
#     </aside>
#     <!-- //플레이어 선택 설정 안내 -->
#     <aside class="layer layerSettingPlayer selectPlayer title" style="display:none;">
#      <div class="box-shadow">
#      </div>
#      <header class="layer-title">
#       <h1>
#        플레이어 선택
#       </h1>
#      </header>
#      <section class="layerContents">
#       <p class="message">
#        음악을 재생할 플레이어를 선택해 주세요.
#       </p>
#       <fieldset>
#        <div class="radioChk">
#         <input checked="checked" id="radio_player_web1" name="radio_player_type1" type="radio" value="WEB"/>
#         <label for="radio_player_web1">
#          웹 플레이어
#         </label>
#        </div>
#        <div class="radioChk">
#         <input id="radio_player_mac1" name="radio_player_type1" type="radio" value="MAC"/>
#         <label for="radio_player_mac1">
#          벅스 플레이어 (프로그램 설치 필요)
#         </label>
#         <p>
#          v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.
#          <br/>
#          <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">
#           [설치 안내 바로가기]
#          </a>
#         </p>
#        </div>
#       </fieldset>
#       <p class="btns">
#        <button class="btnNormal" type="ok">
#         확인
#        </button>
#       </p>
#      </section>
#      <button class="btnClose" type="cancel">
#       닫기
#      </button>
#     </aside>
#     <!-- //플레이어 선택 안내 -->
#     <!--
# <aside class="layer layerPlayingPlayer" style="display:none;">
# 	<div class="box-shadow"></div>
#
# 	<section class="layerContents">
# 		<strong class="message">벅스 플레이어로 재생됩니다.</strong>
# 		<ul>
# 			<li>벅스 웹상단 &gt; 플레이어 선택에서 플레이어를 변경할 수 있습니다.</li>
# 			<li>혹시 벅스 플레이어가 실행되지 않는다면? <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" onclick="$('.layerPlayingPlayer').hide();" target="_blank">[설치 안내 바로가기]</a></li>
# 		</ul>
# 	</section>
# </aside>
# -->
#     <script type="text/javascript">
#      //	var ua = navigator.userAgent;
# //	window._isMacBrowser = navigator.userAgent.search("Mac") > -1;
# //	window._isMacPlayerLinked = /Mac OS X 11_/.test(ua)
# //				|| /Mac OS X 12_/.test(ua)
# //				|| (/Mac OS X 10_/.test(ua) && !/Mac OS X 10_10/.test(ua) && !/Mac OS X 10_9/.test(ua) && !/Mac OS X 10_8/.test(ua) && !/Mac OS X 10_7/.test(ua) && !/Mac OS X 10_6/.test(ua) && !/Mac OS X 10_5/.test(ua)
# //														&& !/Mac OS X 10_4/.test(ua) && !/Mac OS X 10_3/.test(ua) && !/Mac OS X 10_2/.test(ua));
#
# 	var goServiceGuidePlayerPage = function(){
# 		if(navigator.platform.indexOf('Win') > -1){
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer";
# 		}else{
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer";
# 		}
# 	}
#
# 	$(document).ready(function() {
# 		showMacPlayerSelection();
# 	});
#
# 	var showMacPlayerSelection = function() {
# 		if(bugs.music.isMacPlayerSupport()) {
# 			$(".slogan .selectPlayer").show();
# 			$(".slogan .bugsPlayer").hide();
#
# 			var dp = bugs.cookie.get('defaultPlayer') || "";
#
# 			updateHeaderPlayerMenu(dp);
# 		} else {
# 			$(".slogan .selectPlayer").hide();
# 			$(".slogan .bugsPlayer").show();
# 		}
# 	}
#
# 	var updateHeaderPlayerMenu = function(type) {
# 		$("#headerWebPlayer").hide();
# 		$("#headerMacPlayer").hide();
#
# 		if(type == "MAC") {
# 			$("#headerMacPlayer").show();
# 		} else { // if(type == "" || type == "WEB") {
# 			$("#headerWebPlayer").show();
# 			$("#headerWebPlayer").removeAttr("onclick");
# 			$("#headerWebPlayer").unbind("click").bind("click", function() {
# 				bugs.music.popWebPlayer();
# 				bugs.wiselog.area('M_header_02_20');
# 				return false;
# 			});
# 		}
# 	}
#     </script>
#     <div class="top">
#      <div class="slogan">
#       <a class="nabi" href="https://music.bugs.co.kr/nabi?wl_ref=M_header_02_16" target="_blank">
#        <span class="icon">
#        </span>
#        나비프로젝트
#       </a>
#       <a class="supersound" href="https://music.bugs.co.kr/event/promotion/supersound/index?wl_ref=M_header_02_01" target="_blank">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        슈퍼사운드 벅스
#       </a>
#       <a aria-label="새창" class="openPlayer" href="javascript:;" id="headerWebPlayer" onclick="javascript:bugs.music.popWebPlayer();bugs.wiselog.area('M_header_02_13');return false;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        웹 플레이어
#       </a>
#       <a class="openPlayer" href="bugs3://app/wakeup" id="headerMacPlayer" onclick="bugs.wiselog.area('M_header_02_18');" style="display:none;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        벅스 플레이어
#       </a>
#       <span class="bugsPlayer" style="display:none;">
#        <span class="bar">
#        </span>
#        <a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_14');}catch(e){} goServiceGuidePlayerPage();">
#         벅스 플레이어
#        </a>
#       </span>
#       <a aria-label="새창" class="selectPlayer" href="javascript:;" onclick="bugs.ui.showPlayerSettingLayer();bugs.wiselog.area('M_header_02_19');" style="display:none;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        플레이어 선택
#       </a>
#      </div>
#      <div class="rightGroup">
#       <div class="more">
#        <a href="http://help.bugs.co.kr" onclick="try{bugs.wiselog.area('M_header_02_06');}catch(e){}">
#         고객센터
#        </a>
#        <a class="game" href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_08');}catch(e){}bugs.ui.cp.headerGameMenuToggle();">
#         <span class="bar">
#         </span>
#         게임
#        </a>
#        <aside class="layer gameMenu">
#         <div class="box-shadow">
#         </div>
#         <ul class="list-layer-select">
#          <li>
#           <a href="http://www.hangame.com/" onclick="try{bugs.wiselog.area('M_header_02_09');}catch(e){}" target="_blank">
#            한게임
#           </a>
#          </li>
#          <li>
#           <a href="http://shotonline.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_10" onclick="try{bugs.wiselog.area('M_header_02_10');}catch(e){}" target="_blank">
#            샷온라인
#           </a>
#          </li>
#          <li>
#           <a href="http://game.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_11" onclick="try{bugs.wiselog.area('M_header_02_11');}catch(e){}" target="_blank">
#            피망
#           </a>
#          </li>
#         </ul>
#        </aside>
#       </div>
#       <div class="family">
#        <a class="comico" href="http://comico.toast.com" onclick="try{bugs.wiselog.area('M_header_02_03');}catch(e){}" target="_blank">
#         comico
#        </a>
#        <a class="ticketlink" href="http://www.ticketlink.co.kr" onclick="try{bugs.wiselog.area('M_header_02_04');}catch(e){}" target="_blank">
#         티켓링크
#        </a>
#        <a class="hangame" href="http://www.hangame.com" onclick="try{bugs.wiselog.area('M_header_02_05');}catch(e){}" target="_blank">
#         HANGAME
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="header">
#      <a class="logo seasonal hyrend" href="https://music.bugs.co.kr?wl_ref=M_header_03_01">
#       Bugs!
#       <span class="blind">
#        -홈으로 이동
#       </span>
#      </a>
#      <div class="innerContainer">
#       <input id="_hsi" type="hidden">
#        <fieldset class="searchForm" id="hederSearchForm">
#         <div class="input">
#          <input autocomplete="off" id="headerSearchInput" title="검색어 입력" type="text">
#           <span class="adKeywordDelete" id="keywordClearButton">
#            <span class="blind">
#             검색어 삭제
#            </span>
#           </span>
#           <button class="btnSearch" id="hederSearchFormButton" onclick="bugs.search.searchFromButton();">
#            검색
#            <span class="blind">
#             -페이지 이동
#            </span>
#           </button>
#          </input>
#         </div>
#         <div id="suggest" style="display:none;">
#          <div class="box-shadow">
#          </div>
#         </div>
#        </fieldset>
#        <div class="banner">
#        </div>
#       </input>
#      </div>
#      <div class="rightSection">
#       <div class="member">
#        <div class="login" id="loginHeader">
#         <!-- <a href="javascript:bugs.ui.showLoginLayerForHeader();" onclick="javascript:bugs.wiselog.area('M_header_03_05');">로그인</a>
# 			<a href="https://secure.bugs.co.kr/member/join/memberMain?wl_ref=M_header_03_06" class="signup"><span class="bar"></span> 회원가입<span class="blind">-페이지 이동</span></a> -->
#         <a href="javascript:bugs.ui.showLoginLayerForHeader({caller:this});" onclick="bugs.wiselog.area('M_header_03_05');">
#          로그인 / 회원가입
#         </a>
#        </div>
#        <div class="notification" id="memberNotificationArea">
#         <button id="btnNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">
#          알림
#         </button>
#         <button class="count" id="aNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">
#          <span class="blind">
#           새로운
#          </span>
#          <span>
#           알림
#          </span>
#          0
#          <span class="blind">
#           개
#          </span>
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <script type="text/javascript">
#     $(window).load(function(){
# 		if(g_isLogged){
# 			bugs.music.myAlbumList.gnbListArea = $("#gnbMyalbumListArea");
# 			bugs.music.myAlbumList.moreView = $("#btnMyalbumMoreView");
# 			bugs.music.myAlbumList.getGnbMyAlbumList(1);
# 		}
# 	});
#    </script>
#    <div id="gnb">
#     <span class="btnMenuFolding" id="gnbHandleBtn" style="display:none">
#      <span class="bu">
#      </span>
#      MENU
#     </span>
#     <div id="gnbBody">
#      <div class="links">
#       <div class="inner">
#        <a class="btnNormal lounge" href="https://music.bugs.co.kr/member/vipinfo?wl_ref=M_header_02_12">
#         <span class="iconLounge">
#         </span>
#         벅스 VIP 멤버십 안내
#        </a>
#        <a class="link ticket" href="https://music.bugs.co.kr/pay/recommend?wl_ref=M_left_01_01">
#         이용권 구매
#         <span class="bar">
#         </span>
#        </a>
#        <a class="link coupon" href="https://music.bugs.co.kr/pay/offlineCoupon?wl_ref=M_left_01_01">
#         상품권 등록
#        </a>
#       </div>
#      </div>
#      <nav>
#       <ul>
#        <li class="chart">
#         <a class="hyrend" href="https://music.bugs.co.kr/chart?wl_ref=M_left_02_01" lmid="lm_chart">
#          벅스차트
#         </a>
#        </li>
#        <li class="news">
#         <a class="hyrend" href="https://music.bugs.co.kr/newest?wl_ref=M_left_02_03" lmid="lm_news">
#          최신 음악
#         </a>
#        </li>
#        <li class="music4u">
#         <a class="hyrend" href="https://music.bugs.co.kr/music4u?wl_ref=M_left_02_02" lmid="lm_m4u">
#          뮤직4U
#         </a>
#        </li>
#        <li class="genre">
#         <a class="hyrend" href="https://music.bugs.co.kr/genre/home?wl_ref=M_left_02_06" lmid="lm_genre">
#          장르
#         </a>
#        </li>
#        <li class="special">
#         <a class="hyrend" href="https://music.bugs.co.kr/special?wl_ref=M_left_02_08" lmid="lm_special">
#          뮤직포스트
#         </a>
#        </li>
#        <li class="theme open" folder="2">
#         <strong>
#          테마
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/musicpd?wl_ref=M_left_02_04" lmid="lm_esalbum">
#            뮤직PD 앨범
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/recomreview?wl_ref=M_left_02_05" lmid="lm_recomreview">
#            추천앨범 리뷰
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/years?wl_ref=M_left_02_07" lmid="lm_years">
#            연도별
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/maniachart/kpop?wl_ref=M_left_02_09" lmid="lm_mania">
#            매니아
#           </a>
#          </li>
#         </ul>
#        </li>
#        <!-- 				<li class="bside"><a href="https://music.bugs.co.kr/bside?wl_ref=M_left_02_13" class="hyrend" lmid="lm_bside">Bside</a></li> -->
#        <li class="connect">
#         <a class="hyrend" href="https://music.bugs.co.kr/connect?wl_ref=M_left_02_13" lmid="lm_connect">
#          커넥트
#          <span class="iconNew">
#           NEW
#          </span>
#         </a>
#        </li>
#        <li class="radio">
#         <a class="hyrend" href="https://music.bugs.co.kr/radio?wl_ref=M_left_02_10" lmid="lm_radio">
#          라디오
#         </a>
#        </li>
#        <li class="flac">
#         <a class="hyrend" href="https://music.bugs.co.kr/flactheater/home?wl_ref=M_left_02_11" lmid="lm_flac">
#          FLAC 전용관
#         </a>
#        </li>
#        <li class="bugsonTV open" folder="5">
#         <strong>
#          벅스TV
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li class="specialLive">
#           <a href="https://music.bugs.co.kr/special/bugstv?wl_ref=M_left_04_04">
#            스페셜 라이브
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="mymusic open" folder="3">
#         <strong>
#          내 음악
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?wl_ref=M_left_03_05" lmid="lm_recentTrack" loginrequired="PAGE">
#            최근 들은 곡
#           </a>
#           <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('',true);">
#            최근 들은 곡 재생
#           </button>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?sort=LISTEN_COUNT&amp;wl_ref=M_left_03_06" lmid="lm_manytimesTrack" loginrequired="PAGE">
#            가장 많이 들은 곡
#           </a>
#           <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('LISTEN_COUNT',true);">
#            가장 많이 들은 곡 재생
#           </button>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/purchased/track?wl_ref=M_left_03_01" lmid="lm_buymusic" loginrequired="PAGE">
#            구매한 음악
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/like/track?wl_ref=M_left_03_02" lmid="lm_likemusic" loginrequired="PAGE">
#            좋아한 음악
#           </a>
#          </li>
#         </ul>
#         <div class="myalbum">
#          <strong>
#           내 앨범
#          </strong>
#          <a class="edit hyrend" href="https://music.bugs.co.kr/user/library/myalbum/list?wl_ref=M_left_03_07" lmid="lm_myAlbumManage" loginrequired="PAGE">
#           편집
#          </a>
#          <div class="btnNewAlbum">
#           <a href="javascript:;" onclick="playlists.make2('GNB');bugs.wiselog.area('M_left_03_04');">
#            <span class="blind">
#             내앨범
#            </span>
#            +  새로 만들기
#           </a>
#          </div>
#          <ul id="gnbMyalbumListArea">
#          </ul>
#          <div>
#           <a class="btnMoreAlbum" href="javascript:;" id="btnMyalbumMoreView" onclick="bugs.music.myAlbumList.getNext(); bugs.wiselog.area('M_left_03_08');" style="display:none;">
#            더보기
#            <span>
#            </span>
#           </a>
#          </div>
#          <div class="loadingFailed" id="gnbMyalbumLoadFail" style="display:none;">
#           <p>
#            내 앨범을 불러오지
#            <br/>
#            못했습니다.
#           </p>
#           <button onclick="bugs.music.myAlbumList.getGnbMyAlbumList(1, 'failReload');">
#            <span class="icon">
#            </span>
#            내 앨범 불러오기
#           </button>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <script>
#     try{
# 	bugs.navigator.setLeftMenuFolder();
# }
# catch(e){}
#    </script>
#    <div id="hyrendContentBody">
#     <script>
#      var chartDatePicker;
# 	var chartDate = "";
# 	$(document).ready(function(){
#
# 		var dpOption = {
# 			showButtonSelector:".btnSelect",
# 			currentPeriodStartDate : new Date(2018,03-1, 13),
# 			currentPeriodEndDate : new Date(2018,03-1, 13),
# 							minDate : new Date(2006, 9 - 1, 23),
# 			maxDate : new Date(2018,03-1, 14),
# 			onSelect:function(){
# 				bugs.debug.show( "datepicker:" + $(this).val() );
# 				var url = "https://music.bugs.co.kr/chart/track/day/total?chartdate=" + $(this).val();
# 				bugs.navigator.goState(url);
# 			}
# 		};
# 		chartDatePicker = bugs.datepicker.button("#chartDate", dpOption);
# 		chartDatePicker.datepicker('setDate', '20180313');
#
# 	});
#     </script>
#     <article class="mnWhatshot mnChart pgChartTrack" id="container">
#      <header class="sectionPadding pgTitle">
#       <div class="innerContainer">
#        <h1>
#         벅스차트
#        </h1>
#        <script type="text/javascript">
#         var toggleNationLayer = function() {
#     $("aside.selectNation").toggle(250, function(){});
#   }
#
# $(document).ready(function () {
#
#   function changeTitle(){
#     try{
#               if('KR' != 'KR'){
#         var newTitle = '벅스차트 > 곡 차트 > 대한민국 - 벅스';
#         var curTitle = document.title;
#         if(newTitle != curTitle){
#           document.title = newTitle;
#         } else {
#           setTimeout(changeTitle, 500);
#         }
#       }
#     } catch(e){}
#   };
#
#   changeTitle();
#
#   $(document).click(function(ev){
#     if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
#     if ($(ev.target).attr('class') != "selectedNationName"
#         && ($(ev.target).attr('class').indexOf("flag") != 0  )
#         && ($(ev.target).attr('class').indexOf("btnNation") == -1 ) ) {
#           $("aside.selectNation").hide(250);
#       }
#     });
# });
#        </script>
#        <a class="btnNation" href="javascript:;" onclick="bugs.wiselog.area('chart_filter_nation');toggleNationLayer();">
#         <span class="flag">
#          <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/>
#         </span>
#         <em class="selectedNationName">
#          대한민국
#         </em>
#        </a>
#        <aside class="layer selectNation">
#         <div class="box-shadow">
#         </div>
#         <h1>
#          국가선택
#         </h1>
#         <ul>
#          <li>
#           <a class="selected KR" href="https://music.bugs.co.kr/chart/track/realtime/total?nation=KR" onclick="bugs.wiselog.area('chart_nation_KR');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/>
#            </span>
#            <em class="selectedNationName">
#             대한민국
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="nl" href="https://music.bugs.co.kr/chart/track/week/total?nation=nl" onclick="bugs.wiselog.area('chart_nation_nl');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/NL.png"/>
#            </span>
#            <em class="selectedNationName">
#             네덜란드
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="dk" href="https://music.bugs.co.kr/chart/track/week/total?nation=dk" onclick="bugs.wiselog.area('chart_nation_dk');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DK.png"/>
#            </span>
#            <em class="selectedNationName">
#             덴마크
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="de" href="https://music.bugs.co.kr/chart/track/week/total?nation=de" onclick="bugs.wiselog.area('chart_nation_de');">
# ...
#
# 	if(contentsBanner != "" && contentsBanner != "[]" ){
# 		contentsBanner = bugs.utils.parseJson(contentsBanner);
# 		var wiselogStr = "";
# 		for(var i = 0; i < contentsBanner.length && i < 3; i++){
# 			if(i==0){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_01');"
# 			}else if( i==1){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_02');"
# 			}else if( i==2){
# 				wiselogStr = "bugs.wiselog.area('S_sp_04_03');"
# 			}
# 			$('#contentsBanner'+(i+1)).empty();
# 			$('#contentsBanner'+(i+1)).append('<a href="'+contentsBanner[i].link+'" target="'+contentsBanner[i].target+
# 					'" onclick="'+wiselogStr+'bugs.logging.banner('+contentsBanner[i].banner_id+','+"'banner'"+')" title="'+contentsBanner[i].title+'-페이지 이동">'+
# 											'<img src="'+contentsBanner[i].image_path+'" alt="'+contentsBanner[i].title+'"></a>');
# 		}
#
# 		var oldWidth = $(window).width();
# 		if(oldWidth < 1903){
# 			$('#contentsBanner2').addClass('lineBreak');
# 		}else{
# 			$('#contentsBanner3').addClass('lineBreak');
# 		}
# 		var currentWidth = 0;
# 		$(window).on('resize',function(){
# 			currentWidth = $(window).width();
# 			if(oldWidth < 1903 && 1903 <= currentWidth){
# 				$('#contentsBanner2').removeClass('lineBreak');
# 				$('#contentsBanner3').addClass('lineBreak');
# 			}else if(currentWidth < 1903 && 1903 <= oldWidth){
# 				$('#contentsBanner3').removeClass('lineBreak');
# 				$('#contentsBanner2').addClass('lineBreak');
# 			}
# 			oldWidth = currentWidth;
# 		});
#
# 		$('aside.contentsBanner').show();
# 	}
#
# });
# </script>
# <aside class="contentsBanner" style="display:none;">
#  <ul class="listContentsBanner">
#   <li id="contentsBanner1">
#   </li>
#   <li id="contentsBanner2">
#   </li>
#   <li id="contentsBanner3">
#   </li>
#  </ul>
# </aside>
# <div class="floatingTop">
#  <a class="btnTop" href="javascript:void(bugs.navigator.scrollTop())">
#   TOP
#  </a>
# </div>
# <script src="/js/jquery/jquery-dateFormat.min.js" type="text/javascript">
# </script>
# <script>
#  $(window.document).ready(function() {
# 			setTimeout(function(){
# 				$.ajax({
# 					url : g_urlAjax + "/board/notice/ajax/commonfooternotice",
# 					type : "POST",
# 					dataType : "json",
# 					success : function(data){
# 						if(data != null){
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").text(data.title);
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").attr("href", g_urlMusic + "/board/notice?srl=" + data.srl + "&wl_ref=M_footer_01_01");
# 							$("#commonFooterNotice time").text(data.crt_dt);
# 							$("#commonFooterNotice time").attr("datetime", $.format.date(Date.parse(data.crt_dt,"yyyy.MM.dd"), "yyyy-MM-dd"));
# 						}
# 					}
# 				});
# 			}, 1300);
#
# });
# </script>
# <footer id="footer">
#  <section class="sectionPadding">
#   <div class="innerContainer">
#    <div class="notice" id="commonFooterNotice">
#     <strong>
#      <a href="https://music.bugs.co.kr/board/notice?wl_ref=M_footer_01_01">
#       공지사항
#      </a>
#     </strong>
#     <a href="javascript:;" id="commonFooterNoticeTitle">
#     </a>
#     <time datetime="">
#     </time>
#    </div>
#    <div class="quicklinks">
#     <ul>
#      <li>
#       <a href="https://music.bugs.co.kr/event?wl_ref=M_footer_02_01">
#        이벤트
#       </a>
#      </li>
#      <li>
#       <a href="https://music.bugs.co.kr/panel?wl_ref=M_footer_02_01">
#        벅스패널
#       </a>
#      </li>
#     </ul>
#     <ul>
#      <li>
#       <span class="bar">
#       </span>
#       <a href="https://music.bugs.co.kr/serviceGuide/home?wl_ref=M_footer_02_07">
#        벅스 꿀팁 보기
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </section>
#  <section class="sectionPadding contents">
#   <div class="innerContainer">
#    <ul class="links">
#     <li class="company">
#      <a aria-label="새창" href="http://www.bugscorp.co.kr?wl_ref=M_footer_03_01" target="_blank">
#       회사소개
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/cooperation?wl_ref=M_footer_03_01">
#       제휴문의
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/rules/use?wl_ref=M_footer_03_01">
#       이용약관
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li class="privacy">
#      <a href="https://music.bugs.co.kr/rules/privacy?wl_ref=M_footer_03_01">
#       개인정보처리방침
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/rules/youth?wl_ref=M_footer_03_01">
#       청소년보호정책
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/connect/center?wl_ref=M_footer_03_01">
#       커넥트 센터
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="http://help.bugs.co.kr?wl_ref=M_footer_03_01">
#       고객센터
#      </a>
#      <span class="bar">
#      </span>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/sitemap?wl_ref=M_footer_03_01">
#       사이트맵
#      </a>
#     </li>
#    </ul>
#    <aside>
#     <div class="sns">
#      <a aria-label="새창" class="blog" href="http://blog.bugs.co.kr" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#       블로그
#      </a>
#      <a aria-label="새창" class="facebook" href="https://www.facebook.com/bugsplay" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#       페이스북
#      </a>
#      <a aria-label="새창" class="kakaostory" href="https://story.kakao.com/ch/bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#       카카오스토리
#      </a>
#     </div>
#     <div class="familysite">
#      <button onclick="bugs.ui.cp.footerFamilySiteMenu(this);" tabindex="0">
#       FAMILY SITE
#       <span class="bu">
#       </span>
#      </button>
#      <aside class="layer familysiteMenu">
#       <div class="box-shadow">
#       </div>
#       <ul class="list-layer-select">
#        <li>
#         <a aria-label="새창" href="http://www.nhnent.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">
#          NHN Entertainment
#         </a>
#        </li>
#        <li>
#         <a aria-label="새창" href="http://me.sayclub.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">
#          세이클럽
#         </a>
#        </li>
#       </ul>
#      </aside>
#     </div>
#    </aside>
#    <address>
#     (주)엔에이치엔벅스 | 13487 경기도 성남시 분당구 대왕판교로 645번길 16 플레이뮤지엄 | 대표이사 : 양주일 | 고객센터 :
#     <a href="mailto:help@help.bugs.co.kr">
#      help@help.bugs.co.kr
#     </a>
#     / 1566-4882 (유료)
#     <br>
#      사업자등록번호 : 211-87-15555 | 통신판매업 신고번호 : 제 2013-경기성남-0532호 | 호스팅 제공자 : (주)엔에이치엔벅스 |
#      <a aria-label="새창" href="http://ftc.go.kr/info/bizinfo/communicationView.jsp?apv_perm_no=2013378021930200528&amp;area1=&amp;area2=&amp;currpage=1&amp;searchKey=04&amp;searchVal=2118715555&amp;stdate=&amp;enddate=" target="_blank">
#       사업자 정보 확인
#      </a>
#      | © NHN Bugs Corp. All rights reserved.
#     </br>
#    </address>
#    <script>
#     if (!bugs.ui.cp) {
# 	bugs.ui.cp = {
# 		headerGameMenuToggle : function() {
# 			$('.layer.gameMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_header_02_02');
# 			}
# 		},
# 		footerFamilySiteMenu : function() {
# 			$('.layer.familysiteMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_fotter_03_01');
# 			}
# 		}
# 	};
# }
#    </script>
#    <ul class="emblem">
#     <li>
#      <a href="https://music.bugs.co.kr/specialView/supersound/NJ6P8GAP0ERQFD84GUCF" onclick="bugs.wiselog.area('M_fotter_03_01');">
#       <img alt="하이 레졸루션 공식인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHiRes.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="javascript:void(0)" onclick="window.open('https://www.goodcontent.kr/upload_public/CERTIDW/2017-09-0007_6s59w399b1p6wd220170905003422.png', 'goodContentPop' , 'width=490,height=616,resizable=0');">
#       <img alt="굿 콘텐츠서비스" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemGCSV20171207.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/board/notice?srl=7949" onclick="bugs.wiselog.area('M_fotter_03_01');">
#       <img alt="2015 상반기 대학생선호브랜드 대상" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHerald.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="https://music.bugs.co.kr/board/notice?srl=5162" onclick="bugs.wiselog.area('M_fotter_03_01');">
#       <img alt="스마트앱어워드 대상 수상" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemAppaward.png"/>
#      </a>
#     </li>
#     <li>
#      <a aria-label="새창" href="https://isms.kisa.or.kr/main/isms/issue/?certificationMode=list&amp;crtfYear=&amp;searchCondition=1&amp;searchKeyword=ISMS+13-042" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#       <img alt="정보보호 관리체계 ISMS 인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemISMS.png"/>
#      </a>
#     </li>
#     <li>
#      <a aria-label="새창" href="http://www.kdce.or.kr/user/ctf/clmsCtfTransList.do?NmberBusiRegNo=2118715555&amp;websiteName=www.bugs.co.kr" onclick="window.open(this.href,'','width=600,height=669');bugs.wiselog.area('M_fotter_03_01');return false;">
#       <img alt="음악저작권 이용 허락 인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemClms.png"/>
#      </a>
#     </li>
#     <li>
#      <a aria-label="새창" href="http://www.cleansite.org" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#       <img alt="클린사이트" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemCleansite.png"/>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </section>
# </footer>
# <!--<a href="javascript:void(playlists.resetPlaylist())">리셋하기</a>-->
# <script type="text/javascript">
#  $(document).ready(function(){
# 	try{
# 		bugs.navigator.addHyrendUnloadHandler(function(){playlists.playlistLayerHide();},"track2playlistForMoveHyrend", true);
# 	}catch(e){}
#
# });
# </script>
# <aside class="layer layer-select addMyAlbum" id="track2playlist" style="display:none;">
#  <div class="box-shadow">
#  </div>
#  <h1>
#   내 앨범 목록
#  </h1>
#  <div autoscroll="N" class="innerScroll" id="track2playlistScrollArea">
#   <ul class="list-layer-select">
#    <li>
#     <a href="javascript:;" onclick="$('#track2playlist').hide('blind', {}, 'normal', function() { bugs.ui.modalLayer.hide();playlists.make(); });" title="새 앨범 만들기">
#      + 새 앨범 만들기
#     </a>
#    </li>
#   </ul>
#  </div>
# </aside>
# <!-- 레이어 - 내 앨범 수정 -->
# <aside class="layer createMyAlbum" id="editMyAlbumLayer" style="display:none; z-index:1002;">
#  <div class="box-shadow">
#  </div>
#  <header class="layer-title">
#   <h1>
#    앨범 정보 수정
#   </h1>
#  </header>
#  <section class="layerContents">
#   <fieldset>
#    <legend>
#     내 앨범 수정
#    </legend>
#    <table class="formLayout">
#     <caption>
#      내 앨범 수정 입력 폼
#     </caption>
#     <tbody>
#      <tr>
#       <th scope="row">
#        <label class="lb" for="editMyAlbumLayerPhoto">
#         사진
#        </label>
#       </th>
#       <td>
#        <img alt="" class="thumb" id="editMyAlbumLayerPhoto_img" src="https://file.bugsm.co.kr/wbugs/common/i_defaultMyAlbum_50x50.png"/>
#        <div class="inputFile">
#         <input class="file" diabled="" id="editMyAlbumLayerPhoto" type="text">
#          <button class="btnNormal" id="searchImage" type="button">
#           찾아보기
#          </button>
#          <input id="editMyAlbumLayerPhoto_path" title="사진경로" type="hidden"/>
#         </input>
#        </div>
#       </td>
#       <td class="right" style="width:55px;">
#       </td>
#      </tr>
#      <tr>
#       <th scope="row" style="width:55px;">
#        <label class="lb" for="editMyAlbumLayerTitle">
#         제목
#        </label>
#       </th>
#       <td>
#        <input class="txt" id="editMyAlbumLayerTitle" type="text" value="111"/>
#       </td>
#       <td class="right" style="width:55px;">
#        <span class="remain" id="editMyAlbumLayerTitleRemain">
#         (0/100)
#        </span>
#       </td>
#      </tr>
#      <tr>
#       <th scope="row">
#        <label class="lb" for="editMyAlbumLayerDescribe">
#         설명
#        </label>
#       </th>
#       <td>
#        <textarea class="txtArea" cols="30" id="editMyAlbumLayerDescribe" name="" rows="10"></textarea>
#       </td>
#       <td class="right">
#        <span class="remain" id="editMyAlbumLayerDescribeRemain">
#         (0/300)
#        </span>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#    <p class="btns">
#     <button btntype="ok" class="btnNormal" id="editMyAlbumLayerUpdate">
#      저장
#     </button>
#     <button btntype="cancel" class="btnNormal" id="editMyAlbumLayerCancel">
#      취소
#     </button>
#    </p>
#   </fieldset>
#  </section>
#  <button btntype="close" class="btnClose" id="editMyAlbumLayerClose">
#   닫기
#  </button>
# </aside>
# <!-- 레이어 - 내 앨범 수정 -->
# <aside class="layer createMyAlbum" id="createMyAlbumLayer" style="display:none; z-index:1000;">
#  <div class="box-shadow">
#  </div>
#  <header class="layer-title">
#   <h1>
#    내 앨범 만들기
#   </h1>
#  </header>
#  <section class="layerContents">
#   <fieldset>
#    <legend>
#     내 앨범 만들기
#    </legend>
#    <table class="formLayout">
#     <caption>
#      내 앨범 정보 입력 폼
#     </caption>
#     <tbody>
#      <tr>
#       <th scope="row" style="width:55px;">
#        <label class="lb" for="createMyAlbumLayerTitle">
#         제목
#        </label>
#       </th>
#       <td>
#        <input class="txt" id="createMyAlbumLayerTitle" type="text" value=""/>
#       </td>
#       <td class="right" style="width:55px;">
#        <span class="remain" id="createMyAlbumLayerTitleRemain">
#         (0/100)
#        </span>
#       </td>
#      </tr>
#      <tr>
#       <th scope="row">
#        <label class="lb" for="createMyAlbumLayerDescribe">
#         설명
#        </label>
#       </th>
#       <td>
#        <textarea class="txtArea" cols="30" id="createMyAlbumLayerDescribe" name="" rows="10"></textarea>
#       </td>
#       <td class="right">
#        <span class="remain" id="createMyAlbumLayerDescribeRemain">
#         (0/300)
#        </span>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#    <p class="btns">
#     <button btntype="ok" class="btnNormal" id="createMyAlbumLayerUpdate">
#      저장
#     </button>
#     <button btntype="cancel" class="btnNormal" id="createMyAlbumLayerCancel">
#      취소
#     </button>
#    </p>
#   </fieldset>
#  </section>
#  <button btntype="close" class="btnClose" id="crerateMyAlbumLayerClose">
#   닫기
#  </button>
# </aside>
# <span id="removeSpecialCharTarget" style="display:none;">
# </span>
# <script>
#  try{
# 	bugs.navigator.setLeftMenuShowOnLoad();
# }
# catch(e){}
# $(document).ready(function(){
# 	var isFirefox = navigator.userAgent.toLowerCase().indexOf('firefox') > -1;
# 	if(isFirefox){
# 		$("#skipNav").css({top:"1px", left:"1px"});
# 	}
# });
# </script>
# <!-- 470517  -->
# <script>
#  try {
# 		var expTime = (new Date()).getTime() + (60*60*24*30*1000);
# 	var expTime2 = (new Date()).getTime() - (60*5*1000);
# 	    bugs.cookie.set("last_login_log_date_cookie","", expTime2, "/", "bugs.co.kr");
# }
# catch(e){}
# </script>

# %%
daily_songs = soup.find(class_ = 'list trackList byChart').tbody.find_all('tr') # 노래 목록 저장
#daily_songs
# Out:
# [<tr albumid="20153146" artistid="80020023" multiartist="N" mvid="0" rowtype="track" trackid="30984692">
#  <input name="_isStream" type="hidden" value="30984692">
#  <input name="_isDown" type="hidden" value="30984692">
#  <td class="check"><input disc_id="1" name="check" title="꽃 길" type="checkbox" value="30984692"/></td>
#  <td>
#  <div class="ranking">
#  <strong>1</strong>
#  <p class="change hot"><em>HOT</em></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20153146?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="꽃 길 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201531/20153146.jpg?version=20180314002356"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30984692?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30984692',true);
#  " title="꽃 길">꽃 길</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80020023?wl_ref=list_tr_10_chart" onclick="
#  " title="BIGBANG">BIGBANG</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20153146?wl_ref=list_tr_11_chart" onclick="
#  " title="꽃 길">꽃 길</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30984692',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30984692');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30984692');
#  " track_title="꽃 길">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30984692','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="BIGBANG" artist_id="80020023" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30984692','','20153146','bugs.music.listenRadioFromSeed(\'30984692\',\'track\');','N', 'Y', '_chart');
#  " track_title="꽃 길">기타 기능</a>
#  </td>
#  </input></input></tr>,
#  <tr albumid="721172" artistid="80069631" multiartist="N" mvid="0" rowtype="track" trackid="5149622">
#  <input name="_isStream" type="hidden" value="5149622">
#  <input name="_isDown" type="hidden" value="5149622">
#  <td class="check"><input disc_id="1" name="check" title="My Blossom" type="checkbox" value="5149622"/></td>
#  <td>
#  <div class="ranking">
#  <strong>2</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/721172?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="My Blossom 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/7211/721172.jpg?version=20180314163318"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/5149622?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5149622',true);
#  " title="My Blossom">My Blossom</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80069631?wl_ref=list_tr_10_chart" onclick="
#  " title="소유 (SOYOU)">소유 (SOYOU)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/721172?wl_ref=list_tr_11_chart" onclick="
#  " title="My Blossom">My Blossom</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('5149622',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('5149622');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'5149622');
#  " track_title="My Blossom">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'5149622','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="소유 (SOYOU)" artist_id="80069631" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'5149622','','721172','bugs.music.listenRadioFromSeed(\'5149622\',\'track\');','N', 'Y', '_chart');
#  " track_title="My Blossom">기타 기능</a>
#  </td>
#  </input></input></tr>,
#  <tr albumid="20152077" artistid="80178434" multiartist="N" mvid="391131" rowtype="track" trackid="30977200">
#  <input name="_isStream" type="hidden" value="30977200">
#  <input name="_isDown" type="hidden" value="30977200">
#  <td class="check"><input disc_id="1" name="check" title="Jenga (Feat. Gaeko)" type="checkbox" value="30977200"/></td>
#  <td>
#  <div class="ranking">
#  <strong>3</strong>
#  <p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="바람 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201520/20152077.jpg?version=20180315003606"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30977200?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30977200',true);
#  " title="Jenga (Feat. Gaeko)">Jenga (Feat. Gaeko)</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178434?wl_ref=list_tr_10_chart" onclick="
#  " title="헤이즈(HEIZE)">헤이즈(HEIZE)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_11_chart" onclick="
#  " title="바람">바람</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30977200',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30977200');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30977200');
#  " track_title="Jenga (Feat. Gaeko)">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30977200','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30977200, 391131, 'Y', 'Y', 'Y', 'Y', 30977200, 'N','OVER_15', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="헤이즈(HEIZE)" artist_id="80178434" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30977200','','20152077','bugs.music.listenRadioFromSeed(\'30977200\',\'track\');','N', 'Y', '_chart');
#  " track_title="Jenga (Feat. Gaeko)">기타 기능</a>
#  </td>
#  </input></input></tr>,
#  <tr albumid="719455" artistid="80177857" multiartist="N" mvid="390650" rowtype="track" trackid="5145783">
#  <input name="_isStream" type="hidden" value="5145783">
#  <input name="_isDown" type="hidden" value="5145783"/>
#  <td class="check"><input disc_id="1" name="check" title="별이 빛나는 밤" type="checkbox" value="5145783"/></td>
#  <td>
#  <div class="ranking">
#  <strong>4</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/719455?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Yellow Flower 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/7194/719455.jpg?version=20180309185321"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/5145783?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5145783',true);
#  " title="별이 빛나는 밤">별이 빛나는 밤</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80177857?wl_ref=list_tr_10_chart" onclick="
#  " title="마마무(Mamamoo)">마마무(Mamamoo)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/719455?wl_ref=list_tr_11_chart" onclick="
#  " title="Yellow Flower">Yellow Flower</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('5145783',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('5145783');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'5145783');
#  " track_title="별이 빛나는 밤">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'5145783','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,5145783, 390650, 'Y', 'Y', 'Y', 'Y', 5145783, 'N','OVER_15', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="마마무(Mamamoo)" artist_id="80177857" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'5145783','','719455','bugs.music.listenRadioFromSeed(\'5145783\',\'track\');','N', 'Y', '_chart');
#  " track_title="별이 빛나는 밤">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20152077" artistid="80178434" multiartist="N" mvid="390750" rowtype="track" trackid="30977202">
#  <input name="_isStream" type="hidden" value="30977202">
#  <input name="_isDown" type="hidden" value="30977202"/>
#  <td class="check"><input disc_id="1" name="check" title="내가 더 나빠" type="checkbox" value="30977202"/></td>
#  <td>
#  <div class="ranking">
#  <strong>5</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="바람 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201520/20152077.jpg?version=20180315003606"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30977202?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30977202',true);
#  " title="내가 더 나빠">내가 더 나빠</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178434?wl_ref=list_tr_10_chart" onclick="
#  " title="헤이즈(HEIZE)">헤이즈(HEIZE)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_11_chart" onclick="
#  " title="바람">바람</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30977202',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30977202');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30977202');
#  " track_title="내가 더 나빠">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30977202','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30977202, 390750, 'Y', 'Y', 'Y', 'Y', 30977202, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="헤이즈(HEIZE)" artist_id="80178434" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30977202','','20152077','bugs.music.listenRadioFromSeed(\'30977202\',\'track\');','N', 'Y', '_chart');
#  " track_title="내가 더 나빠">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20142919" artistid="80223033" multiartist="N" mvid="0" rowtype="track" trackid="30923739">
#  <input name="_isStream" type="hidden" value="30923739">
#  <input name="_isDown" type="hidden" value="30923739"/>
#  <td class="check"><input disc_id="1" name="check" title="You" type="checkbox" value="30923739"/></td>
#  <td>
#  <div class="ranking">
#  <strong>6</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20142919?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="투유 프로젝트 - 슈가맨2 Part.2 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201429/20142919.jpg?version=20180220002701"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30923739?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30923739',true);
#  " title="You">You</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80223033?wl_ref=list_tr_10_chart" onclick="
#  " title="멜로망스(MeloMance)">멜로망스(MeloMance)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20142919?wl_ref=list_tr_11_chart" onclick="
#  " title="투유 프로젝트 - 슈가맨2 Part.2">투유 프로젝트 - 슈가맨2 Part.2</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30923739',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30923739');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30923739');
#  " track_title="You">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30923739','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="멜로망스(MeloMance)" artist_id="80223033" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30923739','','20142919','bugs.music.listenRadioFromSeed(\'30923739\',\'track\');','N', 'Y', '_chart');
#  " track_title="You">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20144113" artistid="80246729" multiartist="N" mvid="381150" rowtype="track" trackid="30930536">
#  <input name="_isStream" type="hidden" value="30930536">
#  <input name="_isDown" type="hidden" value="30930536"/>
#  <td class="check"><input disc_id="1" name="check" title="사랑을 했다 (LOVE SCENARIO)" type="checkbox" value="30930536"/></td>
#  <td>
#  <div class="ranking">
#  <strong>7</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20144113?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Return 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201441/20144113.jpg?version=20180306002411"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30930536?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30930536',true);
#  " title="사랑을 했다 (LOVE SCENARIO)">사랑을 했다 (LOVE SCENARIO)</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80246729?wl_ref=list_tr_10_chart" onclick="
#  " title="iKON">iKON</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20144113?wl_ref=list_tr_11_chart" onclick="
#  " title="Return">Return</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30930536',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30930536');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30930536');
#  " track_title="사랑을 했다 (LOVE SCENARIO)">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30930536','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30930536, 381150, 'Y', 'Y', 'Y', 'Y', 30930536, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="iKON" artist_id="80246729" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30930536','','20144113','bugs.music.listenRadioFromSeed(\'30930536\',\'track\');','N', 'Y', '_chart');
#  " track_title="사랑을 했다 (LOVE SCENARIO)">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20147700" artistid="80137715" multiartist="N" mvid="385513" rowtype="track" trackid="30951564">
#  <input name="_isStream" type="hidden" value="30951564">
#  <input name="_isDown" type="hidden" value="30951564"/>
#  <td class="check"><input disc_id="1" name="check" title="그때 헤어지면 돼" type="checkbox" value="30951564"/></td>
#  <td>
#  <div class="ranking">
#  <strong>8</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20147700?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="그때 헤어지면 돼 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201477/20147700.jpg?version=20180213002516"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30951564?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30951564',true);
#  " title="그때 헤어지면 돼">그때 헤어지면 돼</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80137715?wl_ref=list_tr_10_chart" onclick="
#  " title="로이킴">로이킴</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20147700?wl_ref=list_tr_11_chart" onclick="
#  " title="그때 헤어지면 돼">그때 헤어지면 돼</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30951564',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30951564');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30951564');
#  " track_title="그때 헤어지면 돼">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30951564','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30951564, 385513, 'Y', 'Y', 'Y', 'Y', 30951564, 'N','ALL', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="로이킴" artist_id="80137715" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30951564','','20147700','bugs.music.listenRadioFromSeed(\'30951564\',\'track\');','N', 'Y', '_chart');
#  " track_title="그때 헤어지면 돼">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20152077" artistid="80178434" multiartist="N" mvid="0" rowtype="track" trackid="30977201">
#  <input name="_isStream" type="hidden" value="30977201">
#  <input name="_isDown" type="hidden" value="30977201"/>
#  <td class="check"><input disc_id="1" name="check" title="괜찮냐고" type="checkbox" value="30977201"/></td>
#  <td>
#  <div class="ranking">
#  <strong>9</strong>
#  <p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="바람 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201520/20152077.jpg?version=20180315003316"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30977201?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30977201',true);
#  " title="괜찮냐고">괜찮냐고</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178434?wl_ref=list_tr_10_chart" onclick="
#  " title="헤이즈(HEIZE)">헤이즈(HEIZE)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_11_chart" onclick="
#  " title="바람">바람</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30977201',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30977201');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30977201');
#  " track_title="괜찮냐고">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30977201','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="헤이즈(HEIZE)" artist_id="80178434" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30977201','','20152077','bugs.music.listenRadioFromSeed(\'30977201\',\'track\');','N', 'Y', '_chart');
#  " track_title="괜찮냐고">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20139509" artistid="80271242" multiartist="N" mvid="375250" rowtype="track" trackid="30902877">
#  <input name="_isStream" type="hidden" value="30902877">
#  <input name="_isDown" type="hidden" value="30902877"/>
#  <td class="check"><input disc_id="1" name="check" title="뿜뿜" type="checkbox" value="30902877"/></td>
#  <td>
#  <div class="ranking">
#  <strong>10</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20139509?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="GREAT! 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201395/20139509.jpg?version=20180315003143"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30902877?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30902877',true);
#  " title="뿜뿜">뿜뿜</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80271242?wl_ref=list_tr_10_chart" onclick="
#  " title="모모랜드(MOMOLAND)">모모랜드(MOMOLAND)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20139509?wl_ref=list_tr_11_chart" onclick="
#  " title="GREAT!">GREAT!</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30902877',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30902877');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30902877');
#  " track_title="뿜뿜">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30902877','true','false','44.1','true','96', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30902877, 375250, 'Y', 'Y', 'Y', 'Y', 30902877, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="모모랜드(MOMOLAND)" artist_id="80271242" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30902877','','20139509','bugs.music.listenRadioFromSeed(\'30902877\',\'track\');','N', 'Y', '_chart');
#  " track_title="뿜뿜">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20132644" artistid="80216977" multiartist="N" mvid="367370" rowtype="track" trackid="30862934">
#  <input name="_isStream" type="hidden" value="30862934">
#  <input name="_isDown" type="hidden" value="30862934"/>
#  <td class="check"><input disc_id="1" name="check" title="그날처럼" type="checkbox" value="30862934"/></td>
#  <td>
#  <div class="ranking">
#  <strong>11</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20132644?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="그날처럼 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201326/20132644.jpg?version=20171130002741"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30862934?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30862934',true);
#  " title="그날처럼">그날처럼</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80216977?wl_ref=list_tr_10_chart" onclick="
#  " title="장덕철">장덕철</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20132644?wl_ref=list_tr_11_chart" onclick="
#  " title="그날처럼">그날처럼</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30862934',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30862934');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30862934');
#  " track_title="그날처럼">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30862934','true','false','44.1','true','44.1', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30862934, 367370, 'Y', 'Y', 'Y', 'Y', 30862934, 'N','OVER_12', 'N');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="장덕철" artist_id="80216977" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30862934','','20132644','bugs.music.listenRadioFromSeed(\'30862934\',\'track\');','N', 'Y', '_chart');
#  " track_title="그날처럼">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20146368" artistid="80213200" multiartist="N" mvid="384170" rowtype="track" trackid="30944380">
#  <input name="_isStream" type="hidden" value="30944380">
#  <input name="_isDown" type="hidden" value="30944380"/>
#  <td class="check"><input disc_id="1" name="check" title="눈사람" type="checkbox" value="30944380"/></td>
#  <td>
#  <div class="ranking">
#  <strong>12</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20146368?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="그리고 봄 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201463/20146368.jpg?version=20180220002727"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30944380?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30944380',true);
#  " title="눈사람">눈사람</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80213200?wl_ref=list_tr_10_chart" onclick="
#  " title="정승환">정승환</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20146368?wl_ref=list_tr_11_chart" onclick="
#  " title="그리고 봄">그리고 봄</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30944380',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30944380');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30944380');
#  " track_title="눈사람">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30944380','true','true','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30944380, 384170, 'Y', 'Y', 'Y', 'Y', 30944380, 'N','ALL', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="정승환" artist_id="80213200" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30944380','','20146368','bugs.music.listenRadioFromSeed(\'30944380\',\'track\');','N', 'Y', '_chart');
#  " track_title="눈사람">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20144731" artistid="80199440" multiartist="N" mvid="382170" rowtype="track" trackid="30934033">
#  <input name="_isStream" type="hidden" value="30934033">
#  <input name="_isDown" type="hidden" value="30934033"/>
#  <td class="check"><input disc_id="1" name="check" title="Bad Boy" type="checkbox" value="30934033"/></td>
#  <td>
#  <div class="ranking">
#  <strong>13</strong>
#  <p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20144731?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="The Perfect Red Velvet - The 2nd Album Repackage 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201447/20144731.jpg?version=20180314002628"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30934033?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30934033',true);
#  " title="Bad Boy">Bad Boy</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80199440?wl_ref=list_tr_10_chart" onclick="
#  " title="Red Velvet (레드벨벳)">Red Velvet (레드벨벳)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20144731?wl_ref=list_tr_11_chart" onclick="
#  " title="The Perfect Red Velvet - The 2nd Album Repackage">The Perfect Red Velvet - The 2nd Album Repackage</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30934033',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30934033');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30934033');
#  " track_title="Bad Boy">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30934033','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30934033, 382170, 'Y', 'Y', 'Y', 'Y', 30934033, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="Red Velvet (레드벨벳)" artist_id="80199440" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30934033','','20144731','bugs.music.listenRadioFromSeed(\'30934033\',\'track\');','N', 'Y', '_chart');
#  " track_title="Bad Boy">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20142247" artistid="80259080" multiartist="N" mvid="378510" rowtype="track" trackid="30919400">
#  <input name="_isStream" type="hidden" value="30919400">
#  <input name="_isDown" type="hidden" value="30919400"/>
#  <td class="check"><input disc_id="1" name="check" title="Roller Coaster" type="checkbox" value="30919400"/></td>
#  <td>
#  <div class="ranking">
#  <strong>14</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20142247?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Offset 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201422/20142247.jpg?version=20180118002521"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30919400?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30919400',true);
#  " title="Roller Coaster">Roller Coaster</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80259080?wl_ref=list_tr_10_chart" onclick="
#  " title="청하">청하</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20142247?wl_ref=list_tr_11_chart" onclick="
#  " title="Offset">Offset</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30919400',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30919400');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30919400');
#  " track_title="Roller Coaster">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30919400','true','false','44.1','true','96', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30919400, 378510, 'Y', 'Y', 'Y', 'Y', 30919400, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="청하" artist_id="80259080" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30919400','','20142247','bugs.music.listenRadioFromSeed(\'30919400\',\'track\');','N', 'Y', '_chart');
#  " track_title="Roller Coaster">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20107410" artistid="80223033" multiartist="N" mvid="343290" rowtype="track" trackid="30713225">
#  <input name="_isStream" type="hidden" value="30713225">
#  <input name="_isDown" type="hidden" value="30713225"/>
#  <td class="check"><input disc_id="1" name="check" title="선물" type="checkbox" value="30713225"/></td>
#  <td>
#  <div class="ranking">
#  <strong>15</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20107410?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Moonlight 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201074/20107410.jpg?version=20170822040542"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30713225?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30713225',true);
#  " title="선물">선물</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80223033?wl_ref=list_tr_10_chart" onclick="
#  " title="멜로망스(MeloMance)">멜로망스(MeloMance)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20107410?wl_ref=list_tr_11_chart" onclick="
#  " title="Moonlight">Moonlight</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30713225',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30713225');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30713225');
#  " track_title="선물">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30713225','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30713225, 343290, 'Y', 'Y', 'Y', 'Y', 30713225, 'N','OVER_15', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="멜로망스(MeloMance)" artist_id="80223033" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30713225','','20107410','bugs.music.listenRadioFromSeed(\'30713225\',\'track\');','N', 'Y', '_chart');
#  " track_title="선물">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="553693" artistid="80178003" multiartist="N" mvid="0" rowtype="track" trackid="4694464">
#  <input name="_isStream" type="hidden" value="4694464">
#  <input name="_isDown" type="hidden" value="4694464"/>
#  <td class="check"><input disc_id="1" name="check" title="Handclap" type="checkbox" value="4694464"/></td>
#  <td>
#  <div class="ranking">
#  <strong>16</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/553693?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Fitz and The Tantrums [Deluxe] 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/5536/553693.jpg?version=20180131002608"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/4694464?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('4694464',true);
#  " title="Handclap">Handclap</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178003?wl_ref=list_tr_10_chart" onclick="
#  " title="Fitz &amp; The Tantrums">Fitz &amp; The Tantrums</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/553693?wl_ref=list_tr_11_chart" onclick="
#  " title="Fitz and The Tantrums [Deluxe]">Fitz and The Tantrums [Deluxe]</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('4694464',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('4694464');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'4694464');
#  " track_title="Handclap">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'4694464','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="Fitz &amp; The Tantrums" artist_id="80178003" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'4694464','','553693','bugs.music.listenRadioFromSeed(\'4694464\',\'track\');','N', 'Y', '_chart');
#  " track_title="Handclap">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="719455" artistid="80177857" multiartist="N" mvid="390490" rowtype="track" trackid="5145545">
#  <input name="_isStream" type="hidden" value="5145545">
#  <input name="_isDown" type="hidden" value="5145545"/>
#  <td class="check"><input disc_id="1" name="check" title="별 바람 꽃 태양" type="checkbox" value="5145545"/></td>
#  <td>
#  <div class="ranking">
#  <strong>17</strong>
#  <p class="change up"><span class="arrow"></span> <em>2</em> <span>계단 상승</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/719455?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Yellow Flower 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/7194/719455.jpg?version=20180309185321"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/5145545?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5145545',true);
#  " title="별 바람 꽃 태양">별 바람 꽃 태양</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80177857?wl_ref=list_tr_10_chart" onclick="
#  " title="마마무(Mamamoo)">마마무(Mamamoo)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/719455?wl_ref=list_tr_11_chart" onclick="
#  " title="Yellow Flower">Yellow Flower</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('5145545',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('5145545');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'5145545');
#  " track_title="별 바람 꽃 태양">내 앨범에 담기</a>
#  </td>
#  <td>
# ...
#  " title="종현 소품집 '이야기 Op.2'">종현 소품집 '이야기 Op.2'</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30634137',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30634137');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30634137');
#  " track_title="Lonely (Feat. 태연)">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30634137','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30634137, 328130, 'Y', 'Y', 'Y', 'Y', 30634137, 'N','OVER_12', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="종현 (JONGHYUN)" artist_id="80044238" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30634137','','20094377','bugs.music.listenRadioFromSeed(\'30634137\',\'track\');','N', 'Y', '_chart');
#  " track_title="Lonely (Feat. 태연)">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20114619" artistid="80022186" multiartist="N" mvid="350130" rowtype="track" trackid="30757392">
#  <input name="_isStream" type="hidden" value="30757392">
#  <input name="_isDown" type="hidden" value="30757392"/>
#  <td class="check"><input disc_id="1" name="check" title="가시나" type="checkbox" value="30757392"/></td>
#  <td>
#  <div class="ranking">
#  <strong>96</strong>
#  <p class="change up"><span class="arrow"></span> <em>2</em> <span>계단 상승</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20114619?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="SUNMI SPECIAL EDITION [가시나] 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201146/20114619.jpg?version=20170906034143"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30757392?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30757392',true);
#  " title="가시나">가시나</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80022186?wl_ref=list_tr_10_chart" onclick="
#  " title="선미">선미</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20114619?wl_ref=list_tr_11_chart" onclick="
#  " title="SUNMI SPECIAL EDITION [가시나]">SUNMI SPECIAL EDITION [가시나]</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30757392',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30757392');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30757392');
#  " track_title="가시나">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30757392','true','false','44.1','true','96', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30757392, 350130, 'Y', 'Y', 'Y', 'Y', 30757392, 'N','OVER_15', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="선미" artist_id="80022186" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30757392','','20114619','bugs.music.listenRadioFromSeed(\'30757392\',\'track\');','N', 'Y', '_chart');
#  " track_title="가시나">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20152077" artistid="80178434" multiartist="N" mvid="0" rowtype="track" trackid="30977204">
#  <input name="_isStream" type="hidden" value="30977204">
#  <input name="_isDown" type="hidden" value="30977204"/>
#  <td class="check"><input disc_id="1" name="check" title="바람" type="checkbox" value="30977204"/></td>
#  <td>
#  <div class="ranking">
#  <strong>97</strong>
#  <p class="change down"><span class="arrow"></span> <em>15</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="바람 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201520/20152077.jpg?version=20180313132921"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30977204?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30977204',true);
#  " title="바람">바람</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178434?wl_ref=list_tr_10_chart" onclick="
#  " title="헤이즈(HEIZE)">헤이즈(HEIZE)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20152077?wl_ref=list_tr_11_chart" onclick="
#  " title="바람">바람</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30977204',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30977204');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30977204');
#  " track_title="바람">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30977204','true','false','44.1','true','48', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="헤이즈(HEIZE)" artist_id="80178434" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30977204','','20152077','bugs.music.listenRadioFromSeed(\'30977204\',\'track\');','N', 'Y', '_chart');
#  " track_title="바람">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20125506" artistid="20020936" multiartist="N" mvid="0" rowtype="track" trackid="30820107">
#  <input name="_isStream" type="hidden" value="30820107">
#  <input name="_isDown" type="hidden" value="30820107"/>
#  <td class="check"><input disc_id="1" name="check" title="결혼" type="checkbox" value="30820107"/></td>
#  <td>
#  <div class="ranking">
#  <strong>98</strong>
#  <p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20125506?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="이번 생은 처음이라 (tvN 월화드라마) OST - Part.4 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201255/20125506.jpg?version=20171025002932"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30820107?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30820107',true);
#  " title="결혼">결혼</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/20020936?wl_ref=list_tr_10_chart" onclick="
#  " title="문문(MoonMoon)">문문(MoonMoon)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20125506?wl_ref=list_tr_11_chart" onclick="
#  " title="이번 생은 처음이라 (tvN 월화드라마) OST - Part.4">이번 생은 처음이라 (tvN 월화드라마) OST - Part.4</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30820107',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30820107');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30820107');
#  " track_title="결혼">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30820107','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <span class="btn viewMV">영상 재생 불가</span>
#  </td>
#  <td>
#  <a artist_disp_nm="문문(MoonMoon)" artist_id="20020936" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30820107','','20125506','bugs.music.listenRadioFromSeed(\'30820107\',\'track\');','N', 'Y', '_chart');
#  " track_title="결혼">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20150657" artistid="80178297" multiartist="N" mvid="389130" rowtype="track" trackid="30967881">
#  <input name="_isStream" type="hidden" value="30967881">
#  <input name="_isDown" type="hidden" value="30967881"/>
#  <td class="check"><input disc_id="1" name="check" title="너 하나만 (Feat. 효린)" type="checkbox" value="30967881"/></td>
#  <td>
#  <div class="ranking">
#  <strong>99</strong>
#  <p class="change down"><span class="arrow"></span> <em>29</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20150657?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="Eyes On You 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201506/20150657.jpg?version=20180313112001"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30967881?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30967881',true);
#  " title="너 하나만 (Feat. 효린)">너 하나만 (Feat. 효린)</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80178297?wl_ref=list_tr_10_chart" onclick="
#  " title="GOT7 (갓세븐)">GOT7 (갓세븐)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20150657?wl_ref=list_tr_11_chart" onclick="
#  " title="Eyes On You">Eyes On You</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30967881',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30967881');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30967881');
#  " track_title="너 하나만 (Feat. 효린)">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30967881','true','false','44.1','true','96', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30967881, 389130, 'Y', 'Y', 'Y', 'Y', 30967881, 'N','ALL', 'N');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="GOT7 (갓세븐)" artist_id="80178297" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30967881','','20150657','bugs.music.listenRadioFromSeed(\'30967881\',\'track\');','N', 'Y', '_chart');
#  " track_title="너 하나만 (Feat. 효린)">기타 기능</a>
#  </td>
#  </input></tr>,
#  <tr albumid="20112327" artistid="80288421" multiartist="N" mvid="348190" rowtype="track" trackid="30744129">
#  <input name="_isStream" type="hidden" value="30744129">
#  <input name="_isDown" type="hidden" value="30744129"/>
#  <td class="check"><input disc_id="1" name="check" title="에너제틱 (Energetic)" type="checkbox" value="30744129"/></td>
#  <td>
#  <div class="ranking">
#  <strong>100</strong>
#  <p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/20112327?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="1X1=1(TO BE ONE) 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/201123/20112327.jpg?version=20180313002448"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/30744129?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30744129',true);
#  " title="에너제틱 (Energetic)">에너제틱 (Energetic)</a>
#  </p>
#  </th>
#  <td class="left">
#  <p class="artist">
#  <a href="https://music.bugs.co.kr/artist/80288421?wl_ref=list_tr_10_chart" onclick="
#  " title="Wanna One(워너원)">Wanna One(워너원)</a>
#  </p>
#  </td>
#  <td class="left">
#  <a class="album" href="https://music.bugs.co.kr/album/20112327?wl_ref=list_tr_11_chart" onclick="
#  " title="1X1=1(TO BE ONE)">1X1=1(TO BE ONE)</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30744129',true);
#  ">듣기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30744129');
#  ">재생목록에 추가</a>
#  </td>
#  <td>
#  <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30744129');
#  " track_title="에너제틱 (Energetic)">내 앨범에 담기</a>
#  </td>
#  <td>
#  <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30744129','true','true','44.1','false','', null );
#  "><em class="flac">flac </em>다운로드</a>
#  </td>
#  <td>
#  <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
#  bugs.layermenu.mv(this,30744129, 348190, 'Y', 'Y', 'Y', 'Y', 30744129, 'N','ALL', 'Y');
#  ">영상 재생</a>
#  </td>
#  <td>
#  <a artist_disp_nm="Wanna One(워너원)" artist_id="80288421" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
#  bugs.layermenu.trackMoreAction(this,'30744129','','20112327','bugs.music.listenRadioFromSeed(\'30744129\',\'track\');','N', 'Y', '_chart');
#  " track_title="에너제틱 (Energetic)">기타 기능</a>
#  </td>
#  </input></tr>]

# %%
import re

bugs_daily=[]

for d_song in daily_songs: # 각 노래 정보 가져오기
    rank = int(d_song.find('strong').get_text())
    updown = d_song.find('p', class_='change').get_text()
    title = d_song.find('th', scope='row').get_text().strip()
    singer = ' '.join(list(set(re.split('\r\n|\n',d_song.find('p', class_='artist').get_text().strip())))).strip()
    album = d_song.find('a', class_='album').get_text()
    
    if '없음' in updown:
        updown = updown.replace("변동없음","")
    elif '상승'in updown:
        updown = updown.replace("계단 상승", "")
    elif '하락' in updown:
        updown = updown.replace("계단 하락", "")
    else:
        updown = 0
       
    
    #앨범 발매일
    album_page = d_song.find('a')['href']
    page_open= urlopen(album_page)
    album_pg = BeautifulSoup(page_open, 'html.parser')
    #dates = album_pg.find(class_='info').tbody.find_all('tr')[2]

    r_date = album_pg.find('tbody').find('time').text
    
    bugs_daily.append([rank, int(updown), title, singer, album, r_date])
        
    print('순위 :', rank)
    print('등락 :', updown)
    print('곡 :', title)
    print('가수 :', singer)
    print('앨범 :', album)
    print('발매일 :', r_date)
    print()
# Out:
# 순위 : 1
# 등락 : 0
# 곡 : 꽃 길
# 가수 : BIGBANG
# 앨범 : 꽃 길
# 발매일 : 2018.03.13
#
# 순위 : 2
# 등락 : 0
# 곡 : My Blossom
# 가수 : 소유 (SOYOU)
# 앨범 : My Blossom
# 발매일 : 2018.03.12
#
# 순위 : 3
# 등락 :  2
# 곡 : Jenga (Feat. Gaeko)
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 4
# 등락 :  1
# 곡 : 별이 빛나는 밤
# 가수 : 마마무(Mamamoo)
# 앨범 : Yellow Flower
# 발매일 : 2018.03.07
#
# 순위 : 5
# 등락 :  1
# 곡 : 내가 더 나빠
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 6
# 등락 :  1
# 곡 : You
# 가수 : 멜로망스(MeloMance)
# 앨범 : 투유 프로젝트 - 슈가맨2 Part.2
# 발매일 : 2018.01.22
#
# 순위 : 7
# 등락 :  1
# 곡 : 사랑을 했다 (LOVE SCENARIO)
# 가수 : iKON
# 앨범 : Return
# 발매일 : 2018.01.25
#
# 순위 : 8
# 등락 : 0
# 곡 : 그때 헤어지면 돼
# 가수 : 로이킴
# 앨범 : 그때 헤어지면 돼
# 발매일 : 2018.02.12
#
# 순위 : 9
# 등락 :  2
# 곡 : 괜찮냐고
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 10
# 등락 :  1
# 곡 : 뿜뿜
# 가수 : 모모랜드(MOMOLAND)
# 앨범 : GREAT!
# 발매일 : 2018.01.03
#
# 순위 : 11
# 등락 :  1
# 곡 : 그날처럼
# 가수 : 장덕철
# 앨범 : 그날처럼
# 발매일 : 2017.11.28
#
# 순위 : 12
# 등락 : 0
# 곡 : 눈사람
# 가수 : 정승환
# 앨범 : 그리고 봄
# 발매일 : 2018.02.19
#
# 순위 : 13
# 등락 :  2
# 곡 : Bad Boy
# 가수 : Red Velvet (레드벨벳)
# 앨범 : The Perfect Red Velvet - The 2nd Album Repackage
# 발매일 : 2018.01.29
#
# 순위 : 14
# 등락 :  1
# 곡 : Roller Coaster
# 가수 : 청하
# 앨범 : Offset
# 발매일 : 2018.01.17
#
# 순위 : 15
# 등락 : 0
# 곡 : 선물
# 가수 : 멜로망스(MeloMance)
# 앨범 : Moonlight
# 발매일 : 2017.07.10
#
# 순위 : 16
# 등락 : 0
# 곡 : Handclap
# 가수 : Fitz & The Tantrums
# 앨범 : Fitz and The Tantrums [Deluxe]
# 발매일 : 2017.07.28
#
# 순위 : 17
# 등락 :  2
# 곡 : 별 바람 꽃 태양
# 가수 : 마마무(Mamamoo)
# 앨범 : Yellow Flower
# 발매일 : 2018.03.07
#
# 순위 : 18
# 등락 :  4
# 곡 : 잘 살길 바래 (With. DAVII)
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 19
# 등락 :  1
# 곡 : instagram
# 가수 : DEAN(딘)
# 앨범 : instagram
# 발매일 : 2017.12.26
#
# 순위 : 20
# 등락 : 0
# 곡 : 약속해요 (I.P.U.)
# 가수 : Wanna One(워너원)
# 앨범 : 약속해요 (I.P.U.) - Special Theme Track
# 발매일 : 2018.03.05
#
# 순위 : 21
# 등락 : 0
# 곡 : Action! (feat. GRAY)
# 가수 : DPR LIVE
# 앨범 : Action!
# 발매일 : 2018.03.13
#
# 순위 : 22
# 등락 :  1
# 곡 : My Way
# 가수 : 이수
# 앨범 : 돈꽃 (MBC 토요드라마) OST - Part.1
# 발매일 : 2017.11.11
#
# 순위 : 23
# 등락 : 0
# 곡 : Havana (feat. Young Thug)
# 가수 : Camila Cabello(카밀라 카베요)
# 앨범 : Camila
# 발매일 : 2018.01.12
#
# 순위 : 24
# 등락 :  2
# 곡 : MIANHAE
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 25
# 등락 :  1
# 곡 : 너 없는 시간들
# 가수 : 다비치
# 앨범 : &10
# 발매일 : 2018.01.25
#
# 순위 : 26
# 등락 : 0
# 곡 : 비가 온다
# 가수 : 정승환
# 앨범 : 그리고 봄
# 발매일 : 2018.02.19
#
# 순위 : 27
# 등락 :  2
# 곡 : 미안해
# 가수 : 양다일
# 앨범 : inside
# 발매일 : 2017.12.29
#
# 순위 : 28
# 등락 : 0
# 곡 : 이 별
# 가수 : 길구봉구
# 앨범 : Star
# 발매일 : 2017.09.18
#
# 순위 : 29
# 등락 :  12
# 곡 : Look
# 가수 : GOT7 (갓세븐)
# 앨범 : Eyes On You
# 발매일 : 2018.03.12
#
# 순위 : 30
# 등락 :  1
# 곡 : 주인공
# 가수 : 선미
# 앨범 : 주인공
# 발매일 : 2018.01.18
#
# 순위 : 31
# 등락 :  3
# 곡 : #첫사랑
# 가수 : 볼빨간사춘기
# 앨범 : #첫사랑
# 발매일 : 2018.01.10
#
# 순위 : 32
# 등락 :  5
# 곡 : 밤편지
# 가수 : 아이유(IU)
# 앨범 : 밤편지
# 발매일 : 2017.03.24
#
# 순위 : 33
# 등락 :  3
# 곡 : 눈 떠보니 이별이더라
# 가수 : 포맨
# 앨범 : REMEMBER ME
# 발매일 : 2017.10.24
#
# 순위 : 34
# 등락 :  2
# 곡 : 비행운
# 가수 : 문문(MoonMoon)
# 앨범 : LIFE IS BEAUTY FULL
# 발매일 : 2016.11.10
#
# 순위 : 35
# 등락 : 0
# 곡 : 비밀정원
# 가수 : 오마이걸(OH MY GIRL)
# 앨범 : 비밀정원
# 발매일 : 2018.01.09
#
# 순위 : 36
# 등락 :  3
# 곡 : all of my life
# 가수 : 박원
# 앨범 : 0M
# 발매일 : 2017.07.27
#
# 순위 : 37
# 등락 :  4
# 곡 : 밤이 되니까
# 가수 : 펀치 (Punch)
# 앨범 : 밤이 되니까
# 발매일 : 2017.09.29
#
# 순위 : 38
# 등락 : 0
# 곡 : 가을 안부
# 가수 : 먼데이 키즈(Monday Kiz)
# 앨범 : 가을 안부
# 발매일 : 2017.10.14
#
# 순위 : 39
# 등락 :  2
# 곡 : 좋니
# 가수 : 윤종신
# 앨범 : LISTEN 010 좋니
# 발매일 : 2017.06.22
#
# 순위 : 40
# 등락 :  9
# 곡 : 애쓰지 마요
# 가수 : 박보람
# 앨범 : 애쓰지 마요
# 발매일 : 2018.02.13
#
# 순위 : 41
# 등락 :  1
# 곡 : 짙어져
# 가수 : 멜로망스(MeloMance)
# 앨범 : 옐로우 (Yellow - 웹드라마) OST - Part.2
# 발매일 : 2017.10.15
#
# 순위 : 42
# 등락 :  1
# 곡 : 봉제선 (Feat. 수란)
# 가수 : 다이나믹 듀오(Dynamic Duo)
# 앨범 : 봉제선
# 발매일 : 2018.02.07
#
# 순위 : 43
# 등락 : 0
# 곡 : DNA
# 가수 : 방탄소년단
# 앨범 : LOVE YOURSELF 承 'Her'
# 발매일 : 2017.09.18
#
# 순위 : 44
# 등락 :  4
# 곡 : Shape Of You
# 가수 : Ed Sheeran(에드 시런)
# 앨범 : ÷ [Deluxe]
# 발매일 : 2017.03.03
#
# 순위 : 45
# 등락 :  3
# 곡 : 그리워하다
# 가수 : 비투비(BTOB)
# 앨범 : Brother Act.
# 발매일 : 2017.10.16
#
# 순위 : 46
# 등락 :  1
# 곡 : 봄날
# 가수 : 방탄소년단
# 앨범 : YOU NEVER WALK ALONE
# 발매일 : 2017.02.13
#
# 순위 : 47
# 등락 :  2
# 곡 : 노력
# 가수 : 박원
# 앨범 : 1/24
# 발매일 : 2016.11.17
#
# 순위 : 48
# 등락 :  3
# 곡 : Heart Shaker
# 가수 : TWICE (트와이스)
# 앨범 : Merry & Happy
# 발매일 : 2017.12.11
#
# 순위 : 49
# 등락 :  5
# 곡 : 오늘밤도
# 가수 : 펀치 (Punch)
# 앨범 : 오늘밤도
# 발매일 : 2018.02.06
#
# 순위 : 50
# 등락 :  5
# 곡 : 기억의 빈자리
# 가수 : 나얼(Na-Ul)
# 앨범 : 기억의 빈자리
# 발매일 : 2017.11.29
#
# 순위 : 51
# 등락 :  6
# 곡 : LIKEY
# 가수 : TWICE (트와이스)
# 앨범 : twicetagram
# 발매일 : 2017.10.30
#
# 순위 : 52
# 등락 : 0
# 곡 : 피카부 (Peek-A-Boo)
# 가수 : Red Velvet (레드벨벳)
# 앨범 : Perfect Velvet - The 2nd Album
# 발매일 : 2017.11.17
#
# 순위 : 53
# 등락 :  7
# 곡 : 고무줄다리기 (Rubber Band)
# 가수 : iKON
# 앨범 : 고무줄다리기 (Rubber Band)
# 발매일 : 2018.03.05
#
# 순위 : 54
# 등락 :  2
# 곡 : Thunder
# 가수 : Imagine Dragons(이매진 드래곤스)
# 앨범 : Evolve
# 발매일 : 2018.02.22
#
# 순위 : 55
# 등락 :  5
# 곡 : 후유증
# 가수 : 민경훈
# 앨범 : 후유증
# 발매일 : 2018.02.17
#
# 순위 : 56
# 등락 :  3
# 곡 : 답장
# 가수 : 김동률
# 앨범 : 답장
# 발매일 : 2018.01.11
#
# 순위 : 57
# 등락 :  1
# 곡 : There's Nothing Holdin' Me Back
# 가수 : Shawn Mendes(션 멘데스)
# 앨범 : Illuminate [New Deluxe Ver.]
# 발매일 : 2017.04.21
#
# 순위 : 58
# 등락 :  4
# 곡 : 좋아
# 가수 : 민서
# 앨범 : 2017 월간 윤종신 11월호
# 발매일 : 2017.11.15
#
# 순위 : 59
# 등락 :  5
# 곡 : 빛 (Hope)
# 가수 : H.O.T.
# 앨범 : Resurrection
# 발매일 : 1998.09
#
# 순위 : 60
# 등락 :  1
# 곡 : 마지막처럼
# 가수 : BLACKPINK
# 앨범 : 마지막처럼
# 발매일 : 2017.06.22
#
# 순위 : 61
# 등락 :  10
# 곡 : All The Stars (영화 '블랙 팬서' OST)
# 가수 : Kendrick Lamar(켄드릭 라마)
# 앨범 : 블랙 팬서 더 앨범 (Black Panther The Album Music From And Inspired By)
# 발매일 : 2018.02.09
#
# 순위 : 62
# 등락 :  26
# 곡 : 파랑새
# 가수 : 에이프릴(APRIL)
# 앨범 : 에이프릴(APRIL) 5th Mini Album 'The Blue'
# 발매일 : 2018.03.12
#
# 순위 : 63
# 등락 :  6
# 곡 : FRIENDS
# 가수 : Marshmello(마시멜로)
# 앨범 : FRIENDS
# 발매일 : 2018.02.09
#
# 순위 : 64
# 등락 :  3
# 곡 : 시차 (We Are) (Feat. 로꼬 & GRAY)
# 가수 : 우원재
# 앨범 : 시차 (We Are)
# 발매일 : 2017.09.04
#
# 순위 : 65
# 등락 : 0
# 곡 : 나의 사춘기에게
# 가수 : 볼빨간사춘기
# 앨범 : Red Diary Page.1
# 발매일 : 2017.09.28
#
# 순위 : 66
# 등락 :  6
# 곡 : 비
# 가수 : 폴킴(Paul Kim)
# 앨범 : 비
# 발매일 : 2016.06.21
#
# 순위 : 67
# 등락 :  4
# 곡 : 다른사람을 사랑하고 있어
# 가수 : 수지(SUZY)
# 앨범 : Faces of Love
# 발매일 : 2018.01.29
#
# 순위 : 68
# 등락 :  4
# 곡 : 비도 오고 그래서 (Feat. 신용재)
# 가수 : 헤이즈(HEIZE)
# 앨범 : /// (너 먹구름 비)
# 발매일 : 2017.06.26
#
# 순위 : 69
# 등락 :  2
# 곡 : 첫눈처럼 너에게 가겠다
# 가수 : 에일리(Ailee)
# 앨범 : 도깨비 (tvN 금토드라마) OST - Part.9
# 발매일 : 2017.01.07
#
# 순위 : 70
# 등락 :  2
# 곡 : 다시 쓰고 싶어
# 가수 : 에일리(Ailee)
# 앨범 : 이런 꽃 같은 엔딩 (웹드라마) OST - Part.3
# 발매일 : 2018.02.09
#
# 순위 : 71
# 등락 :  4
# 곡 : Closer (feat. Halsey)
# 가수 : The Chainsmokers(체인스모커스)
# 앨범 : Collage
# 발매일 : 2016.11.05
#
# 순위 : 72
# 등락 : 0
# 곡 : Candy (캔디)
# 가수 : H.O.T.
# 앨범 : We Hate All Kinds Of Violence
# 발매일 : 1996.09
#
# 순위 : 73
# 등락 :  2
# 곡 : 바보야
# 가수 : 허각
# 앨범 : 바보야
# 발매일 : 2017.11.27
#
# 순위 : 74
# 등락 :  1
# 곡 : 빨간 맛 (Red Flavor)
# 가수 : Red Velvet (레드벨벳)
# 앨범 : The Red Summer - Summer Mini Album
# 발매일 : 2017.07.09
#
# 순위 : 75
# 등락 :  2
# 곡 : REALLY REALLY
# 가수 : WINNER
# 앨범 : FATE NUMBER FOR
# 발매일 : 2017.04.04
#
# 순위 : 76
# 등락 : 0
# 곡 : 꿈꾸는 마음으로
# 가수 : 우주소녀
# 앨범 : Dream Your Dream
# 발매일 : 2018.02.27
#
# 순위 : 77
# 등락 :  1
# 곡 : 연애소설 (Feat. 아이유)
# 가수 : 에픽하이 (EPIK HIGH)
# 앨범 : WE'VE DONE SOMETHING WONDERFUL
# 발매일 : 2017.10.23
#
# 순위 : 78
# 등락 :  1
# 곡 : 이별 뒷면
# 가수 : 권진아
# 앨범 : 이런 꽃 같은 엔딩 (웹드라마) OST - Part.2
# 발매일 : 2018.02.02
#
# 순위 : 79
# 등락 :  5
# 곡 : 팔레트 (Feat. G-DRAGON)
# 가수 : 아이유(IU)
# 앨범 : Palette
# 발매일 : 2017.04.21
#
# 순위 : 80
# 등락 :  14
# 곡 : Love Letter (언약)
# 가수 : 투샤이(2Shai)
# 앨범 : Love Letter
# 발매일 : 2003.09.08
#
# 순위 : 81
# 등락 :  1
# 곡 : 한숨
# 가수 : 이하이
# 앨범 : SEOULITE
# 발매일 : 2016.03.09
#
# 순위 : 82
# 등락 :  4
# 곡 : 썸 탈꺼야
# 가수 : 볼빨간사춘기
# 앨범 : Red Diary Page.1
# 발매일 : 2017.09.28
#
# 순위 : 83
# 등락 :  2
# 곡 : 너였다면
# 가수 : 정승환
# 앨범 : 또 오해영 (tvN 월화드라마) OST - Part.5
# 발매일 : 2016.05.31
#
# 순위 : 84
# 등락 : 0
# 곡 : 고민보다 Go
# 가수 : 방탄소년단
# 앨범 : LOVE YOURSELF 承 'Her'
# 발매일 : 2017.09.18
#
# 순위 : 85
# 등락 :  5
# 곡 : What Lovers Do (feat. SZA)
# 가수 : Maroon 5(마룬 파이브)
# 앨범 : Red Pill Blues [Deluxe Edition]
# 발매일 : 2017.11.03
#
# 순위 : 86
# 등락 :  1
# 곡 : True Love
# 가수 : 김성규
# 앨범 : 1st Album '10 Stories'
# 발매일 : 2018.02.26
#
# 순위 : 87
# 등락 :  4
# 곡 : HOLIDAY (Feat. DPR LIVE)
# 가수 : 수지(SUZY)
# 앨범 : Faces of Love
# 발매일 : 2018.01.29
#
# 순위 : 88
# 등락 :  4
# 곡 : 그때의 나, 그때의 우리
# 가수 : 어반 자카파(Urban Zakapa)
# 앨범 : 그때의 나, 그때의 우리
# 발매일 : 2017.11.08
#
# 순위 : 89
# 등락 :  1
# 곡 : 좋았을걸
# 가수 : 헤이즈(HEIZE)
# 앨범 : 슬기로운 감빵생활 (tvN 수목드라마) OST - Part.5
# 발매일 : 2017.12.14
#
# 순위 : 90
# 등락 :  7
# 곡 : 폰서트
# 가수 : 10cm(십센치)
# 앨범 : 4.0
# 발매일 : 2017.09.01
#
# 순위 : 91
# 등락 :  3
# 곡 : Beautiful
# 가수 : Wanna One(워너원)
# 앨범 : 1-1=0 (NOTHING WITHOUT YOU)
# 발매일 : 2017.11.13
#
# 순위 : 92
# 등락 :  3
# 곡 : Perhaps Love (사랑인가요) (Prod.By 박근태)
# 가수 : 에릭남(Eric Nam)
# 앨범 : Your BGM Vol.1
# 발매일 : 2017.09.29
#
# 순위 : 93
# 등락 :  6
# 곡 : 사랑은 아프다
# 가수 : 이승철
# 앨범 : 미스티 (JTBC 금토드라마) OST - Part.1
# 발매일 : 2018.02.17
#
# 순위 : 94
# 등락 :  20
# 곡 : 벚꽃 엔딩
# 가수 : 버스커 버스커(Busker Busker)
# 앨범 : 버스커 버스커 1집
# 발매일 : 2012.03.29
#
# 순위 : 95
# 등락 :  2
# 곡 : Lonely (Feat. 태연)
# 가수 : 종현 (JONGHYUN)
# 앨범 : 종현 소품집 '이야기 Op.2'
# 발매일 : 2017.04.24
#
# 순위 : 96
# 등락 :  2
# 곡 : 가시나
# 가수 : 선미
# 앨범 : SUNMI SPECIAL EDITION [가시나]
# 발매일 : 2017.08.22
#
# 순위 : 97
# 등락 :  15
# 곡 : 바람
# 가수 : 헤이즈(HEIZE)
# 앨범 : 바람
# 발매일 : 2018.03.08
#
# 순위 : 98
# 등락 :  2
# 곡 : 결혼
# 가수 : 문문(MoonMoon)
# 앨범 : 이번 생은 처음이라 (tvN 월화드라마) OST - Part.4
# 발매일 : 2017.10.24
# 순위 : 99
# 등락 :  29
# 곡 : 너 하나만 (Feat. 효린)
# 가수 : GOT7 (갓세븐)
# 앨범 : Eyes On You
# 발매일 : 2018.03.12
#
# 순위 : 100
# 등락 :  1
# 곡 : 에너제틱 (Energetic)
# 가수 : Wanna One(워너원)
# 앨범 : 1X1=1(TO BE ONE)
# 발매일 : 2017.08.07

# %%
#bugs_daily
# Out:
# [[1, 0, '꽃 길', 'BIGBANG', '꽃 길', '2018.03.13'],
#  [2, 0, 'My Blossom', '소유 (SOYOU)', 'My Blossom', '2018.03.12'],
#  [3, 2, 'Jenga (Feat. Gaeko)', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [4, 1, '별이 빛나는 밤', '마마무(Mamamoo)', 'Yellow Flower', '2018.03.07'],
#  [5, 1, '내가 더 나빠', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [6, 1, 'You', '멜로망스(MeloMance)', '투유 프로젝트 - 슈가맨2 Part.2', '2018.01.22'],
#  [7, 1, '사랑을 했다 (LOVE SCENARIO)', 'iKON', 'Return', '2018.01.25'],
#  [8, 0, '그때 헤어지면 돼', '로이킴', '그때 헤어지면 돼', '2018.02.12'],
#  [9, 2, '괜찮냐고', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [10, 1, '뿜뿜', '모모랜드(MOMOLAND)', 'GREAT!', '2018.01.03'],
#  [11, 1, '그날처럼', '장덕철', '그날처럼', '2017.11.28'],
#  [12, 0, '눈사람', '정승환', '그리고 봄', '2018.02.19'],
#  [13,
#   2,
#   'Bad Boy',
#   'Red Velvet (레드벨벳)',
#   'The Perfect Red Velvet - The 2nd Album Repackage',
#   '2018.01.29'],
#  [14, 1, 'Roller Coaster', '청하', 'Offset', '2018.01.17'],
#  [15, 0, '선물', '멜로망스(MeloMance)', 'Moonlight', '2017.07.10'],
#  [16,
#   0,
#   'Handclap',
#   'Fitz & The Tantrums',
#   'Fitz and The Tantrums [Deluxe]',
#   '2017.07.28'],
#  [17, 2, '별 바람 꽃 태양', '마마무(Mamamoo)', 'Yellow Flower', '2018.03.07'],
#  [18, 4, '잘 살길 바래 (With. DAVII)', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [19, 1, 'instagram', 'DEAN(딘)', 'instagram', '2017.12.26'],
#  [20,
#   0,
#   '약속해요 (I.P.U.)',
#   'Wanna One(워너원)',
#   '약속해요 (I.P.U.) - Special Theme Track',
#   '2018.03.05'],
#  [21, 0, 'Action! (feat. GRAY)', 'DPR LIVE', 'Action!', '2018.03.13'],
#  [22, 1, 'My Way', '이수', '돈꽃 (MBC 토요드라마) OST - Part.1', '2017.11.11'],
#  [23,
#   0,
#   'Havana (feat. Young Thug)',
#   'Camila Cabello(카밀라 카베요)',
#   'Camila',
#   '2018.01.12'],
#  [24, 2, 'MIANHAE', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [25, 1, '너 없는 시간들', '다비치', '&10', '2018.01.25'],
#  [26, 0, '비가 온다', '정승환', '그리고 봄', '2018.02.19'],
#  [27, 2, '미안해', '양다일', 'inside', '2017.12.29'],
#  [28, 0, '이 별', '길구봉구', 'Star', '2017.09.18'],
#  [29, 12, 'Look', 'GOT7 (갓세븐)', 'Eyes On You', '2018.03.12'],
#  [30, 1, '주인공', '선미', '주인공', '2018.01.18'],
#  [31, 3, '#첫사랑', '볼빨간사춘기', '#첫사랑', '2018.01.10'],
#  [32, 5, '밤편지', '아이유(IU)', '밤편지', '2017.03.24'],
#  [33, 3, '눈 떠보니 이별이더라', '포맨', 'REMEMBER ME', '2017.10.24'],
#  [34, 2, '비행운', '문문(MoonMoon)', 'LIFE IS BEAUTY FULL', '2016.11.10'],
#  [35, 0, '비밀정원', '오마이걸(OH MY GIRL)', '비밀정원', '2018.01.09'],
#  [36, 3, 'all of my life', '박원', '0M', '2017.07.27'],
#  [37, 4, '밤이 되니까', '펀치 (Punch)', '밤이 되니까', '2017.09.29'],
#  [38, 0, '가을 안부', '먼데이 키즈(Monday Kiz)', '가을 안부', '2017.10.14'],
#  [39, 2, '좋니', '윤종신', 'LISTEN 010 좋니', '2017.06.22'],
#  [40, 9, '애쓰지 마요', '박보람', '애쓰지 마요', '2018.02.13'],
#  [41,
#   1,
#   '짙어져',
#   '멜로망스(MeloMance)',
#   '옐로우 (Yellow - 웹드라마) OST - Part.2',
#   '2017.10.15'],
#  [42, 1, '봉제선 (Feat. 수란)', '다이나믹 듀오(Dynamic Duo)', '봉제선', '2018.02.07'],
#  [43, 0, 'DNA', '방탄소년단', "LOVE YOURSELF 承 'Her'", '2017.09.18'],
#  [44, 4, 'Shape Of You', 'Ed Sheeran(에드 시런)', '÷ [Deluxe]', '2017.03.03'],
#  [45, 3, '그리워하다', '비투비(BTOB)', 'Brother Act.', '2017.10.16'],
#  [46, 1, '봄날', '방탄소년단', 'YOU NEVER WALK ALONE', '2017.02.13'],
#  [47, 2, '노력', '박원', '1/24', '2016.11.17'],
#  [48, 3, 'Heart Shaker', 'TWICE (트와이스)', 'Merry & Happy', '2017.12.11'],
#  [49, 5, '오늘밤도', '펀치 (Punch)', '오늘밤도', '2018.02.06'],
#  [50, 5, '기억의 빈자리', '나얼(Na-Ul)', '기억의 빈자리', '2017.11.29'],
#  [51, 6, 'LIKEY', 'TWICE (트와이스)', 'twicetagram', '2017.10.30'],
#  [52,
#   0,
#   '피카부 (Peek-A-Boo)',
#   'Red Velvet (레드벨벳)',
#   'Perfect Velvet - The 2nd Album',
#   '2017.11.17'],
#  [53, 7, '고무줄다리기 (Rubber Band)', 'iKON', '고무줄다리기 (Rubber Band)', '2018.03.05'],
#  [54, 2, 'Thunder', 'Imagine Dragons(이매진 드래곤스)', 'Evolve', '2018.02.22'],
#  [55, 5, '후유증', '민경훈', '후유증', '2018.02.17'],
#  [56, 3, '답장', '김동률', '답장', '2018.01.11'],
#  [57,
#   1,
#   "There's Nothing Holdin' Me Back",
#   'Shawn Mendes(션 멘데스)',
#   'Illuminate\xa0[New Deluxe Ver.]',
#   '2017.04.21'],
#  [58, 4, '좋아', '민서', '2017 월간 윤종신 11월호', '2017.11.15'],
#  [59, 5, '빛 (Hope)', 'H.O.T.', 'Resurrection', '1998.09'],
#  [60, 1, '마지막처럼', 'BLACKPINK', '마지막처럼', '2017.06.22'],
#  [61,
#   10,
#   "All The Stars (영화 '블랙 팬서' OST)",
#   'Kendrick Lamar(켄드릭 라마)',
#   '블랙 팬서 더 앨범 (Black Panther The Album Music From And Inspired By)',
#   '2018.02.09'],
#  [62,
#   26,
#   '파랑새',
#   '에이프릴(APRIL)',
#   "에이프릴(APRIL) 5th Mini Album 'The Blue'",
#   '2018.03.12'],
#  [63, 6, 'FRIENDS', 'Marshmello(마시멜로)', 'FRIENDS', '2018.02.09'],
#  [64, 3, '시차 (We Are) (Feat. 로꼬 & GRAY)', '우원재', '시차 (We Are)', '2017.09.04'],
#  [65, 0, '나의 사춘기에게', '볼빨간사춘기', 'Red Diary Page.1', '2017.09.28'],
#  [66, 6, '비', '폴킴(Paul Kim)', '비', '2016.06.21'],
#  [67, 4, '다른사람을 사랑하고 있어', '수지(SUZY)', 'Faces of Love', '2018.01.29'],
#  [68, 4, '비도 오고 그래서 (Feat. 신용재)', '헤이즈(HEIZE)', '/// (너 먹구름 비)', '2017.06.26'],
#  [69,
#   2,
#   '첫눈처럼 너에게 가겠다',
#   '에일리(Ailee)',
#   '도깨비 (tvN 금토드라마) OST - Part.9',
#   '2017.01.07'],
#  [70,
#   2,
#   '다시 쓰고 싶어',
#   '에일리(Ailee)',
#   '이런 꽃 같은 엔딩 (웹드라마) OST - Part.3',
#   '2018.02.09'],
#  [71,
#   4,
#   'Closer (feat. Halsey)',
#   'The Chainsmokers(체인스모커스)',
#   'Collage',
#   '2016.11.05'],
#  [72, 0, 'Candy (캔디)', 'H.O.T.', 'We Hate All Kinds Of Violence', '1996.09'],
#  [73, 2, '바보야', '허각', '바보야', '2017.11.27'],
#  [74,
#   1,
#   '빨간 맛 (Red Flavor)',
#   'Red Velvet (레드벨벳)',
#   'The Red Summer - Summer Mini Album',
#   '2017.07.09'],
#  [75, 2, 'REALLY REALLY', 'WINNER', 'FATE NUMBER FOR', '2017.04.04'],
#  [76, 0, '꿈꾸는 마음으로', '우주소녀', 'Dream Your Dream', '2018.02.27'],
#  [77,
#   1,
#   '연애소설 (Feat. 아이유)',
#   '에픽하이 (EPIK HIGH)',
#   "WE'VE DONE SOMETHING WONDERFUL",
#   '2017.10.23'],
#  [78, 1, '이별 뒷면', '권진아', '이런 꽃 같은 엔딩 (웹드라마) OST - Part.2', '2018.02.02'],
#  [79, 5, '팔레트 (Feat. G-DRAGON)', '아이유(IU)', 'Palette', '2017.04.21'],
#  [80, 14, 'Love Letter (언약)', '투샤이(2Shai)', 'Love Letter', '2003.09.08'],
#  [81, 1, '한숨', '이하이', 'SEOULITE', '2016.03.09'],
#  [82, 4, '썸 탈꺼야', '볼빨간사춘기', 'Red Diary Page.1', '2017.09.28'],
#  [83, 2, '너였다면', '정승환', '또 오해영 (tvN 월화드라마) OST - Part.5', '2016.05.31'],
#  [84, 0, '고민보다 Go', '방탄소년단', "LOVE YOURSELF 承 'Her'", '2017.09.18'],
#  [85,
#   5,
#   'What Lovers Do\xa0(feat. SZA)',
#   'Maroon 5(마룬 파이브)',
#   'Red Pill Blues [Deluxe Edition]',
#   '2017.11.03'],
#  [86, 1, 'True Love', '김성규', "1st Album '10 Stories'", '2018.02.26'],
#  [87,
#   4,
#   'HOLIDAY (Feat. DPR LIVE)',
#   '수지(SUZY)',
#   'Faces of Love',
#   '2018.01.29'],
#  [88,
#   4,
#   '그때의 나, 그때의 우리',
#   '어반 자카파(Urban Zakapa)',
#   '그때의 나, 그때의 우리',
#   '2017.11.08'],
#  [89,
#   1,
#   '좋았을걸',
#   '헤이즈(HEIZE)',
#   '슬기로운 감빵생활 (tvN 수목드라마) OST - Part.5',
#   '2017.12.14'],
#  [90, 7, '폰서트', '10cm(십센치)', '4.0', '2017.09.01'],
#  [91,
#   3,
#   'Beautiful',
#   'Wanna One(워너원)',
#   '1-1=0 (NOTHING WITHOUT YOU)',
#   '2017.11.13'],
#  [92,
#   3,
#   'Perhaps Love (사랑인가요) (Prod.By 박근태)',
#   '에릭남(Eric Nam)',
#   'Your BGM Vol.1',
#   '2017.09.29'],
#  [93, 6, '사랑은 아프다', '이승철', '미스티 (JTBC 금토드라마) OST - Part.1', '2018.02.17'],
#  [94, 20, '벚꽃 엔딩', '버스커 버스커(Busker Busker)', '버스커 버스커 1집', '2012.03.29'],
#  [95,
#   2,
#   'Lonely (Feat. 태연)',
#   '종현 (JONGHYUN)',
#   "종현 소품집 '이야기 Op.2'",
#   '2017.04.24'],
#  [96, 2, '가시나', '선미', 'SUNMI SPECIAL EDITION [가시나]', '2017.08.22'],
#  [97, 15, '바람', '헤이즈(HEIZE)', '바람', '2018.03.08'],
#  [98,
#   2,
#   '결혼',
#   '문문(MoonMoon)',
#   '이번 생은 처음이라 (tvN 월화드라마) OST - Part.4',
#   '2017.10.24'],
#  [99, 29, '너 하나만 (Feat. 효린)', 'GOT7 (갓세븐)', 'Eyes On You', '2018.03.12'],
#  [100,
#   1,
#   '에너제틱 (Energetic)',
#   'Wanna One(워너원)',
#   '1X1=1(TO BE ONE)',
#   '2017.08.07']]

# %%
import pandas as pd

#노래 정보 데이터 프레임 만들기
song_frame = pd.DataFrame(bugs_daily, columns=['순위','등락','bugs_제목','bugs_가수','bugs_앨범','bugs_발매일'])
song_frame.head()
# Out:
#    순위  등락              bugs_제목       bugs_가수        bugs_앨범    bugs_발매일
# 0   1   0                  꽃 길       BIGBANG            꽃 길  2018.03.13
# 1   2   0           My Blossom    소유 (SOYOU)     My Blossom  2018.03.12
# 2   3   2  Jenga (Feat. Gaeko)    헤이즈(HEIZE)             바람  2018.03.08
# 3   4   1             별이 빛나는 밤  마마무(Mamamoo)  Yellow Flower  2018.03.07
# 4   5   1              내가 더 나빠    헤이즈(HEIZE)             바람  2018.03.08

# %%
mv_page = urlopen('https://music.bugs.co.kr/chart/mv/day/total') # 비디오 순위 정보 페이지

mv_soup = BeautifulSoup(mv_page, 'html.parser')

#print(mv_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <!-- bgsweb-www905.svr.toastmaker.net -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드" name="keywords">
#    <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" name="description">
#     <!-- bgsweb-www905.svr.toastmaker.net -->
#     <script type="text/javascript">
#      if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlJs = "/js";
# 	var g_urlMe = "https://music.bugs.co.kr/user";
# 	var g_urlThumbnail = "http://nboardr.bugs.co.kr/thumbnail";
# 	var g_urlOpenalbum = "https://music.bugs.co.kr/openalbum";
# 	var g_urlClipimg = "//image.bugsm.co.kr";
# 	//var g_urlLikes = "https://music.bugs.co.kr/like";
# 	//var g_urlPlaylists = "https://music.bugs.co.kr/playlist";
# 	var g_urlAward = "http://award.bugs.co.kr";
# 	var g_urlLikes = "https://music.bugs.co.kr/like";
# 	var g_urlPlaylists = "https://music.bugs.co.kr/playlist"
# 	var g_urlListen = "https://music.bugs.co.kr/listen";
# 	var g_urlMyinfo = "https://music.bugs.co.kr/myinfo";
# 	var g_urlSecureMyinfo = "https://secure.bugs.co.kr/myinfo";
# 	var g_urlSearch = "https://music.bugs.co.kr/search";
# 	var g_urlChart = "https://music.bugs.co.kr/chart";
# 	var g_urlPay = "https://music.bugs.co.kr/pay";
# 	var g_urlBilling = "https://pay.bugs.co.kr";
# 	var g_urlPartner = "https://www.bugs.co.kr/Partner";
# 	var g_urlSecurePay = "https://secure.bugs.co.kr/pay";
# 	var g_urlOtu = "https://notu.bugs.co.kr";
# 	var g_urlBoard = "http://board.bugs.co.kr/notice";
# 	var g_urlEvent = "https://music.bugs.co.kr/event";
# 	var g_storageServerRead = "http://nboardr.bugs.co.kr";
# 	var g_storageServerWrite = "https://nboardw.bugs.co.kr";
# 	var g_urlPanel = "https://music.bugs.co.kr/panel";
# 	var g_urlAjax = "https://music.bugs.co.kr";
# 	var g_urlAppsvr = "http://appsvr.bugs.co.kr";
# 	var g_urlMusicPd = "https://music.bugs.co.kr/musicpd";
# 	var g_urlGenre = "https://music.bugs.co.kr/genre";
# 	var g_urlMLounge = "https://mlounge.bugs.co.kr";
# 	var g_urlNinanoclub = "http://ninanoclub.bugs.co.kr";
# 	var g_urlM = "https://m.bugs.co.kr";
# 	var g_urlDl = "https://dl.bugs.co.kr";
#
# 	var g_env = "svc";
#
# 	var g_isLogged = false;
# 	var g_msrl = false;
#     </script>
#     <!-- cache.filePacking : false -->
#     <!-- [open_lib_js] origin list / start -->
#     <script src="/js/jquery/jquery-1.11.2.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-browser-plugin.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-migrate-1.2.1.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.mousewheel.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.jscrollpane.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-ui-1.11.4.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery-bugs-extends.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.animateSprite.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.dotdotdot.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.json.min-2.5.1.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.easing-1.3.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/swiper.jquery.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/lib/js.cookie-1.5.1.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.form.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.fileupload.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/jquery/jquery.iframe-transport.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/html5/html5shiv.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/code-snippet.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/raphael.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/toast/tui.chart/chart.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <!-- [open_lib_js] origin list / end -->
#     <!-- [bugs_desktopLib_js] origin list / start -->
#     <script src="/js/commons.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/ui.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/utils/music.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/utils/suggest.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/utils/notice.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/me/likes.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/m/kakao-1.0.8.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/log/clickLog.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/me/playlist.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/log/makePCookie.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/player/min/mvHtml5Player.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/lib/kakao.min.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.navigator.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.scroll.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.datepicker.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <!-- [bugs_desktopLib_js] origin list / end -->
#     <!-- [bugs_newLib_js] origin list / start -->
#     <script src="/js/bugs/bugs.alert.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.app.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.sns.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.mobile.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.data.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.layer.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.string.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.object.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.play.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.debug.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.location.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.object.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.utils.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.useragent.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.member.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.html.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.image.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.wiselog.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.userReaction.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.userReport.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.bside.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.comment.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.handler.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.scroll.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.musiccast.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.encryption.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.number.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.story.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.connect.graph.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.recommend.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.like.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.recommend.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <script src="/js/bugs/bugs.api.like.js?env=svc&amp;_t_s_=20180315-1607" type="text/javascript">
#     </script>
#     <!-- [bugs_newLib_js] origin list / end -->
#     <!-- clova issue로 분기 -->
#     <script src="/js/swfobject/swfobject.js" type="text/javascript">
#     </script>
#     <!-- java enum to js -->
#     <script src="https://music.bugs.co.kr/js/enumtojs" type="text/javascript">
#     </script>
#     <script src="/js/utils/personMedia.js?version=20161212" type="text/javascript">
#     </script>
#     <script src="/js/me/playlist.js?version=20151102" type="text/javascript">
#     </script>
#     <script src="/js/log/makePCookie.js" type="text/javascript">
#     </script>
#     <script src="/js/player/min/mvHtml5Player.min.js?version=20180315:1607" type="text/javascript">
#     </script>
#     <!-- <script type="text/javascript" src="/js/utils/fileUploader.js"></script> -->
#     <script src="/js/lib/kakao.min.js" type="text/javascript">
#     </script>
#     <!-- <script type="text/javascript" src="/js/lib/kakao.story.min.js"></script> -->
#     <!--[if gt IE 7]>
# 	<script type="text/javascript" src="/js/jquery/jquery.ba-hashchange.min.js"></script>
# <![endif]-->
#     <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/js/html5/html5shiv.min.js"></script>
# 	<script type="text/javascript" src="/js/json2.js"></script>
# <![endif]-->
#     <!-- [bugs_commonStyle_css] origin list / start -->
#     <link href="/css/jquery/jquery.jscrollpane.css?env=svc&amp;_t_s_=20180315-1607" rel="stylesheet" type="text/css"/>
#     <link href="/css/jquery/jquery-ui-1.11.4.css?env=svc&amp;_t_s_=20180315-1607" rel="stylesheet" type="text/css"/>
#     <link href="/css/bugs/bugs.image.css?env=svc&amp;_t_s_=20180315-1607" rel="stylesheet" type="text/css"/>
#     <link href="/css/playerMV.css?env=svc&amp;_t_s_=20180315-1607" rel="stylesheet" type="text/css"/>
#     <link href="/css/toast/tui.chart/chart.min.connect.css?env=svc&amp;_t_s_=20180315-1607" rel="stylesheet" type="text/css"/>
#     <!-- [bugs_commonStyle_css] origin list / end -->
#     <meta content="summary_large_image" name="twitter:card"/>
#     <meta content="https://music.bugs.co.kr/chart/track/day/total" name="twitter:url"/>
#     <meta content="벅스!에서 다양한 음악컨텐츠를 볼 수 있습니다." name="twitter:description"/>
#     <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" name="twitter:image:src"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:iphone"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:ipad"/>
#     <meta content="bugs3://app/whatshot/chart" name="twitter:app:url:googleplay"/>
#     <!-- open graph -->
#     <meta content="122936701116206" property="fb:app_id">
#      <meta content="슈퍼사운드 벅스" property="og:title">
#       <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="og:url">
#        <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" property="og:image">
#         <meta content="벅스!" property="og:site_name">
#          <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" property="og:description">
#           <meta content="website" property="og:type">
#            <meta content="ko_KR" property="og:locale"/>
#            <!-- app link -->
#            <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="al:ios:url"/>
#            <meta content="348555322" property="al:ios:app_store_id"/>
#            <meta content="벅스(ios)" property="al:ios:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="al:iphone:url"/>
#            <meta content="348555322" property="al:iphone:app_store_id"/>
#            <meta content="벅스(iphone)" property="al:iphone:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="al:ipad:url"/>
#            <meta content="420598915" property="al:ipad:app_store_id"/>
#            <meta content="벅스(ipad)" property="al:ipad:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="al:android:url"/>
#            <meta content="com.neowiz.android.bugs" property="al:android:package"/>
#            <meta content="벅스(android)" property="al:android:app_name"/>
#            <meta content="https://music.bugs.co.kr/chart/mv/day/total" property="al:web:url">
#             <!-- twitter card -->
#             <meta content="summary_large_image" name="twitter:card"/>
#             <meta content="https://music.bugs.co.kr/chart/mv/day/total" name="twitter:url"/>
#             <meta content="@Bugs_play" name="twitter:site"/>
#             <meta content="슈퍼사운드 벅스" name="twitter:title"/>
#             <meta content="벅스 2천만곡 음악서비스, 슈퍼사운드, 고음질, FLAC, 최신 인기가요, 복면가왕 무료보기, 페이코" name="twitter:description"/>
#             <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" name="twitter:image:src"/>
#             <meta content="벅스" name="twitter:app:name:iphone"/>
#             <meta content="벅스" name="twitter:app:name:ipad"/>
#             <meta content="벅스" name="twitter:app:name:googleplay"/>
#             <meta content="https://music.bugs.co.kr/chart/mv/day/total" name="twitter:app:url:iphone"/>
#             <meta content="https://music.bugs.co.kr/chart/mv/day/total" name="twitter:app:url:ipad"/>
#             <meta content="https://music.bugs.co.kr/chart/mv/day/total" name="twitter:app:url:googleplay"/>
#             <meta content="348555322" name="twitter:app:id:iphone"/>
#             <meta content="420598915" name="twitter:app:id:ipad"/>
#             <meta content="com.neowiz.android.bugs" name="twitter:app:id:googleplay"/>
#             <link href="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" rel="image_src"/>
#             <meta content="https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png" itemprop="image"/>
#             <!-- bugs.sns 용 공유 파라미터 -->
#             <script>
#              var bugsSnsParam = {
# 		 			url : "https://music.bugs.co.kr/chart/mv/day/total",
# 		 			text : "슈퍼사운드 벅스",
# 		 			img : "https://file.bugsm.co.kr/wbugs/common/i_snsBugs@2x.png",
# 		 			hashTag : "#벅스",
# 		 			corner : "벅스"
# 		 		}
#             </script>
#             <span itemscope="" itemtype="http://schema.org/Organization">
#              <link href="https://music.bugs.co.kr" itemprop="url"/>
#              <a href="https://www.facebook.com/bugsplay" itemprop="sameAs">
#              </a>
#              <a href="http://blog.bugs.co.kr" itemprop="sameAs">
#              </a>
#              <a href="https://twitter.com/bugs_play" itemprop="sameAs">
#              </a>
#              <a href="https://itunes.apple.com/kr/app/bugs/id348555322?mt=8" itemprop="sameAs">
#              </a>
#              <a href="https://play.google.com/store/apps/details?id=com.neowiz.android.bugs" itemprop="sameAs">
#              </a>
#             </span>
#             <meta content="ko_KR" property="og:locale">
#              <title>
#               벅스차트 &gt; 인기 영상 &gt; 일간 &gt; 전체 장르 - 벅스
#              </title>
#              <meta content="no-cache" http-equiv="Cache-Control"/>
#              <meta content="no-cache" http-equiv="Pragma"/>
#              <meta content="0" http-equiv="Expires"/>
#              <!-- 네이버 검색용 메타 -->
#              <meta content="0582453e44d4365f5e597d1580911be7a3173ef7" name="naver-site-verification">
#               <link for="bugs" href="/css/wbugsWhatshot.css?version=20180315-16_bgsweb-www905.svr.toastmaker.net" rel="stylesheet" type="text/css"/>
#               <!-- commonUtils.ftl -->
#               <!--[if gt IE 7]>
# 	<link rel="stylesheet" href="/css/fonts.css" type="text/css">
# <![endif]-->
#               <?if !IE?>
#               <link href="/css/fonts.css" rel="stylesheet" type="text/css"/>
#               <?endif?>
#               <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="shortcut icon" type="image/x-icon">
#                <link href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" rel="icon" type="image/x-icon">
#                 <script src="//wcs.naver.net/wcslog.js" type="text/javascript">
#                 </script>
#                 <script src="/js/log/naver_marketing.js">
#                 </script>
#                 <script src="/js/log/ace_counter.js">
#                 </script>
#                 <script>
#                  $(document).ready(function(){
# 		$("[dotdotdot=Y]").dotdotdot({
# 			watch : "window"
# 		});
# 	});
#                 </script>
#                </link>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="skipNav">
#    <a href="#container" onclick="$('#container').attr('tabIndex','-1');$('#container').focus();$('body,html').scrollTop(0);return false;">
#     <span>
#      본문 바로가기
#     </span>
#    </a>
#    <a href="#gnb" onclick="bugs.navigator.setLeftMenuShow(true,true);$('#gnb').attr('tabIndex','-1');$('#gnb').focus();return false;">
#     <span>
#      메뉴 바로가기
#     </span>
#    </a>
#    <a href="#loginHeader" onclick="$('#loginHeader a:first-of-type').attr('tabIndex','-1');$('#loginHeader a:first-of-type').focus();return false;">
#     <span>
#      로그인 바로가기
#     </span>
#    </a>
#    <a href="#footer" onclick="$('#footer').attr('tabIndex','-1');$('#footer').focus();return false;">
#     <span>
#      하단 정보 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="wrap">
#    <script>
#     $(document).ready(function(){
# 					if('' == ""){
# 				bugs.searchBoxAd.init();
# 				bugs.searchBoxAd.checkInput();
# 				bugs.searchBoxAd.inputBlur();
# 				bugs.searchBoxAd.deleteText();
# 			}
#
# 		popWebPlayerNotification();
#
# 		bugs.suggest.close();
# 		var headerCommonBanner = '[{"content_id2":"","weight":20,"album":null,"link":"http://music.bugs.co.kr/radio/musiccast/episode/10799","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521083209000,"minutes":6,"seconds":49,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"title":"주노드라마 12화","expire_day":0,"regdate":{"time":1521080249000,"minutes":17,"seconds":29,"hours":11,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521255600000,"minutes":0,"seconds":0,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":6,"date":17},"banner_id":51165,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/165/51/0/51165.jpg","upd_dt":"","view_start_date":{"time":1521039600000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15}},{"content_id2":"","weight":20,"album":null,"link":"https://music.bugs.co.kr/musicpd/albumview/26589","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521077323000,"minutes":28,"seconds":43,"hours":10,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"title":"죽기 전에 꼭 들어야 할 쳄발로 명곡","expire_day":0,"regdate":{"time":1521077323000,"minutes":28,"seconds":43,"hours":10,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521428400000,"minutes":0,"seconds":0,"hours":12,"month":2,"year":118,"timezoneOffset":-540,"day":1,"date":19},"banner_id":51155,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/155/51/0/51155.jpg","upd_dt":"","view_start_date":{"time":1521039600000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":4,"date":15}},{"content_id2":"","weight":20,"album":null,"link":"http://music.bugs.co.kr/musicpd/albumview/26479","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521018546000,"minutes":9,"seconds":6,"hours":18,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14},"title":"NCT 2018 프로젝트 필청트랙 듣고 선물은 덤~","expire_day":0,"regdate":{"time":1521018200000,"minutes":3,"seconds":20,"hours":18,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14},"artist":null,"wiselog_code":"","sub_category":"main","content_type":"NONE","crt_dt":"","css_class_nm":"","upd_id":"","clickCount":0,"status":"OK","pay_yn":"","track":null,"mv":null,"artist_id":"0","view_end_date":{"time":1521126000000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":5,"date":16},"banner_id":51134,"album_id":"0","category":"WBUGS_HEADER_COMMON_BANNER","content_id":0,"image_bg_color":"","app_nm":"","crt_id":"","db_sts":"","totalWeight":0,"target":"_self","view_env":"SVC","image_path":"//image.bugsm.co.kr/banner/images/original/134/51/0/51134.jpg","upd_dt":"","view_start_date":{"time":1520953200000,"minutes":0,"seconds":0,"hours":0,"month":2,"year":118,"timezoneOffset":-540,"day":3,"date":14}},{"content_id2":"","weight":20,"album":null,"link":"https://music.bugs.co.kr/specialView/concert/FGOS1OHVD0DAZ6RQC3RY","str_content_id":"0","image_path2":"","mobile_target":"","view_target":"ALL","lastupdate":{"time":1521010291000,"minutes":51,"secon ...
#
# 		if(headerCommonBanner != ""){
# 			window._headerCommonBannerMainList = bugs.utils.parseJson(headerCommonBanner.split("||")[0]);
# 			window._headerCommonBannerSubList = bugs.utils.parseJson(headerCommonBanner.split("||")[1]);
# 		}
#
# 		headerCommonBannerLoad(location.href);
#
# 		if(bugs.cookie.get("hasCouponEmailID") == "1"){
# 			$("#no_coupon_text").append('<a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D26048%26categoryNo%3D4600" class="linkFAQ" target="_blank">구매한 이용권이 보이지 않는다면?</a>');
# 		}
# 	});
#
# 	function popWebPlayerNotification() {
# 		var flag = Cookies.get("wpn");
# 		if(!flag)
# 			$(".slogan .tip").show();
# 		else
# 			$(".slogan .tip").hide();
# 	};
#
# 	function closeWebPlayerNotification() {
# 		Cookies.set("wpn", "Y", {expires:365*50, path:"/", domain:document.domain});
# 		$(".slogan .tip").hide();
# 	}
#
# 	function headerCommonBannerLoad(url){
# // 		url = window.location.href; //테스트용
#
# 		if(url.indexOf("?") > 0){
# 			url = url.substring(0,url.indexOf("?"))
# 		}
#
# 		if(url == g_urlWww || url == g_urlWww+"/" || url == g_urlWww+"/index" || url == g_urlMusic){ //main
# 			if(window._headerCommonBannerMainList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerMainList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+ bugs.common_util.setLinkUrlWiseLog(selectedBanner.link, "M_header_03_03") +'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
#
# 		}else{ //sub
# 			if(window._headerCommonBannerSubList.length > 0){
# 				var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerSubList);
# 				$('#header div.header div.banner').empty();
# 				$('#header div.header div.banner').append('<a href="'+selectedBanner.link+'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
# 						'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
# 			}
# 		}
#
# 	};
#    </script>
#    <header id="header">
#     <!--[if lte IE 7]>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('#wrap').addClass('commonHeaderIEBrowser');
# 	});
# </script>
#
# <div class="IEBrowserUnavailable">
# 	안정적인 서비스 이용을 위해 브라우저를 최신 버전으로 업데이트 해주세요. <a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D31944%26categoryNo%3D4622">자세한 안내 보기 &gt;</a>
# </div>
#
# <![endif]-->
#     <aside class="layer layerSettingPlayer guide title" style="display:none;">
#      <div class="box-shadow">
#      </div>
#      <header class="layer-title">
#       <h1>
#        안내
#       </h1>
#      </header>
#      <section class="layerContents">
#       <p class="message">
#        음악을 재생할 플레이어를 선택해 주세요.
#        <br/>
#        벅스 웹상단 &gt;
#        <strong>
#         플레이어 선택
#        </strong>
#        에서 플레이어를 변경할 수 있습니다.
#       </p>
#       <fieldset>
#        <div class="radioChk">
#         <input checked="checked" id="radio_player_web2" name="radio_player_type2" type="radio" value="WEB"/>
#         <label for="radio_player_web2">
#          웹 플레이어
#         </label>
#        </div>
#        <div class="radioChk">
#         <input id="radio_player_mac2" name="radio_player_type2" type="radio" value="MAC"/>
#         <label for="radio_player_mac2">
#          벅스 플레이어 (프로그램 설치 필요)
#         </label>
#         <p>
#          v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.
#          <br/>
#          <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">
#           [설치 안내 바로가기]
#          </a>
#         </p>
#        </div>
#       </fieldset>
#       <p class="agreeCheck">
#        <input id="setPlayerSelectionConfirm" name="setPlayer" type="checkbox"/>
#        <label for="setPlayerSelectionConfirm">
#         항상 선택한 플레이어로 재생
#        </label>
#       </p>
#       <p class="btns">
#        <button class="btnNormal" type="ok">
#         확인
#        </button>
#       </p>
#      </section>
#      <button class="btnClose" type="cancel">
#       닫기
#      </button>
#     </aside>
#     <!-- //플레이어 선택 설정 안내 -->
#     <aside class="layer layerSettingPlayer selectPlayer title" style="display:none;">
#      <div class="box-shadow">
#      </div>
#      <header class="layer-title">
#       <h1>
#        플레이어 선택
#       </h1>
#      </header>
#      <section class="layerContents">
#       <p class="message">
#        음악을 재생할 플레이어를 선택해 주세요.
#       </p>
#       <fieldset>
#        <div class="radioChk">
#         <input checked="checked" id="radio_player_web1" name="radio_player_type1" type="radio" value="WEB"/>
#         <label for="radio_player_web1">
#          웹 플레이어
#         </label>
#        </div>
#        <div class="radioChk">
#         <input id="radio_player_mac1" name="radio_player_type1" type="radio" value="MAC"/>
#         <label for="radio_player_mac1">
#          벅스 플레이어 (프로그램 설치 필요)
#         </label>
#         <p>
#          v 1.3.0 미만인 경우,  최신 버전으로 업데이트 해주세요.
#          <br/>
#          <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">
#           [설치 안내 바로가기]
#          </a>
#         </p>
#        </div>
#       </fieldset>
#       <p class="btns">
#        <button class="btnNormal" type="ok">
#         확인
#        </button>
#       </p>
#      </section>
#      <button class="btnClose" type="cancel">
#       닫기
#      </button>
#     </aside>
#     <!-- //플레이어 선택 안내 -->
#     <!--
# <aside class="layer layerPlayingPlayer" style="display:none;">
# 	<div class="box-shadow"></div>
#
# 	<section class="layerContents">
# 		<strong class="message">벅스 플레이어로 재생됩니다.</strong>
# 		<ul>
# 			<li>벅스 웹상단 &gt; 플레이어 선택에서 플레이어를 변경할 수 있습니다.</li>
# 			<li>혹시 벅스 플레이어가 실행되지 않는다면? <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" onclick="$('.layerPlayingPlayer').hide();" target="_blank">[설치 안내 바로가기]</a></li>
# 		</ul>
# 	</section>
# </aside>
# -->
#     <script type="text/javascript">
#      //	var ua = navigator.userAgent;
# //	window._isMacBrowser = navigator.userAgent.search("Mac") > -1;
# //	window._isMacPlayerLinked = /Mac OS X 11_/.test(ua)
# //				|| /Mac OS X 12_/.test(ua)
# //				|| (/Mac OS X 10_/.test(ua) && !/Mac OS X 10_10/.test(ua) && !/Mac OS X 10_9/.test(ua) && !/Mac OS X 10_8/.test(ua) && !/Mac OS X 10_7/.test(ua) && !/Mac OS X 10_6/.test(ua) && !/Mac OS X 10_5/.test(ua)
# //														&& !/Mac OS X 10_4/.test(ua) && !/Mac OS X 10_3/.test(ua) && !/Mac OS X 10_2/.test(ua));
#
# 	var goServiceGuidePlayerPage = function(){
# 		if(navigator.platform.indexOf('Win') > -1){
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer";
# 		}else{
# 			document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer";
# 		}
# 	}
#
# 	$(document).ready(function() {
# 		showMacPlayerSelection();
# 	});
#
# 	var showMacPlayerSelection = function() {
# 		if(bugs.music.isMacPlayerSupport()) {
# 			$(".slogan .selectPlayer").show();
# 			$(".slogan .bugsPlayer").hide();
#
# 			var dp = bugs.cookie.get('defaultPlayer') || "";
#
# 			updateHeaderPlayerMenu(dp);
# 		} else {
# 			$(".slogan .selectPlayer").hide();
# 			$(".slogan .bugsPlayer").show();
# 		}
# 	}
#
# 	var updateHeaderPlayerMenu = function(type) {
# 		$("#headerWebPlayer").hide();
# 		$("#headerMacPlayer").hide();
#
# 		if(type == "MAC") {
# 			$("#headerMacPlayer").show();
# 		} else { // if(type == "" || type == "WEB") {
# 			$("#headerWebPlayer").show();
# 			$("#headerWebPlayer").removeAttr("onclick");
# 			$("#headerWebPlayer").unbind("click").bind("click", function() {
# 				bugs.music.popWebPlayer();
# 				bugs.wiselog.area('M_header_02_20');
# 				return false;
# 			});
# 		}
# 	}
#     </script>
#     <div class="top">
#      <div class="slogan">
#       <a class="nabi" href="https://music.bugs.co.kr/nabi?wl_ref=M_header_02_16" target="_blank">
#        <span class="icon">
#        </span>
#        나비프로젝트
#       </a>
#       <a class="supersound" href="https://music.bugs.co.kr/event/promotion/supersound/index?wl_ref=M_header_02_01" target="_blank">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        슈퍼사운드 벅스
#       </a>
#       <a aria-label="새창" class="openPlayer" href="javascript:;" id="headerWebPlayer" onclick="javascript:bugs.music.popWebPlayer();bugs.wiselog.area('M_header_02_13');return false;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        웹 플레이어
#       </a>
#       <a class="openPlayer" href="bugs3://app/wakeup" id="headerMacPlayer" onclick="bugs.wiselog.area('M_header_02_18');" style="display:none;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        벅스 플레이어
#       </a>
#       <span class="bugsPlayer" style="display:none;">
#        <span class="bar">
#        </span>
#        <a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_14');}catch(e){} goServiceGuidePlayerPage();">
#         벅스 플레이어
#        </a>
#       </span>
#       <a aria-label="새창" class="selectPlayer" href="javascript:;" onclick="bugs.ui.showPlayerSettingLayer();bugs.wiselog.area('M_header_02_19');" style="display:none;">
#        <span class="bar">
#        </span>
#        <span class="icon">
#        </span>
#        플레이어 선택
#       </a>
#      </div>
#      <div class="rightGroup">
#       <div class="more">
#        <a href="http://help.bugs.co.kr" onclick="try{bugs.wiselog.area('M_header_02_06');}catch(e){}">
#         고객센터
#        </a>
#        <a class="game" href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_08');}catch(e){}bugs.ui.cp.headerGameMenuToggle();">
#         <span class="bar">
#         </span>
#         게임
#        </a>
#        <aside class="layer gameMenu">
#         <div class="box-shadow">
#         </div>
#         <ul class="list-layer-select">
#          <li>
#           <a href="http://www.hangame.com/" onclick="try{bugs.wiselog.area('M_header_02_09');}catch(e){}" target="_blank">
#            한게임
#           </a>
#          </li>
#          <li>
#           <a href="http://shotonline.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_10" onclick="try{bugs.wiselog.area('M_header_02_10');}catch(e){}" target="_blank">
#            샷온라인
#           </a>
#          </li>
#          <li>
#           <a href="http://game.bugs.co.kr?wl_ref=sub_gnb&amp;wl_ref=M_header_02_11" onclick="try{bugs.wiselog.area('M_header_02_11');}catch(e){}" target="_blank">
#            피망
#           </a>
#          </li>
#         </ul>
#        </aside>
#       </div>
#       <div class="family">
#        <a class="comico" href="http://comico.toast.com" onclick="try{bugs.wiselog.area('M_header_02_03');}catch(e){}" target="_blank">
#         comico
#        </a>
#        <a class="ticketlink" href="http://www.ticketlink.co.kr" onclick="try{bugs.wiselog.area('M_header_02_04');}catch(e){}" target="_blank">
#         티켓링크
#        </a>
#        <a class="hangame" href="http://www.hangame.com" onclick="try{bugs.wiselog.area('M_header_02_05');}catch(e){}" target="_blank">
#         HANGAME
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="header">
#      <a class="logo seasonal hyrend" href="https://music.bugs.co.kr?wl_ref=M_header_03_01">
#       Bugs!
#       <span class="blind">
#        -홈으로 이동
#       </span>
#      </a>
#      <div class="innerContainer">
#       <input id="_hsi" type="hidden">
#        <fieldset class="searchForm" id="hederSearchForm">
#         <div class="input">
#          <input autocomplete="off" id="headerSearchInput" title="검색어 입력" type="text">
#           <span class="adKeywordDelete" id="keywordClearButton">
#            <span class="blind">
#             검색어 삭제
#            </span>
#           </span>
#           <button class="btnSearch" id="hederSearchFormButton" onclick="bugs.search.searchFromButton();">
#            검색
#            <span class="blind">
#             -페이지 이동
#            </span>
#           </button>
#          </input>
#         </div>
#         <div id="suggest" style="display:none;">
#          <div class="box-shadow">
#          </div>
#         </div>
#        </fieldset>
#        <div class="banner">
#        </div>
#       </input>
#      </div>
#      <div class="rightSection">
#       <div class="member">
#        <div class="login" id="loginHeader">
#         <!-- <a href="javascript:bugs.ui.showLoginLayerForHeader();" onclick="javascript:bugs.wiselog.area('M_header_03_05');">로그인</a>
# 			<a href="https://secure.bugs.co.kr/member/join/memberMain?wl_ref=M_header_03_06" class="signup"><span class="bar"></span> 회원가입<span class="blind">-페이지 이동</span></a> -->
#         <a href="javascript:bugs.ui.showLoginLayerForHeader({caller:this});" onclick="bugs.wiselog.area('M_header_03_05');">
#          로그인 / 회원가입
#         </a>
#        </div>
#        <div class="notification" id="memberNotificationArea">
#         <button id="btnNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">
#          알림
#         </button>
#         <button class="count" id="aNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">
#          <span class="blind">
#           새로운
#          </span>
#          <span>
#           알림
#          </span>
#          0
#          <span class="blind">
#           개
#          </span>
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <script type="text/javascript">
#     $(window).load(function(){
# 		if(g_isLogged){
# 			bugs.music.myAlbumList.gnbListArea = $("#gnbMyalbumListArea");
# 			bugs.music.myAlbumList.moreView = $("#btnMyalbumMoreView");
# 			bugs.music.myAlbumList.getGnbMyAlbumList(1);
# 		}
# 	});
#    </script>
#    <div id="gnb">
#     <span class="btnMenuFolding" id="gnbHandleBtn" style="display:none">
#      <span class="bu">
#      </span>
#      MENU
#     </span>
#     <div id="gnbBody">
#      <div class="links">
#       <div class="inner">
#        <a class="btnNormal lounge" href="https://music.bugs.co.kr/member/vipinfo?wl_ref=M_header_02_12">
#         <span class="iconLounge">
#         </span>
#         벅스 VIP 멤버십 안내
#        </a>
#        <a class="link ticket" href="https://music.bugs.co.kr/pay/recommend?wl_ref=M_left_01_01">
#         이용권 구매
#         <span class="bar">
#         </span>
#        </a>
#        <a class="link coupon" href="https://music.bugs.co.kr/pay/offlineCoupon?wl_ref=M_left_01_01">
#         상품권 등록
#        </a>
#       </div>
#      </div>
#      <nav>
#       <ul>
#        <li class="chart">
#         <a class="hyrend" href="https://music.bugs.co.kr/chart?wl_ref=M_left_02_01" lmid="lm_chart">
#          벅스차트
#         </a>
#        </li>
#        <li class="news">
#         <a class="hyrend" href="https://music.bugs.co.kr/newest?wl_ref=M_left_02_03" lmid="lm_news">
#          최신 음악
#         </a>
#        </li>
#        <li class="music4u">
#         <a class="hyrend" href="https://music.bugs.co.kr/music4u?wl_ref=M_left_02_02" lmid="lm_m4u">
#          뮤직4U
#         </a>
#        </li>
#        <li class="genre">
#         <a class="hyrend" href="https://music.bugs.co.kr/genre/home?wl_ref=M_left_02_06" lmid="lm_genre">
#          장르
#         </a>
#        </li>
#        <li class="special">
#         <a class="hyrend" href="https://music.bugs.co.kr/special?wl_ref=M_left_02_08" lmid="lm_special">
#          뮤직포스트
#         </a>
#        </li>
#        <li class="theme open" folder="2">
#         <strong>
#          테마
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/musicpd?wl_ref=M_left_02_04" lmid="lm_esalbum">
#            뮤직PD 앨범
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/recomreview?wl_ref=M_left_02_05" lmid="lm_recomreview">
#            추천앨범 리뷰
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/years?wl_ref=M_left_02_07" lmid="lm_years">
#            연도별
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/maniachart/kpop?wl_ref=M_left_02_09" lmid="lm_mania">
#            매니아
#           </a>
#          </li>
#         </ul>
#        </li>
#        <!-- 				<li class="bside"><a href="https://music.bugs.co.kr/bside?wl_ref=M_left_02_13" class="hyrend" lmid="lm_bside">Bside</a></li> -->
#        <li class="connect">
#         <a class="hyrend" href="https://music.bugs.co.kr/connect?wl_ref=M_left_02_13" lmid="lm_connect">
#          커넥트
#          <span class="iconNew">
#           NEW
#          </span>
#         </a>
#        </li>
#        <li class="radio">
#         <a class="hyrend" href="https://music.bugs.co.kr/radio?wl_ref=M_left_02_10" lmid="lm_radio">
#          라디오
#         </a>
#        </li>
#        <li class="flac">
#         <a class="hyrend" href="https://music.bugs.co.kr/flactheater/home?wl_ref=M_left_02_11" lmid="lm_flac">
#          FLAC 전용관
#         </a>
#        </li>
#        <li class="bugsonTV open" folder="5">
#         <strong>
#          벅스TV
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li class="specialLive">
#           <a href="https://music.bugs.co.kr/special/bugstv?wl_ref=M_left_04_04">
#            스페셜 라이브
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="mymusic open" folder="3">
#         <strong>
#          내 음악
#         </strong>
#         <span class="bu">
#         </span>
#         <ul>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?wl_ref=M_left_03_05" lmid="lm_recentTrack" loginrequired="PAGE">
#            최근 들은 곡
#           </a>
#           <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('',true);">
#            최근 들은 곡 재생
#           </button>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/listen?sort=LISTEN_COUNT&amp;wl_ref=M_left_03_06" lmid="lm_manytimesTrack" loginrequired="PAGE">
#            가장 많이 들은 곡
#           </a>
#           <button aria-label="새창" onclick="bugs.music.myAlbumList.listenListenedList('LISTEN_COUNT',true);">
#            가장 많이 들은 곡 재생
#           </button>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/purchased/track?wl_ref=M_left_03_01" lmid="lm_buymusic" loginrequired="PAGE">
#            구매한 음악
#           </a>
#          </li>
#          <li>
#           <a class="hyrend" href="https://music.bugs.co.kr/user/library/like/track?wl_ref=M_left_03_02" lmid="lm_likemusic" loginrequired="PAGE">
#            좋아한 음악
#           </a>
#          </li>
#         </ul>
#         <div class="myalbum">
#          <strong>
#           내 앨범
#          </strong>
#          <a class="edit hyrend" href="https://music.bugs.co.kr/user/library/myalbum/list?wl_ref=M_left_03_07" lmid="lm_myAlbumManage" loginrequired="PAGE">
#           편집
#          </a>
#          <div class="btnNewAlbum">
#           <a href="javascript:;" onclick="playlists.make2('GNB');bugs.wiselog.area('M_left_03_04');">
#            <span class="blind">
#             내앨범
#            </span>
#            +  새로 만들기
#           </a>
#          </div>
#          <ul id="gnbMyalbumListArea">
#          </ul>
#          <div>
#           <a class="btnMoreAlbum" href="javascript:;" id="btnMyalbumMoreView" onclick="bugs.music.myAlbumList.getNext(); bugs.wiselog.area('M_left_03_08');" style="display:none;">
#            더보기
#            <span>
#            </span>
#           </a>
#          </div>
#          <div class="loadingFailed" id="gnbMyalbumLoadFail" style="display:none;">
#           <p>
#            내 앨범을 불러오지
#            <br/>
#            못했습니다.
#           </p>
#           <button onclick="bugs.music.myAlbumList.getGnbMyAlbumList(1, 'failReload');">
#            <span class="icon">
#            </span>
#            내 앨범 불러오기
#           </button>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <script>
#     try{
# 	bugs.navigator.setLeftMenuFolder();
# }
# catch(e){}
#    </script>
#    <div id="hyrendContentBody">
#     <script>
#      var chartDatePicker;
# 	var chartDate = "";
# 	$(document).ready(function(){
#
# 		var dpOption = {
# 			showButtonSelector:".btnSelect",
# 			currentPeriodStartDate : new Date(2018,03-1, 14),
# 			currentPeriodEndDate : new Date(2018,03-1, 14),
# 						minDate : new Date(2014, 8 - 1, 2),
# 			maxDate : new Date(2018,03-1, 14),
# 			onSelect:function(){
# 				bugs.debug.show( "datepicker:" + $(this).val() );
# 				var url = "https://music.bugs.co.kr/chart/mv/day/total?chartdate=" + $(this).val();
# 				bugs.navigator.goState(url);
# 			}
# 		};
# 		chartDatePicker = bugs.datepicker.button("#chartDate", dpOption);
# 		chartDatePicker.datepicker('setDate', '20180314');
#
# 	});
#     </script>
#     <article class="mnWhatshot mnChart pgTopMV" id="container">
#      <header class="sectionPadding pgTitle">
#       <div class="innerContainer">
#        <h1>
#         벅스차트
#        </h1>
#        <script type="text/javascript">
#         var toggleNationLayer = function() {
#     $("aside.selectNation").toggle(250, function(){});
#   }
#
# $(document).ready(function () {
#
#   function changeTitle(){
#     try{
#               if('KR' != 'KR'){
#         var newTitle = '벅스차트 > 곡 차트 > 대한민국 - 벅스';
#         var curTitle = document.title;
#         if(newTitle != curTitle){
#           document.title = newTitle;
#         } else {
#           setTimeout(changeTitle, 500);
#         }
#       }
#     } catch(e){}
#   };
#
#   changeTitle();
#
#   $(document).click(function(ev){
#     if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
#     if ($(ev.target).attr('class') != "selectedNationName"
#         && ($(ev.target).attr('class').indexOf("flag") != 0  )
#         && ($(ev.target).attr('class').indexOf("btnNation") == -1 ) ) {
#           $("aside.selectNation").hide(250);
#       }
#     });
# });
#        </script>
#        <a class="btnNation" href="javascript:;" onclick="bugs.wiselog.area('chart_filter_nation');toggleNationLayer();">
#         <span class="flag">
#          <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/>
#         </span>
#         <em class="selectedNationName">
#          대한민국
#         </em>
#        </a>
#        <aside class="layer selectNation">
#         <div class="box-shadow">
#         </div>
#         <h1>
#          국가선택
#         </h1>
#         <ul>
#          <li>
#           <a class="selected KR" href="https://music.bugs.co.kr/chart/track/realtime/total?nation=KR" onclick="bugs.wiselog.area('chart_nation_KR');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png"/>
#            </span>
#            <em class="selectedNationName">
#             대한민국
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="nl" href="https://music.bugs.co.kr/chart/track/week/total?nation=nl" onclick="bugs.wiselog.area('chart_nation_nl');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/NL.png"/>
#            </span>
#            <em class="selectedNationName">
#             네덜란드
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="dk" href="https://music.bugs.co.kr/chart/track/week/total?nation=dk" onclick="bugs.wiselog.area('chart_nation_dk');">
#            <span class="flag">
#             <img alt="" src="https://file.bugsm.co.kr/wbugs/api/flag/square/DK.png"/>
#            </span>
#            <em class="selectedNationName">
#             덴마크
#            </em>
#           </a>
#          </li>
#          <li>
#           <a class="de" href="https://music.bugs.co.kr/chart/track/week/total?nation=de" onclick="bugs.wiselog.area('chart_nation_de');">
#            <span class="flag">
# ...
#             기타 기능
#            </a>
#           </figcaption>
#          </figure>
#         </li>
#         <li class="divider lineBreak">
#          <figure albumid="507550" class="mvInfo" multiartist="N" mvid="208570" trackid="4374514">
#           <a class="thumbnail" href="javascript:;" onclick="bugs.wiselog.area('list_mv_01');bugs.music.viewMV(208570,true); " title="뱅뱅뱅 (BANG BANG BANG) 영상 보기">
#            <span class="mask">
#            </span>
#            <img alt="뱅뱅뱅 (BANG BANG BANG) 영상 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/mvhd/images/224/2085/208570.jpg?version=20171215040159"/>
#            <time class="duration" datetime="">
#             03:49
#            </time>
#           </a>
#           <figcaption class="info">
#            <p class="trackTitle">
#             <span class="badge o15">
#              [15세 이상 관람가]
#             </span>
#             <a href="javascript:;" onclick="bugs.wiselog.area('list_mv_02');bugs.music.viewMV(208570); " title="뱅뱅뱅 (BANG BANG BANG) 영상 보기">
#              뱅뱅뱅 (BANG BANG BANG)
#             </a>
#            </p>
#            <div class="subInfo">
#             <p class="artist">
#              <a href="https://music.bugs.co.kr/artist/80020023?wl_ref=list_mv_03" title="BIGBANG">
#               BIGBANG
#              </a>
#             </p>
#             <p>
#              <time datetime="">
#               2015.06.01
#              </time>
#              <span class="albumType">
#               <span class="bar">
#               </span>
#               정규
#              </span>
#             </p>
#            </div>
#            <a artist_disp_nm="BIGBANG" artist_id="80020023" class="btnActions" href="javascript:;" layerpositiontarget="figure" mv_title="뱅뱅뱅 (BANG BANG BANG)" onclick="bugs.wiselog.area('list_mv_04');
# bugs.layermenu.mvMoreAction(this,'208570','4374514', '507550','SL','FULLHD','STR','PASS','N', 'N','OK', '');">
#             기타 기능
#            </a>
#           </figcaption>
#          </figure>
#         </li>
#        </ul>
#        <div class="pageAdditionalInfo">
#         <ul>
#          <li>
#           <span class="icon">
#           </span>
#           집계기간 내 보기와 다운로드 수 합산하여 반영
#          </li>
#         </ul>
#        </div>
#       </div>
#      </section>
#     </article>
#    </div>
#    <div class="floatingTop">
#     <a class="btnTop" href="javascript:void(bugs.navigator.scrollTop())">
#      TOP
#     </a>
#    </div>
#    <script src="/js/jquery/jquery-dateFormat.min.js" type="text/javascript">
#    </script>
#    <script>
#     $(window.document).ready(function() {
# 			setTimeout(function(){
# 				$.ajax({
# 					url : g_urlAjax + "/board/notice/ajax/commonfooternotice",
# 					type : "POST",
# 					dataType : "json",
# 					success : function(data){
# 						if(data != null){
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").text(data.title);
# 							$("#commonFooterNotice a#commonFooterNoticeTitle").attr("href", g_urlMusic + "/board/notice?srl=" + data.srl + "&wl_ref=M_footer_01_01");
# 							$("#commonFooterNotice time").text(data.crt_dt);
# 							$("#commonFooterNotice time").attr("datetime", $.format.date(Date.parse(data.crt_dt,"yyyy.MM.dd"), "yyyy-MM-dd"));
# 						}
# 					}
# 				});
# 			}, 1300);
#
# });
#    </script>
#    <footer id="footer">
#     <section class="sectionPadding">
#      <div class="innerContainer">
#       <div class="notice" id="commonFooterNotice">
#        <strong>
#         <a href="https://music.bugs.co.kr/board/notice?wl_ref=M_footer_01_01">
#          공지사항
#         </a>
#        </strong>
#        <a href="javascript:;" id="commonFooterNoticeTitle">
#        </a>
#        <time datetime="">
#        </time>
#       </div>
#       <div class="quicklinks">
#        <ul>
#         <li>
#          <a href="https://music.bugs.co.kr/event?wl_ref=M_footer_02_01">
#           이벤트
#          </a>
#         </li>
#         <li>
#          <a href="https://music.bugs.co.kr/panel?wl_ref=M_footer_02_01">
#           벅스패널
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li>
#          <span class="bar">
#          </span>
#          <a href="https://music.bugs.co.kr/serviceGuide/home?wl_ref=M_footer_02_07">
#           벅스 꿀팁 보기
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </section>
#     <section class="sectionPadding contents">
#      <div class="innerContainer">
#       <ul class="links">
#        <li class="company">
#         <a aria-label="새창" href="http://www.bugscorp.co.kr?wl_ref=M_footer_03_01" target="_blank">
#          회사소개
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/cooperation?wl_ref=M_footer_03_01">
#          제휴문의
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/rules/use?wl_ref=M_footer_03_01">
#          이용약관
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li class="privacy">
#         <a href="https://music.bugs.co.kr/rules/privacy?wl_ref=M_footer_03_01">
#          개인정보처리방침
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/rules/youth?wl_ref=M_footer_03_01">
#          청소년보호정책
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/connect/center?wl_ref=M_footer_03_01">
#          커넥트 센터
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="http://help.bugs.co.kr?wl_ref=M_footer_03_01">
#          고객센터
#         </a>
#         <span class="bar">
#         </span>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/sitemap?wl_ref=M_footer_03_01">
#          사이트맵
#         </a>
#        </li>
#       </ul>
#       <aside>
#        <div class="sns">
#         <a aria-label="새창" class="blog" href="http://blog.bugs.co.kr" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#          블로그
#         </a>
#         <a aria-label="새창" class="facebook" href="https://www.facebook.com/bugsplay" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#          페이스북
#         </a>
#         <a aria-label="새창" class="kakaostory" href="https://story.kakao.com/ch/bugs" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#          카카오스토리
#         </a>
#        </div>
#        <div class="familysite">
#         <button onclick="bugs.ui.cp.footerFamilySiteMenu(this);" tabindex="0">
#          FAMILY SITE
#          <span class="bu">
#          </span>
#         </button>
#         <aside class="layer familysiteMenu">
#          <div class="box-shadow">
#          </div>
#          <ul class="list-layer-select">
#           <li>
#            <a aria-label="새창" href="http://www.nhnent.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">
#             NHN Entertainment
#            </a>
#           </li>
#           <li>
#            <a aria-label="새창" href="http://me.sayclub.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">
#             세이클럽
#            </a>
#           </li>
#          </ul>
#         </aside>
#        </div>
#       </aside>
#       <address>
#        (주)엔에이치엔벅스 | 13487 경기도 성남시 분당구 대왕판교로 645번길 16 플레이뮤지엄 | 대표이사 : 양주일 | 고객센터 :
#        <a href="mailto:help@help.bugs.co.kr">
#         help@help.bugs.co.kr
#        </a>
#        / 1566-4882 (유료)
#        <br>
#         사업자등록번호 : 211-87-15555 | 통신판매업 신고번호 : 제 2013-경기성남-0532호 | 호스팅 제공자 : (주)엔에이치엔벅스 |
#         <a aria-label="새창" href="http://ftc.go.kr/info/bizinfo/communicationView.jsp?apv_perm_no=2013378021930200528&amp;area1=&amp;area2=&amp;currpage=1&amp;searchKey=04&amp;searchVal=2118715555&amp;stdate=&amp;enddate=" target="_blank">
#          사업자 정보 확인
#         </a>
#         | © NHN Bugs Corp. All rights reserved.
#        </br>
#       </address>
#       <script>
#        if (!bugs.ui.cp) {
# 	bugs.ui.cp = {
# 		headerGameMenuToggle : function() {
# 			$('.layer.gameMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_header_02_02');
# 			}
# 		},
# 		footerFamilySiteMenu : function() {
# 			$('.layer.familysiteMenu').toggle();
#
# 			if(bugs.wiselog.area) {
# 				bugs.wiselog.area('M_fotter_03_01');
# 			}
# 		}
# 	};
# }
#       </script>
#       <ul class="emblem">
#        <li>
#         <a href="https://music.bugs.co.kr/specialView/supersound/NJ6P8GAP0ERQFD84GUCF" onclick="bugs.wiselog.area('M_fotter_03_01');">
#          <img alt="하이 레졸루션 공식인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHiRes.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="javascript:void(0)" onclick="window.open('https://www.goodcontent.kr/upload_public/CERTIDW/2017-09-0007_6s59w399b1p6wd220170905003422.png', 'goodContentPop' , 'width=490,height=616,resizable=0');">
#          <img alt="굿 콘텐츠서비스" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemGCSV20171207.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/board/notice?srl=7949" onclick="bugs.wiselog.area('M_fotter_03_01');">
#          <img alt="2015 상반기 대학생선호브랜드 대상" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHerald.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://music.bugs.co.kr/board/notice?srl=5162" onclick="bugs.wiselog.area('M_fotter_03_01');">
#          <img alt="스마트앱어워드 대상 수상" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemAppaward.png"/>
#         </a>
#        </li>
#        <li>
#         <a aria-label="새창" href="https://isms.kisa.or.kr/main/isms/issue/?certificationMode=list&amp;crtfYear=&amp;searchCondition=1&amp;searchKeyword=ISMS+13-042" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#          <img alt="정보보호 관리체계 ISMS 인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemISMS.png"/>
#         </a>
#        </li>
#        <li>
#         <a aria-label="새창" href="http://www.kdce.or.kr/user/ctf/clmsCtfTransList.do?NmberBusiRegNo=2118715555&amp;websiteName=www.bugs.co.kr" onclick="window.open(this.href,'','width=600,height=669');bugs.wiselog.area('M_fotter_03_01');return false;">
#          <img alt="음악저작권 이용 허락 인증" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemClms.png"/>
#         </a>
#        </li>
#        <li>
#         <a aria-label="새창" href="http://www.cleansite.org" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
#          <img alt="클린사이트" src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemCleansite.png"/>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </section>
#    </footer>
#   </div>
#   <!--<a href="javascript:void(playlists.resetPlaylist())">리셋하기</a>-->
#   <script type="text/javascript">
#    $(document).ready(function(){
# 	try{
# 		bugs.navigator.addHyrendUnloadHandler(function(){playlists.playlistLayerHide();},"track2playlistForMoveHyrend", true);
# 	}catch(e){}
#
# });
#   </script>
#   <aside class="layer layer-select addMyAlbum" id="track2playlist" style="display:none;">
#    <div class="box-shadow">
#    </div>
#    <h1>
#     내 앨범 목록
#    </h1>
#    <div autoscroll="N" class="innerScroll" id="track2playlistScrollArea">
#     <ul class="list-layer-select">
#      <li>
#       <a href="javascript:;" onclick="$('#track2playlist').hide('blind', {}, 'normal', function() { bugs.ui.modalLayer.hide();playlists.make(); });" title="새 앨범 만들기">
#        + 새 앨범 만들기
#       </a>
#      </li>
#     </ul>
#    </div>
#   </aside>
#   <!-- 레이어 - 내 앨범 수정 -->
#   <aside class="layer createMyAlbum" id="editMyAlbumLayer" style="display:none; z-index:1002;">
#    <div class="box-shadow">
#    </div>
#    <header class="layer-title">
#     <h1>
#      앨범 정보 수정
#     </h1>
#    </header>
#    <section class="layerContents">
#     <fieldset>
#      <legend>
#       내 앨범 수정
#      </legend>
#      <table class="formLayout">
#       <caption>
#        내 앨범 수정 입력 폼
#       </caption>
#       <tbody>
#        <tr>
#         <th scope="row">
#          <label class="lb" for="editMyAlbumLayerPhoto">
#           사진
#          </label>
#         </th>
#         <td>
#          <img alt="" class="thumb" id="editMyAlbumLayerPhoto_img" src="https://file.bugsm.co.kr/wbugs/common/i_defaultMyAlbum_50x50.png"/>
#          <div class="inputFile">
#           <input class="file" diabled="" id="editMyAlbumLayerPhoto" type="text">
#            <button class="btnNormal" id="searchImage" type="button">
#             찾아보기
#            </button>
#            <input id="editMyAlbumLayerPhoto_path" title="사진경로" type="hidden">
#            </input>
#           </input>
#          </div>
#         </td>
#         <td class="right" style="width:55px;">
#         </td>
#        </tr>
#        <tr>
#         <th scope="row" style="width:55px;">
#          <label class="lb" for="editMyAlbumLayerTitle">
#           제목
#          </label>
#         </th>
#         <td>
#          <input class="txt" id="editMyAlbumLayerTitle" type="text" value="111"/>
#         </td>
#         <td class="right" style="width:55px;">
#          <span class="remain" id="editMyAlbumLayerTitleRemain">
#           (0/100)
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <th scope="row">
#          <label class="lb" for="editMyAlbumLayerDescribe">
#           설명
#          </label>
#         </th>
#         <td>
#          <textarea class="txtArea" cols="30" id="editMyAlbumLayerDescribe" name="" rows="10"></textarea>
#         </td>
#         <td class="right">
#          <span class="remain" id="editMyAlbumLayerDescribeRemain">
#           (0/300)
#          </span>
#         </td>
#        </tr>
#       </tbody>
#      </table>
#      <p class="btns">
#       <button btntype="ok" class="btnNormal" id="editMyAlbumLayerUpdate">
#        저장
#       </button>
#       <button btntype="cancel" class="btnNormal" id="editMyAlbumLayerCancel">
#        취소
#       </button>
#      </p>
#     </fieldset>
#    </section>
#    <button btntype="close" class="btnClose" id="editMyAlbumLayerClose">
#     닫기
#    </button>
#   </aside>
#   <!-- 레이어 - 내 앨범 수정 -->
#   <aside class="layer createMyAlbum" id="createMyAlbumLayer" style="display:none; z-index:1000;">
#    <div class="box-shadow">
#    </div>
#    <header class="layer-title">
#     <h1>
#      내 앨범 만들기
#     </h1>
#    </header>
#    <section class="layerContents">
#     <fieldset>
#      <legend>
#       내 앨범 만들기
#      </legend>
#      <table class="formLayout">
#       <caption>
#        내 앨범 정보 입력 폼
#       </caption>
#       <tbody>
#        <tr>
#         <th scope="row" style="width:55px;">
#          <label class="lb" for="createMyAlbumLayerTitle">
#           제목
#          </label>
#         </th>
#         <td>
#          <input class="txt" id="createMyAlbumLayerTitle" type="text" value=""/>
#         </td>
#         <td class="right" style="width:55px;">
#          <span class="remain" id="createMyAlbumLayerTitleRemain">
#           (0/100)
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <th scope="row">
#          <label class="lb" for="createMyAlbumLayerDescribe">
#           설명
#          </label>
#         </th>
#         <td>
#          <textarea class="txtArea" cols="30" id="createMyAlbumLayerDescribe" name="" rows="10"></textarea>
#         </td>
#         <td class="right">
#          <span class="remain" id="createMyAlbumLayerDescribeRemain">
#           (0/300)
#          </span>
#         </td>
#        </tr>
#       </tbody>
#      </table>
#      <p class="btns">
#       <button btntype="ok" class="btnNormal" id="createMyAlbumLayerUpdate">
#        저장
#       </button>
#       <button btntype="cancel" class="btnNormal" id="createMyAlbumLayerCancel">
#        취소
#       </button>
#      </p>
#     </fieldset>
#    </section>
#    <button btntype="close" class="btnClose" id="crerateMyAlbumLayerClose">
#     닫기
#    </button>
#   </aside>
#   <span id="removeSpecialCharTarget" style="display:none;">
#   </span>
#   <script>
#    try{
# 	bugs.navigator.setLeftMenuShowOnLoad();
# }
# catch(e){}
# $(document).ready(function(){
# 	var isFirefox = navigator.userAgent.toLowerCase().indexOf('firefox') > -1;
# 	if(isFirefox){
# 		$("#skipNav").css({top:"1px", left:"1px"});
# 	}
# });
#   </script>
#   <!-- 470517  -->
#   <script>
#    try {
# 		var expTime = (new Date()).getTime() + (60*60*24*30*1000);
# 	var expTime2 = (new Date()).getTime() - (60*5*1000);
# 	    bugs.cookie.set("last_login_log_date_cookie","", expTime2, "/", "bugs.co.kr");
# }
# catch(e){}
#   </script>
#  </body>
# </html>

# %%
daily_mvs = mv_soup.find('ul', class_='list tileView mvList ').find_all('li', class_='divider') #동영상 차트 목록 저장
# daily_mvs = mv_soup.find('ul', {'class':['list','tileView','mvList']})
#daily_mvs

# %%
bugs_dailymv=[]
cnt = 0

for d_mv in daily_mvs: # 각 동영상 정보 저장
    singer =  ' '.join(list(set(re.split('\r\n|\n',d_mv.find('p', class_='artist').get_text().strip())))).strip()
    #d_mv.find('p', class_='artist').get_text().strip()
    title = d_mv.find('p', class_='trackTitle').find('a').text
    w_grade = d_mv.find(class_='badge').get_text()
    cnt = cnt+1
    
    bugs_dailymv.append([ cnt  ,singer, title, w_grade])
    
    
    
    print('mv_랭킹 :', cnt)
    print('mv_가수 :', singer)
    print('mv_곡 :', title)
    print('mv_시청등급 :', w_grade)
    print()
# Out:
# mv_랭킹 : 1
# mv_가수 : 모모랜드(MOMOLAND)
# mv_곡 : 뿜뿜
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 2
# mv_가수 : 마마무(Mamamoo)
# mv_곡 : 별이 빛나는 밤
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 3
# mv_가수 : Red Velvet (레드벨벳)
# mv_곡 : Bad Boy
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 4
# mv_가수 : NCT 127
# mv_곡 : TOUCH
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 5
# mv_가수 : Wanna One(워너원)
# mv_곡 : 약속해요 (I.P.U.)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 6
# mv_가수 : NCT U
# mv_곡 : BOSS
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 7
# mv_가수 : TWICE (트와이스)
# mv_곡 : Heart Shaker
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 8
# mv_가수 : 헤이즈(HEIZE)
# mv_곡 : jenga (Feat. Gaeko)
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 9
# mv_가수 : iKON
# mv_곡 : 사랑을했다 (LOVE SCENARIO)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 10
# mv_가수 : TWICE (트와이스)
# mv_곡 : LIKEY
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 11
# mv_가수 : 셀럽파이브
# mv_곡 : 셀럽파이브(셀럽이 되고 싶어)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 12
# mv_가수 : 청하
# mv_곡 : Roller Coaster
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 13
# mv_가수 : 선미
# mv_곡 : 주인공
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 14
# mv_가수 : 에이프릴(APRIL)
# mv_곡 : 파랑새
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 15
# mv_가수 : NCT U
# mv_곡 : Baby Don't Stop
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 16
# mv_가수 : 방탄소년단
# mv_곡 : DNA
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 17
# mv_가수 : 헤이즈(HEIZE)
# mv_곡 : 내가 더 나빠
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 18
# mv_가수 : GOT7 (갓세븐)
# mv_곡 : Look
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 19
# mv_가수 : Red Velvet (레드벨벳)
# mv_곡 : 피카부 (Peek-A-Boo)
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 20
# mv_가수 : 오마이걸(OH MY GIRL)
# mv_곡 : 비밀정원
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 21
# mv_가수 : NCT DREAM
# mv_곡 : GO
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 22
# mv_가수 : 헤이즈(HEIZE)
# mv_곡 : MIANHAE
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 23
# mv_가수 : Wanna One(워너원)
# mv_곡 : 에너제틱 (Energetic)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 24
# mv_가수 : 마마무(Mamamoo)
# mv_곡 : 별 바람 꽃 태양
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 25
# mv_가수 : Red Velvet (레드벨벳)
# mv_곡 : 빨간 맛 (Red Flavor)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 26
# mv_가수 : 강호동
# mv_곡 : 복을 발로 차버렸어 (I kicked my luck off)_Music Video
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 27
# mv_가수 : BLACKPINK
# mv_곡 : 마지막처럼
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 28
# mv_가수 : TWICE (트와이스)
# mv_곡 : One More Time
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 29
# mv_가수 : 포레스텔라
# mv_곡 : You Are My Star
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 30
# mv_가수 : 볼빨간사춘기
# mv_곡 : 썸 탈꺼야
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 31
# mv_가수 : 현아(HyunA)
# mv_곡 : Lip & Hip
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 32
# mv_가수 : 싸이 (PSY)
# mv_곡 : New Face
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 33
# mv_가수 : 선미
# mv_곡 : 가시나
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 34
# mv_가수 : 김민호
# mv_곡 : 공룡은 살아있다!
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 35
# mv_가수 : 우주소녀
# mv_곡 : 꿈꾸는 마음으로
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 36
# mv_가수 : TWICE (트와이스)
# mv_곡 : TT
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 37
# mv_가수 : 위키미키(Weki Meki)
# mv_곡 : La La La
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 38
# mv_가수 : 홍진영
# mv_곡 : 잘가라
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 39
# mv_가수 : TWICE (트와이스)
# mv_곡 : KNOCK KNOCK
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 40
# mv_가수 : TWICE (트와이스)
# mv_곡 : Candy Pop
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 41
# mv_가수 : 로이킴
# mv_곡 : 그때 헤어지면 돼
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 42
# mv_가수 : 장덕철
# mv_곡 : 그날처럼
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 43
# mv_가수 : 방탄소년단
# mv_곡 : MIC Drop (Steve Aoki Remix) (Feat. Desiigner)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 44
# mv_가수 : HOYA(호야)
# mv_곡 : Angel
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 45
# mv_가수 : EXID
# mv_곡 : 덜덜덜
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 46
# mv_가수 : 방탄소년단
# mv_곡 : 봄날
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 47
# mv_가수 : 구구단(gugudan)
# mv_곡 : The Boots
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 48
# mv_가수 : 국민의 아들
# mv_곡 : NEVER
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 49
# mv_가수 : Wanna One(워너원)
# mv_곡 : 활활 (Burn It Up)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 50
# mv_가수 : 김성규
# mv_곡 : True Love
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 51
# mv_가수 : 씨엘씨(CLC)
# mv_곡 : BLACK DRESS
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 52
# mv_가수 : 마마무(Mamamoo)
# mv_곡 : 칠해줘
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 53
# mv_가수 : TWICE (트와이스)
# mv_곡 : SIGNAL
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 54
# mv_가수 : 아이유(IU)
# mv_곡 : 팔레트 (Feat. G-DRAGON)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 55
# mv_가수 : TWICE (트와이스)
# mv_곡 : Merry & Happy
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 56
# mv_가수 : 세븐틴(Seventeen)
# mv_곡 : 고맙다
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 57
# mv_가수 : Camila Cabello(카밀라 카베요)
# mv_곡 : Havana (Feat. Young Thug)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 58
# mv_가수 : 여자친구(GFRIEND)
# mv_곡 : 귀를 기울이면 (LOVE WHISPER)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 59
# mv_가수 : 보아 (BoA)
# mv_곡 : 내가 돌아 (NEGA DOLA)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 60
# mv_가수 : TWICE (트와이스)
# mv_곡 : CHEER UP
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 61
# mv_가수 : 멜로망스(MeloMance)
# mv_곡 : 선물
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 62
# mv_가수 : Wanna One(워너원)
# mv_곡 : Beautiful
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 63
# mv_가수 : 싸이 (PSY)
# mv_곡 : I LUV IT
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 64
# mv_가수 : 방탄소년단
# mv_곡 : 쩔어
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 65
# mv_가수 : BLACKPINK
# mv_곡 : 붐바야
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 66
# mv_가수 : TWICE (트와이스)
# mv_곡 : OOH-AHH하게
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 67
# mv_가수 : 마마무(Mamamoo)
# mv_곡 : 나로 말할 것 같으면
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 68
# mv_가수 : 김영철
# mv_곡 : 안되나용 (Feat. 휘성(Realslow))
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 69
# mv_가수 : JBJ
# mv_곡 : 꽃이야
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 70
# mv_가수 : 블락비(Block B)
# mv_곡 : Shall We Dance
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 71
# mv_가수 : 비투비(BTOB)
# mv_곡 : 그리워하다
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 72
# mv_가수 : EXO
# mv_곡 : Ko Ko Bop
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 73
# mv_가수 : BLACKPINK
# mv_곡 : 불장난
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 74
# mv_가수 : 여자친구(GFRIEND)
# mv_곡 : 여름비 (SUMMER RAIN)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 75
# mv_가수 : GOT7 (갓세븐)
# mv_곡 : 너 하나만 (Feat. 효린) (Special Video)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 76
# mv_가수 : 수지(SUZY)
# mv_곡 : 다른사람을 사랑하고 있어
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 77
# mv_가수 : Kendrick Lamar(켄드릭 라마)
# mv_곡 : All The Stars (Lyrics ver.)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 78
# mv_가수 : 우원재
# mv_곡 : 시차 (We Are)
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 79
# mv_가수 : 구구단(gugudan)
# mv_곡 : Chococo
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 80
# mv_가수 : Red Velvet (레드벨벳)
# mv_곡 : 러시안 룰렛 (Russian Roulette)
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 81
# mv_가수 : 보아 (BoA)
# mv_곡 : ONE SHOT, TWO SHOT
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 82
# mv_가수 : 수지(SUZY)
# mv_곡 : SObeR
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 83
# mv_가수 : 세븐틴(Seventeen)
# mv_곡 : 박수
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 84
# mv_가수 : Red Velvet (레드벨벳)
# mv_곡 : Dumb Dumb
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 85
# mv_가수 : 방탄소년단
# mv_곡 : Not Today
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 86
# mv_가수 : 러블리즈(Lovelyz)
# mv_곡 : 종소리
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 87
# mv_가수 : 스컬
# mv_곡 : 오래된 엘피 feat. 매드클라운, 허각
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 88
# mv_가수 : Marshmello(마시멜로)
# mv_곡 : FRIENDS (한국어 자막 ver.)
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 89
# mv_가수 : 인피니트(Infinite)
# mv_곡 : Tell Me
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 90
# mv_가수 : 김동률
# mv_곡 : 답장
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 91
# mv_가수 : 디노(김민호) & 펀치(김서준)
# mv_곡 : 위 아더 디노 (공룡메카드 엔딩곡)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 92
# mv_가수 : HIGH4, 아이유
# mv_곡 : 봄 사랑 벚꽃 말고
# mv_시청등급 : [12세 이상 관람가]
#
# mv_랭킹 : 93
# mv_가수 : 이짜나언짜나
# mv_곡 : '미세먼지'를 다 날려보낼 춤
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 94
# mv_가수 : 치타(CHEETAH)
# mv_곡 : I'll Be There
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 95
# mv_가수 : 선우정아(Sunwoojunga)
# mv_곡 : 고양이 (feat. 아이유)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 96
# mv_가수 : 우.걸.다
# mv_곡 : 헬로 헬로 (헬로카봇 시즌5 엔딩)
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 97
# mv_가수 : 다비치
# mv_곡 : 너 없는 시간들
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 98
# mv_가수 : 민경훈
# mv_곡 : 후유증
# mv_시청등급 : [15세 이상 관람가]
#
# mv_랭킹 : 99
# mv_가수 : 싸이 (PSY)
# mv_곡 : 강남스타일
# mv_시청등급 : [전체 관람가]
#
# mv_랭킹 : 100
# mv_가수 : BIGBANG
# mv_곡 : 뱅뱅뱅 (BANG BANG BANG)
# mv_시청등급 : [15세 이상 관람가]

# %%
bugs_dailymv[0:10]
# Out:
# [[1, '모모랜드(MOMOLAND)', '뿜뿜', '[12세 이상 관람가]'],
#  [2, '마마무(Mamamoo)', '별이 빛나는 밤', '[15세 이상 관람가]'],
#  [3, 'Red Velvet (레드벨벳)', 'Bad Boy', '[12세 이상 관람가]'],
#  [4, 'NCT 127', 'TOUCH', '[12세 이상 관람가]'],
#  [5, 'Wanna One(워너원)', '약속해요 (I.P.U.)', '[전체 관람가]'],
#  [6, 'NCT U', 'BOSS', '[15세 이상 관람가]'],
#  [7, 'TWICE (트와이스)', 'Heart Shaker', '[12세 이상 관람가]'],
#  [8, '헤이즈(HEIZE)', 'jenga (Feat. Gaeko)', '[15세 이상 관람가]'],
#  [9, 'iKON', '사랑을했다 (LOVE SCENARIO)', '[12세 이상 관람가]'],
#  [10, 'TWICE (트와이스)', 'LIKEY', '[12세 이상 관람가]']]

# %%
import pandas as pd

# 동영상 정보 데이터 프레임화 시키기
mv_frame = pd.DataFrame(bugs_dailymv, columns=['bugs_mv_순위','bugs_아티스트','bugs_제목','bugs_시청등급'])
mv_frame.head()
# Out:
#    bugs_mv_순위          bugs_아티스트        bugs_제목     bugs_시청등급
# 0           1     모모랜드(MOMOLAND)             뿜뿜  [12세 이상 관람가]
# 1           2       마마무(Mamamoo)       별이 빛나는 밤  [15세 이상 관람가]
# 2           3  Red Velvet (레드벨벳)        Bad Boy  [12세 이상 관람가]
# 3           4            NCT 127          TOUCH  [12세 이상 관람가]
# 4           5     Wanna One(워너원)  약속해요 (I.P.U.)      [전체 관람가]

# %%
# 노래 제목을 기준으로 요일 Top 100 차트와 동영상 Top 100 차트를 합친다.
bugs = pd.merge(song_frame, mv_frame, on='bugs_제목')
bugs
# Out:
#      순위  등락               bugs_제목            bugs_가수  \
# 0     4   1              별이 빛나는 밤       마마무(Mamamoo)
# 1     5   1               내가 더 나빠         헤이즈(HEIZE)
# 2     8   0             그때 헤어지면 돼                로이킴
# 3    10   1                    뿜뿜     모모랜드(MOMOLAND)
# 4    11   1                  그날처럼                장덕철
# 5    13   2               Bad Boy  Red Velvet (레드벨벳)
# 6    14   1        Roller Coaster                 청하
# 7    15   0                    선물    멜로망스(MeloMance)
# 8    17   2             별 바람 꽃 태양       마마무(Mamamoo)
# 9    20   0         약속해요 (I.P.U.)     Wanna One(워너원)
# 10   24   2               MIANHAE         헤이즈(HEIZE)
# 11   25   1              너 없는 시간들                다비치
# 12   29  12                  Look         GOT7 (갓세븐)
# 13   30   1                   주인공                 선미
# 14   35   0                  비밀정원   오마이걸(OH MY GIRL)
# 15   43   0                   DNA              방탄소년단
# 16   45   3                 그리워하다          비투비(BTOB)
# 17   46   1                    봄날              방탄소년단
# 18   48   3          Heart Shaker       TWICE (트와이스)
# 19   51   6                 LIKEY       TWICE (트와이스)
# 20   52   0      피카부 (Peek-A-Boo)  Red Velvet (레드벨벳)
# 21   55   5                   후유증                민경훈
# 22   56   3                    답장                김동률
# 23   60   1                 마지막처럼          BLACKPINK
# 24   62  26                   파랑새        에이프릴(APRIL)
# 25   67   4         다른사람을 사랑하고 있어           수지(SUZY)
# 26   74   1     빨간 맛 (Red Flavor)  Red Velvet (레드벨벳)
# 27   76   0              꿈꾸는 마음으로               우주소녀
# 28   79   5  팔레트 (Feat. G-DRAGON)            아이유(IU)
# 29   82   4                 썸 탈꺼야             볼빨간사춘기
# 30   86   1             True Love                김성규
# 31   91   3             Beautiful     Wanna One(워너원)
# 32   96   2                   가시나                 선미
# 33  100   1      에너제틱 (Energetic)     Wanna One(워너원)
#
#                                              bugs_앨범    bugs_발매일  bugs_mv_순위  \
# 0                                      Yellow Flower  2018.03.07           2
# 1                                                 바람  2018.03.08          17
# 2                                          그때 헤어지면 돼  2018.02.12          41
# 3                                             GREAT!  2018.01.03           1
# 4                                               그날처럼  2017.11.28          42
# 5   The Perfect Red Velvet - The 2nd Album Repackage  2018.01.29           3
# 6                                             Offset  2018.01.17          12
# 7                                          Moonlight  2017.07.10          61
# 8                                      Yellow Flower  2018.03.07          24
# 9                약속해요 (I.P.U.) - Special Theme Track  2018.03.05           5
# 10                                                바람  2018.03.08          22
# 11                                               &10  2018.01.25          97
# 12                                       Eyes On You  2018.03.12          18
# 13                                               주인공  2018.01.18          13
# 14                                              비밀정원  2018.01.09          20
# 15                             LOVE YOURSELF 承 'Her'  2017.09.18          16
# 16                                      Brother Act.  2017.10.16          71
# 17                              YOU NEVER WALK ALONE  2017.02.13          46
# 18                                     Merry & Happy  2017.12.11           7
# 19                                       twicetagram  2017.10.30          10
# 20                    Perfect Velvet - The 2nd Album  2017.11.17          19
# 21                                               후유증  2018.02.17          98
# 22                                                답장  2018.01.11          90
# 23                                             마지막처럼  2017.06.22          27
# 24             에이프릴(APRIL) 5th Mini Album 'The Blue'  2018.03.12          14
# 25                                     Faces of Love  2018.01.29          76
# 26                The Red Summer - Summer Mini Album  2017.07.09          25
# 27                                  Dream Your Dream  2018.02.27          35
# 28                                           Palette  2017.04.21          54
# 29                                  Red Diary Page.1  2017.09.28          30
# 30                            1st Album '10 Stories'  2018.02.26          50
# 31                       1-1=0 (NOTHING WITHOUT YOU)  2017.11.13          62
# 32                       SUNMI SPECIAL EDITION [가시나]  2017.08.22          33
# 33                                  1X1=1(TO BE ONE)  2017.08.07          23
#
#             bugs_아티스트     bugs_시청등급
# 0        마마무(Mamamoo)  [15세 이상 관람가]
# 1          헤이즈(HEIZE)  [12세 이상 관람가]
# 2                 로이킴      [전체 관람가]
# 3      모모랜드(MOMOLAND)  [12세 이상 관람가]
# 4                 장덕철  [12세 이상 관람가]
# 5   Red Velvet (레드벨벳)  [12세 이상 관람가]
# 6                  청하  [12세 이상 관람가]
# 7     멜로망스(MeloMance)  [15세 이상 관람가]
# 8        마마무(Mamamoo)  [12세 이상 관람가]
# 9      Wanna One(워너원)      [전체 관람가]
# 10         헤이즈(HEIZE)  [15세 이상 관람가]
# 11                다비치      [전체 관람가]
# 12         GOT7 (갓세븐)  [12세 이상 관람가]
# 13                 선미  [12세 이상 관람가]
# 14   오마이걸(OH MY GIRL)  [12세 이상 관람가]
# 15              방탄소년단      [전체 관람가]
# 16          비투비(BTOB)  [12세 이상 관람가]
# 17              방탄소년단  [12세 이상 관람가]
# 18       TWICE (트와이스)  [12세 이상 관람가]
# 19       TWICE (트와이스)  [12세 이상 관람가]
# 20  Red Velvet (레드벨벳)  [15세 이상 관람가]
# 21                민경훈  [15세 이상 관람가]
# 22                김동률  [12세 이상 관람가]
# 23          BLACKPINK  [12세 이상 관람가]
# 24        에이프릴(APRIL)  [12세 이상 관람가]
# 25           수지(SUZY)  [15세 이상 관람가]
# 26  Red Velvet (레드벨벳)  [12세 이상 관람가]
# 27               우주소녀  [12세 이상 관람가]
# 28            아이유(IU)  [12세 이상 관람가]
# 29             볼빨간사춘기  [12세 이상 관람가]
# 30                김성규  [12세 이상 관람가]
# 31     Wanna One(워너원)      [전체 관람가]
# 32                 선미  [15세 이상 관람가]
# 33     Wanna One(워너원)      [전체 관람가]

# %%
import numpy as np
import platform

from matplotlib import font_manager,rc
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['axes.unicode_minus']=False

if platform.system()=='Darwin':
    rc('font',family='AppleGothic')
elif platform.system()=='Windows':
    path="c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)

else:
    print('Unknown System... Sorry~~')

# %%
np.corrcoef(bugs['순위'], bugs['bugs_mv_순위'])
#노래 차트 순위와 동영상 차트 순위의 상관관계 구하기
# Out:
# array([[1.        , 0.27364241],
#        [0.27364241, 1.        ]])

# %%
plt.figure(figsize=(13,8))
plt.plot(bugs['순위'], bugs['bugs_mv_순위'], color='blue', markersize=12)
plt.grid()
plt.legend(loc='best')
plt.xlabel('일간_랭킹')
plt.ylabel('일간MV_랭킹')
plt.title('bugs 랭킹')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(bugs['순위'], bugs['bugs_mv_순위'], s=50) 
plt.xlabel('일간_랭킹')
plt.ylabel('일간MV_랭킹')
plt.title('bugs 랭킹')
plt.grid() 
plt.show()

# %%
r_fp =np.polyfit(bugs['순위'], bugs['bugs_mv_순위'],1) 
r_fp  #기준에 대한 선

f1 = np.poly1d(r_fp)
fx = np.linspace(0,100,100) 
plt.figure(figsize=(10,10)) 
plt.scatter(bugs['순위'], bugs['bugs_mv_순위'], s=50) 
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g') # 기준 직선 그려주기 
plt.xlabel('일간_랭킹')
plt.ylabel('일간MV_랭킹')
plt.title('bugs 랭킹')
plt.grid() 
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.scatter(bugs['순위'], bugs['bugs_mv_순위'],c=bugs['순위'], s=50) 
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g') 
#오차가 가장 큰 10개의 구에 대해서 텍스트 부여하기 
# for n in range(10):     
#     plt.text(bugs['순위'][n]*1.02,  bugs['bugs_mv_순위'][n] * 0.98, bugs.index[n], fontsize=15)  

plt.xlabel('일간_랭킹') 
plt.ylabel('일간MV_랭킹')
plt.title('bugs 랭킹')
plt.colorbar() 
plt.grid()
plt.show()
